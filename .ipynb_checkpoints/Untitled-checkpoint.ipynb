# %%
# useful to have this code snippet to avoid getting an error in case forgeting 
# to close spark

try:
    spark.stop()
except:
    pass

# Using findspark to find automatically the spark folder
import findspark
findspark.init()

# import python libraries

# initialize
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType
from pyspark.sql.types import DoubleType
from pyspark.sql.types import IntegerType
from pyspark.sql import functions as F
from pyspark.sql import Row

# from pyspark.ml.feature import HashingTF, IDF, RegexTokenizer, StringIndexer, NGram
# from pyspark.ml.classification import LogisticRegression
# from pyspark.ml import Pipeline
# from pyspark.mllib.evaluation import MulticlassMetrics

spark = SparkSession.builder.master("local[*]").getOrCreate()
# num_samples = 100000000

# def inside(p):
#     x, y = random.random(), random.random()
#     return x*x + y*y < 1

# count = spark.sparkContext.parallelize(range(0, num_samples)).filter(inside).count()
# pi = 4 * count / num_samples
# print(pi)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz

# %%
with open('../Downloads/cluster2.txt') as fp:
    data = [line for line in fp]
data = data[0].split(",")
print(data[1])
for row in data[:200]:
    print(row)
# Out:
#  'mrxb-9w9v.BOROUGH___COMMUNITY.txt.gz'
# ['s3k6-pzi2.website.txt.gz'
#  'mrxb-9w9v.BOROUGH___COMMUNITY.txt.gz'
#  'crc3-tcnm.CORE_SUBJECT.txt.gz'
#  'aiww-p3af.Location.txt.gz'
#  'jhjm-vsp8.Agency.txt.gz'
#  '3rfa-3xsf.Incident_Zip.txt.gz'
#  'pqg4-dm6b.Phone.txt.gz'
#  'mdcw-n682.First_Name.txt.gz'
#  'a5td-mswe.Vehicle_Color.txt.gz'
#  '2bnn-yakx.Vehicle_Color.txt.gz'
#  'mjux-q9d4.SCHOOL_LEVEL_.txt.gz'
#  'jz4z-kudi.Violation_Location__City_.txt.gz'
#  'ge8j-uqbf.interest.txt.gz'
#  'niy5-4j7q.MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Neighborhood.txt.gz'
#  '446w-773i.Address_1.txt.gz'
#  '2sps-j9st.PERSON_FIRST_NAME.txt.gz'
#  'mdcw-n682.Last_Name.txt.gz'
#  '52dp-yji6.Owner_Last_Name.txt.gz'
#  '43nn-pn8j.DBA.txt.gz'
#  '5fn4-dr26.City.txt.gz'
#  '7yay-m4ae.AGENCY_NAME.txt.gz'
#  'wcmg-48ep.CORE_SUBJECT___MS_CORE_and__09_12_ONLY_.txt.gz'
#  'vw9i-7mzq.interest1.txt.gz'
#  '3miu-myq2.COMPARABLE_RENTAL___2__Neighborhood.txt.gz'
#  'upwt-zvh3.SCHOOL_LEVEL_.txt.gz'
#  'uqxv-h2se.independentwebsite.txt.gz'
#  'yjub-udmw.Location__Lat__Long_.txt.gz'
#  'f3cg-u8bv.Agency.txt.gz'
#  'ahjc-fdu3.PRINCIPAL_PHONE_NUMBER.txt.gz'
#  'a2pm-dj2w.Borough.txt.gz'
#  'vhah-kvpj.Borough.txt.gz'
#  'yg5a-hytu.CORE_SUBJECT___MS_CORE_and__09_12_ONLY_.txt.gz'
#  'qcdj-rwhu.BUSINESS_NAME2.txt.gz'
#  'n3p6-zve2.website.txt.gz'
#  'c284-tqph.Vehicle_Make.txt.gz'
#  'pdpg-nn8i.CORE_SUBJECT___MS_CORE_and__9_12_ONLY_.txt.gz'
#  '2bnn-yakx.Vehicle_Body_Type.txt.gz'
#  'ji82-xba5.address.txt.gz'
#  'kiv2-tbus.Vehicle_Color.txt.gz'
#  'q5za-zqz7.Agency.txt.gz'
#  'fb26-34vu.CORE_SUBJECT__MS_CORE_and_9_12_ONLY_.txt.gz'
#  'yahh-6yjc.School_Type.txt.gz'
#  'kiv2-tbus.Vehicle_Make.txt.gz'
#  'faiq-9dfq.Vehicle_Body_Type.txt.gz'
#  'niy5-4j7q.COMPARABLE_RENTAL___2__Building_Classification.txt.gz'
#  's3k6-pzi2.interest1.txt.gz'
#  'm59i-mqex.QUEENS_CONDOMINIUM_PROPERTY_Building_Classification.txt.gz'
#  'fzv4-jan3.SCHOOL_LEVEL_.txt.gz'
#  's9d3-x4fz.ZIP.txt.gz'
#  'jt7v-77mi.Vehicle_Color.txt.gz'
#  'cspg-yi7g.PHONE.txt.gz'
#  'vx8i-nprf.MI.txt.gz'
#  'qgea-i56i.PREM_TYP_DESC.txt.gz'
#  'mjux-q9d4.SCHOOL.txt.gz'
#  'cspg-yi7g.ADDRESS.txt.gz'
#  'qusa-igsv.CORE_SUBJECT___MS_CORE_and__09_12_ONLY_.txt.gz'
#  'ipu4-2q9a.Owner_s_House_Zip_Code.txt.gz'
#  'va74-3m6c.company_phone.txt.gz'
#  'a9md-ynri.MI.txt.gz'
#  'n84m-kx4j.VEHICLE_MAKE.txt.gz'
#  '8gpu-s594.SCHOOL_NAME.txt.gz'
#  'tg3t-nh4h.BusinessName.txt.gz'
#  'mu46-p9is.Location.txt.gz'
#  '4s7y-vm5x.CORE_SUBJECT.txt.gz'
#  '3rfa-3xsf.Street_Name.txt.gz'
#  'niy5-4j7q.MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Building_Classification.txt.gz'
#  '6anw-twe4.FirstName.txt.gz'
#  'weg5-33pj.SCHOOL_LEVEL_.txt.gz'
#  'h9gi-nx95.VEHICLE_TYPE_CODE_2.txt.gz'
#  '2bnn-yakx.Vehicle_Make.txt.gz'
#  'hy4q-igkk.Intersection_Street_2.txt.gz'
#  'sxmw-f24h.Street_Name.txt.gz'
#  'sqcr-6mww.Park_Facility_Name.txt.gz'
#  '6rrm-vxj9.parkname.txt.gz'
#  'd3ge-anaz.CORE_COURSE__MS_CORE_and_9_12_ONLY_.txt.gz'
#  'cvh6-nmyi.SCHOOL.txt.gz'
#  '4kpn-sezh.Website.txt.gz'
#  't8hj-ruu2.License_Business_City.txt.gz'
#  '2sps-j9st.PERSON_LAST_NAME.txt.gz'
#  'vwxi-2r5k.CORE_SUBJECT.txt.gz'
#  'myei-c3fa.Neighborhood_2.txt.gz'
#  '2bmr-jdsv.DBA.txt.gz'
#  '5mw2-hzqx.BROOKLYN_CONDOMINIUM_PROPERTY_Building_Classification.txt.gz'
#  'uq7m-95z8.neighborhood.txt.gz'
#  'pvqr-7yc4.Vehicle_Make.txt.gz'
#  'nhms-9u6g.Name__Last__First_.txt.gz'
#  'f4rp-2kvy.Street.txt.gz'
#  '3btx-p4av.COMPARABLE_RENTAL___1__Neighborhood.txt.gz'
#  'qpm9-j523.org_neighborhood.txt.gz'
#  'bbs3-q5us.ZIP.txt.gz'
#  'erm2-nwe9.Landmark.txt.gz'
#  '72ss-25qh.Borough.txt.gz'
#  'jz4z-kudi.Violation_Location__Zip_Code_.txt.gz'
#  's27g-2w3u.School_Name.txt.gz'
#  'yayv-apxh.SCHOOL_LEVEL_.txt.gz'
#  'emnd-d8ba.PRINCIPAL_PHONE_NUMBER.txt.gz'
#  'cyfw-hfqk.STATEN_ISLAND_CONDOMINIUM_PROPERTY_Neighborhood.txt.gz'
#  's79c-jgrm.City.txt.gz'
#  'uzcy-9puk.Intersection_Street_2.txt.gz'
#  '8k4x-9mp5.Last_Name__only_2014_15_.txt.gz'
#  '6bgk-3dad.RESPONDENT_CITY.txt.gz'
#  'kwmq-dbub.CANDMI.txt.gz'
#  'uzcy-9puk.Street_Name.txt.gz'
#  'uchs-jqh4.School_Name.txt.gz'
#  'yrf7-4wry.COMPARABLE_RENTAL___2___Neighborhood.txt.gz'
#  'brga-xeqy.Agency.txt.gz'
#  'bs8b-p36w.LOCATION.txt.gz'
#  'i9pf-sj7c.INTEREST.txt.gz'
#  't8hj-ruu2.First_Name.txt.gz'
#  'dm9a-ab7w.AUTH_REP_FIRST_NAME.txt.gz'
#  '5uac-w243.PREM_TYP_DESC.txt.gz'
#  'h9gi-nx95.VEHICLE_TYPE_CODE_3.txt.gz'
#  '6je4-4x7e.SCHOOL_LEVEL_.txt.gz'
#  '4pt5-3vv4.Location.txt.gz'
#  '4d7f-74pe.Agency.txt.gz'
#  '735p-zed8.CANDMI.txt.gz'
#  'ph7v-u5f3.TOP_VEHICLE_MODELS___5.txt.gz'
#  'e9xc-u3ds.ZIP.txt.gz'
#  '4n2j-ut8i.SCHOOL_LEVEL_.txt.gz'
#  '3rfa-3xsf.Cross_Street_2.txt.gz'
#  'vrn4-2abs.SCHOOL_LEVEL_.txt.gz'
#  '4hiy-398i.CORE_SUBJECT___MS_CORE_and__09_12_ONLY_.txt.gz'
#  'ajxm-kzmj.NeighborhoodName.txt.gz'
#  'ydkf-mpxb.CrossStreetName.txt.gz'
#  'bty7-2jhb.Site_Safety_Mgr_s_Last_Name.txt.gz'
#  '9z9b-6hvk.Borough.txt.gz'
#  'sxmw-f24h.School_Name.txt.gz'
#  'kwmq-dbub.CITY.txt.gz'
#  'faiq-9dfq.Vehicle_Color.txt.gz'
#  'fbaw-uq4e.Location_1.txt.gz'
#  'erm2-nwe9.Incident_Zip.txt.gz'
#  '8eux-rfe8.INPUT_1_Borough.txt.gz'
#  't8hj-ruu2.Business_Phone_Number.txt.gz'
#  'sxmw-f24h.Cross_Street_1.txt.gz'
#  'w9ak-ipjd.Owner_s_Business_Name.txt.gz'
#  'jz4z-kudi.Respondent_Address__Zip_Code_.txt.gz'
#  'aiww-p3af.Street_Name.txt.gz'
#  'szkz-syh6.Prequalified_Vendor_Address.txt.gz'
#  'jt7v-77mi.Vehicle_Make.txt.gz'
#  'pq5i-thsu.DVC_MAKE.txt.gz'
#  'mqdy-gu73.Color.txt.gz'
#  '3rfa-3xsf.Park_Facility_Name.txt.gz'
#  '52dp-yji6.Owner_First_Name.txt.gz'
#  'ffnc-f3aa.SCHOOL_LEVEL_.txt.gz'
#  '9b9u-8989.DBA.txt.gz'
#  'as69-ew8f.StartCity.txt.gz'
#  'qu8g-sxqf.MI.txt.gz'
#  '956m-xy24.COMPARABLE_RENTAL_2__Building_Classification.txt.gz'
#  'dj4e-3xrn.SCHOOL_LEVEL_.txt.gz'
#  'kiv2-tbus.Vehicle_Body_Type.txt.gz'
#  'pvqr-7yc4.Vehicle_Make.txt.gz'
#  's3k6-pzi2.interest4.txt.gz'
#  'bdjm-n7q4.CrossStreet2.txt.gz'
#  'sqcr-6mww.Cross_Street_2.txt.gz'
#  'cgz5-877h.SCHOOL_LEVEL_.txt.gz'
#  'en2c-j6tw.BRONX_CONDOMINIUM_PROPERTY_Building_Classification.txt.gz'
#  'vw9i-7mzq.interest3.txt.gz'
#  'ic3t-wcy2.Zip.txt.gz'
#  'k3cd-yu9d.CANDMI.txt.gz'
#  'bjuu-44hx.DVV_MAKE.txt.gz'
#  'w6yt-hctp.BROOKLYN_CONDOMINIUM_PROPERTY_Neighborhood.txt.gz'
#  'ic3t-wcy2.Applicant_s_First_Name.txt.gz'
#  'pvqr-7yc4.Vehicle_Color.txt.gz'
#  'crc3-tcnm.BOROUGH.txt.gz'
#  'sqcr-6mww.Location.txt.gz'
#  '9b9u-8989.Establishment_Street.txt.gz'
#  'kj4p-ruqc.StreetName.txt.gz'
#  'pvqr-7yc4.Vehicle_Body_Type.txt.gz'
#  'jz4z-kudi.Respondent_Address__City_.txt.gz'
#  'hy4q-igkk.Cross_Street_1.txt.gz'
#  '922w-z7da.address_1.txt.gz'
#  'w9ak-ipjd.Filing_Representative_First_Name.txt.gz'
#  '9ck8-hj3u.PRINCIPAL_PHONE_NUMBER.txt.gz'
#  '4twk-9yq2.CrossStreet2.txt.gz'
#  'mq9d-au8i.School_Name.txt.gz'
#  'r4c5-ndkx._Phone.txt.gz'
#  'rtws-c2ai.School_Name.txt.gz'
#  'kiv2-tbus.Vehicle_Make.txt.gz'
#  '4twk-9yq2.CrossStreet2.txt.gz'
#  'w9if-3pyn.School_Name.txt.gz'
#  'uq7m-95z8.interest1.txt.gz'
#  'n2s5-fumm.BRONX_CONDOMINIUM_PROPERTY_Neighborhood.txt.gz'
#  '72ss-25qh.Agency_ID.txt.gz'
#  'pvqr-7yc4.Vehicle_Body_Type.txt.gz'
#  'bdjm-n7q4.Location.txt.gz'
#  'h9gi-nx95.VEHICLE_TYPE_CODE_4.txt.gz'
#  'ebkm-iyma.Street_Address.txt.gz'
#  'tqtj-sjs8.FromStreetName.txt.gz'
#  'uzcy-9puk.Incident_Zip.txt.gz'
#  'a5qt-5jpu.STATEN_ISLAND_CONDOMINIUM_PROPERTY_Neighborhood.txt.gz'
#  'e9xc-u3ds.CANDMI.txt.gz'
#  '7btz-mnc8.Provider_First_Name.txt.gz'
#  '8586-3zfm.School_Name.txt.gz'
#  'aiww-p3af.School_Name.txt.gz'
#  'vr8p-8shw.DVT_MAKE.txt.gz'
#  'xne4-4v8f.SCHOOL_LEVEL_.txt.gz'
#  'ci93-uc8s.Website.txt.gz'
#  '7btz-mnc8.Provider_Last_Name.txt.gz'
#  'vw9i-7mzq.interest4.txt.gz'
#  'as69-ew8f.TruckMake.txt.gz'

# %%
types = [row.split('.')[1] for row in data]
# print(types)

list_to_match = ["Person name (Last name, First name, Middle name, Full name)","Business name", "Phone Number",
                 "Address", "Street name","City","Neighborhood", "Latitude Longitude", "Zip", "Borough",
                 "School name", "Color", "Car make", "City agency",
                 "Areas of study", "Subjects",
                 "School Levels", "College/University names","Websites",
                 "Building Classification","Vehicle Type",
                 "Type of location"]

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass
 
    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
 
    return False

def process(word):
    word = word.strip()
    lsword = word.split('_')
#     print(lsword)
    wr = ""
    for w in lsword:
        if is_number(w):
#             print("It comes",w)
            continue
        wr += w
#     print(lsword)
#     print("This",wr)
#     word = ''.join(ls)
#     word = word.replace('_', "")
#     re.sub('\\d', "", word)
    return wr.lower()


# word = "CORE_COURSE__MS_CORE_and_9_12_ONLY_"
# print(process(word))

for row in types:
#     print(row)
    newrow = process(row)
    ls = []
    for list_name in list_to_match:
        ls.append( (fuzz.partial_ratio(newrow, list_name.lower()), list_name))
#         print(row, fuzz.partial_ratio(row, list_name))
    ls.sort(reverse=True)
#     print(ls)
    print(row," is most likely : ", ls[0][1])
def checkType(row):
    newrow = process(row)
    ls = []
    for list_name in list_to_match:
        ls.append( (fuzz.partial_ratio(newrow, list_name.lower()), list_name))
    ls.sort(reverse=True)
    return ls[0][1]
# Out:
# website  is most likely :  Websites
# BOROUGH___COMMUNITY  is most likely :  Borough
# CORE_SUBJECT  is most likely :  Subjects
# Location  is most likely :  Type of location
# Agency  is most likely :  City agency
# Incident_Zip  is most likely :  Zip
# Phone  is most likely :  Phone Number
# First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Vehicle_Color  is most likely :  Color
# Vehicle_Color  is most likely :  Color
# SCHOOL_LEVEL_  is most likely :  School Levels
# Violation_Location__City_  is most likely :  City
# interest  is most likely :  College/University names
# MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Neighborhood  is most likely :  Neighborhood
# Address_1  is most likely :  Address
# PERSON_FIRST_NAME  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Last_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Owner_Last_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# DBA  is most likely :  Websites
# City  is most likely :  City agency
# AGENCY_NAME  is most likely :  City agency
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# interest1  is most likely :  College/University names
# COMPARABLE_RENTAL___2__Neighborhood  is most likely :  Neighborhood
# SCHOOL_LEVEL_  is most likely :  School Levels
# independentwebsite  is most likely :  Websites
# Location__Lat__Long_  is most likely :  Latitude Longitude
# Agency  is most likely :  City agency
# PRINCIPAL_PHONE_NUMBER  is most likely :  Phone Number
# Borough  is most likely :  Borough
# Borough  is most likely :  Borough
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# BUSINESS_NAME2  is most likely :  Business name
# website  is most likely :  Websites
# Vehicle_Make  is most likely :  Vehicle Type
# CORE_SUBJECT___MS_CORE_and__9_12_ONLY_  is most likely :  Subjects
# Vehicle_Body_Type  is most likely :  Vehicle Type
# address  is most likely :  Address
# Vehicle_Color  is most likely :  Color
# Agency  is most likely :  City agency
# CORE_SUBJECT__MS_CORE_and_9_12_ONLY_  is most likely :  Subjects
# School_Type  is most likely :  School Levels
# Vehicle_Make  is most likely :  Vehicle Type
# Vehicle_Body_Type  is most likely :  Vehicle Type
# COMPARABLE_RENTAL___2__Building_Classification  is most likely :  Building Classification
# interest1  is most likely :  College/University names
# QUEENS_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# SCHOOL_LEVEL_  is most likely :  School Levels
# ZIP  is most likely :  Zip
# Vehicle_Color  is most likely :  Color
# PHONE  is most likely :  Phone Number
# MI  is most likely :  Zip
# PREM_TYP_DESC  is most likely :  Vehicle Type
# SCHOOL  is most likely :  School name
# ADDRESS  is most likely :  Address
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# Owner_s_House_Zip_Code  is most likely :  Zip
# company_phone  is most likely :  Phone Number
# MI  is most likely :  Zip
# VEHICLE_MAKE  is most likely :  Vehicle Type
# SCHOOL_NAME  is most likely :  School name
# BusinessName  is most likely :  Business name
# Location  is most likely :  Type of location
# CORE_SUBJECT  is most likely :  Subjects
# Street_Name  is most likely :  Street name
# MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Building_Classification  is most likely :  Building Classification
# FirstName  is most likely :  Person name (Last name, First name, Middle name, Full name)
# SCHOOL_LEVEL_  is most likely :  School Levels
# VEHICLE_TYPE_CODE_2  is most likely :  Vehicle Type
# Vehicle_Make  is most likely :  Vehicle Type
# Intersection_Street_2  is most likely :  Subjects
# Street_Name  is most likely :  Street name
# Park_Facility_Name  is most likely :  City
# parkname  is most likely :  Person name (Last name, First name, Middle name, Full name)
# CORE_COURSE__MS_CORE_and_9_12_ONLY_  is most likely :  Color
# SCHOOL  is most likely :  School name
# Website  is most likely :  Websites
# License_Business_City  is most likely :  City
# PERSON_LAST_NAME  is most likely :  Person name (Last name, First name, Middle name, Full name)
# CORE_SUBJECT  is most likely :  Subjects
# Neighborhood_2  is most likely :  Neighborhood
# DBA  is most likely :  Websites
# BROOKLYN_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# neighborhood  is most likely :  Neighborhood
# Vehicle_Make  is most likely :  Vehicle Type
# Name__Last__First_  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Street  is most likely :  Street name
# COMPARABLE_RENTAL___1__Neighborhood  is most likely :  Neighborhood
# org_neighborhood  is most likely :  Neighborhood
# ZIP  is most likely :  Zip
# Landmark  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Borough  is most likely :  Borough
# Violation_Location__Zip_Code_  is most likely :  Zip
# School_Name  is most likely :  School name
# SCHOOL_LEVEL_  is most likely :  School Levels
# PRINCIPAL_PHONE_NUMBER  is most likely :  Phone Number
# STATEN_ISLAND_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# City  is most likely :  City agency
# Intersection_Street_2  is most likely :  Subjects
# Last_Name__only_2014_15_  is most likely :  Person name (Last name, First name, Middle name, Full name)
# RESPONDENT_CITY  is most likely :  City
# CANDMI  is most likely :  Type of location
# Street_Name  is most likely :  Street name
# School_Name  is most likely :  School name
# COMPARABLE_RENTAL___2___Neighborhood  is most likely :  Neighborhood
# Agency  is most likely :  City agency
# LOCATION  is most likely :  Type of location
# INTEREST  is most likely :  College/University names
# First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# AUTH_REP_FIRST_NAME  is most likely :  Person name (Last name, First name, Middle name, Full name)
# PREM_TYP_DESC  is most likely :  Vehicle Type
# VEHICLE_TYPE_CODE_3  is most likely :  Vehicle Type
# SCHOOL_LEVEL_  is most likely :  School Levels
# Location  is most likely :  Type of location
# Agency  is most likely :  City agency
# CANDMI  is most likely :  Type of location
# TOP_VEHICLE_MODELS___5  is most likely :  Vehicle Type
# ZIP  is most likely :  Zip
# SCHOOL_LEVEL_  is most likely :  School Levels
# Cross_Street_2  is most likely :  Street name
# SCHOOL_LEVEL_  is most likely :  School Levels
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# NeighborhoodName  is most likely :  Neighborhood
# CrossStreetName  is most likely :  Street name
# Site_Safety_Mgr_s_Last_Name  is most likely :  Street name
# Borough  is most likely :  Borough
# School_Name  is most likely :  School name
# CITY  is most likely :  City agency
# Vehicle_Color  is most likely :  Color
# Location_1  is most likely :  Type of location
# Incident_Zip  is most likely :  Zip
# INPUT_1_Borough  is most likely :  Borough
# Business_Phone_Number  is most likely :  Phone Number
# Cross_Street_1  is most likely :  Street name
# Owner_s_Business_Name  is most likely :  Business name
# Respondent_Address__Zip_Code_  is most likely :  Zip
# Street_Name  is most likely :  Street name
# Prequalified_Vendor_Address  is most likely :  Address
# Vehicle_Make  is most likely :  Vehicle Type
# DVC_MAKE  is most likely :  Car make
# Color  is most likely :  Color
# Park_Facility_Name  is most likely :  City
# Owner_First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# SCHOOL_LEVEL_  is most likely :  School Levels
# DBA  is most likely :  Websites
# StartCity  is most likely :  City
# MI  is most likely :  Zip
# COMPARABLE_RENTAL_2__Building_Classification  is most likely :  Building Classification
# SCHOOL_LEVEL_  is most likely :  School Levels
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Vehicle_Make  is most likely :  Vehicle Type
# interest4  is most likely :  College/University names
# CrossStreet2  is most likely :  Street name
# Cross_Street_2  is most likely :  Street name
# SCHOOL_LEVEL_  is most likely :  School Levels
# BRONX_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# interest3  is most likely :  College/University names
# Zip  is most likely :  Zip
# CANDMI  is most likely :  Type of location
# DVV_MAKE  is most likely :  Car make
# BROOKLYN_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# Applicant_s_First_Name  is most likely :  Street name
# Vehicle_Color  is most likely :  Color
# BOROUGH  is most likely :  Borough
# Location  is most likely :  Type of location
# Establishment_Street  is most likely :  Street name
# StreetName  is most likely :  Street name
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Respondent_Address__City_  is most likely :  City
# Cross_Street_1  is most likely :  Street name
# address_1  is most likely :  Address
# Filing_Representative_First_Name  is most likely :  College/University names
# PRINCIPAL_PHONE_NUMBER  is most likely :  Phone Number
# CrossStreet2  is most likely :  Street name
# School_Name  is most likely :  School name
# _Phone  is most likely :  Phone Number
# School_Name  is most likely :  School name
# Vehicle_Make  is most likely :  Vehicle Type
# CrossStreet2  is most likely :  Street name
# School_Name  is most likely :  School name
# interest1  is most likely :  College/University names
# BRONX_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# Agency_ID  is most likely :  City agency
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Location  is most likely :  Type of location
# VEHICLE_TYPE_CODE_4  is most likely :  Vehicle Type
# Street_Address  is most likely :  Address
# FromStreetName  is most likely :  Street name
# Incident_Zip  is most likely :  Zip
# STATEN_ISLAND_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# CANDMI  is most likely :  Type of location
# Provider_First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# School_Name  is most likely :  School name
# School_Name  is most likely :  School name
# DVT_MAKE  is most likely :  Car make
# SCHOOL_LEVEL_  is most likely :  School Levels
# Website  is most likely :  Websites
# Provider_Last_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# interest4  is most likely :  College/University names
# TruckMake  is most likely :  Car make
# website  is most likely :  Websites
# owner_city  is most likely :  City
# HOUSE_NUMBER  is most likely :  Phone Number
# BROOKLYN___COOPERATIVES_COMPARABLE_PROPERTIES___Building_Classification  is most likely :  Building Classification
# Agency  is most likely :  City agency
# City  is most likely :  City agency
# Vendor_DBA  is most likely :  Color
# Borough  is most likely :  Borough
# School_Name  is most likely :  School name
# interest6  is most likely :  College/University names
# Agency_Website  is most likely :  Websites
# APPLICANT_FIRST_NAME  is most likely :  Street name
# Incident_Zip  is most likely :  Zip
# DBA  is most likely :  Websites
# BOROUGH  is most likely :  Borough
# telephone  is most likely :  Latitude Longitude
# StreetName  is most likely :  Street name
# COMPARABLE_RENTAL___1__Building_Classification  is most likely :  Building Classification
# CORE_SUBJECT_9_12_ONLY_  is most likely :  Subjects
# TOSTREETNAME  is most likely :  Street name
# BORO  is most likely :  Borough
# Middle_Initial  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Agency  is most likely :  City agency
# LOCATION  is most likely :  Type of location
# WEBSITE  is most likely :  Websites
# Owner_s__Phone__  is most likely :  School name
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# Agency  is most likely :  City agency
# AUTH_REP_LAST_NAME  is most likely :  Street name
# Website  is most likely :  Websites
# VEHICLE_TYPE_CODE_5  is most likely :  Vehicle Type
# Park_Facility_Name  is most likely :  City
# Site_Safety_Mgr_s_Last_Name  is most likely :  Street name
# VEHICLE_TYPE_CODE_1  is most likely :  Vehicle Type
# Site_Safety_Mgr_s_First_Name  is most likely :  Street name
# City  is most likely :  City agency
# BORO  is most likely :  Borough
# Address_1__self_reported_  is most likely :  Address
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Neighborhood  is most likely :  Neighborhood
# CORE_COURSE_9_12_ONLY_  is most likely :  Color
# School_Name  is most likely :  School name
# Address_1__self_reported_  is most likely :  Address
# Address  is most likely :  Address
# SCHOOL_LEVEL_  is most likely :  School Levels
# Park_Site_Name  is most likely :  College/University names
# Address  is most likely :  Address
# STREET_NAME  is most likely :  Street name
# interest5  is most likely :  College/University names
# Vehicle_Color  is most likely :  Color
# School_Name  is most likely :  School name
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# Vehicle_Make  is most likely :  Vehicle Type
# MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Building_Classification  is most likely :  Building Classification
# BORO  is most likely :  Borough
# LastName  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Location_1  is most likely :  Type of location
# BOROUGH  is most likely :  Borough
# Agency  is most likely :  City agency
# QUEENS_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Park_Facility_Name  is most likely :  City
# Vehicle_Make  is most likely :  Vehicle Type
# Agency_Name  is most likely :  City agency
# BROOKLYN_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# OWNER_BUS_STREET_NAME  is most likely :  Street name
# CORE_COURSE__MS_CORE_and_9_12_ONLY_  is most likely :  Color
# CITY  is most likely :  City agency
# Applicant_Last_Name  is most likely :  Street name
# Address1  is most likely :  Address
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Phone_Number  is most likely :  Phone Number

# %%
df = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/.tsv")

# %%
df = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2017_DOE_High_School_Directory.tsv")

# %%
df.select('website').show(df.count(),truncate=False)
# Out:
# +--------------------------------------------------------+
# |website                                                 |
# +--------------------------------------------------------+
# |www.theclintonschool.net                                |
# |schools.nyc.gov/schoolportals/21/K728                   |
# |schools.nyc.gov/SchoolPortals/08/X282                   |
# |www.bkmusicntheatre.com                                 |
# |www.epicschoolsnyc.org                                  |
# |www.preparatoryacademyforwriters.com                    |
# |www.generationschools.org                               |
# |www.panamericanihs.org                                  |
# |www.bronxlgj.org                                        |
# |www.richmondhillhs.org                                  |
# |www.MatherHSNYC.org                                     |
# |www.queensgateway.com                                   |
# |www.wjps.org                                            |
# |www.FrankSinatraSchoolOfTheArts.org                     |
# |schools.nyc.gov/SchoolPortals/10/X439                   |
# |schools.nyc.gov/schoolportals/29/Q313                   |
# |www.eschs.org                                           |
# |schools.nyc.gov/schoolportals/02/M544                   |
# |www.hsmcnyc.org                                         |
# |www.vanguardnyc.net                                     |
# |www.queensinquiry.com                                   |
# |www.ywlnetwork.org                                      |
# |www.ecoandfin.org                                       |
# |sites.google.com/site/bronxcollegiateacademy            |
# |www.bronxsoftware.org                                   |
# |www.LawandFinance.org                                   |
# |www.BSSJBrooklyn.com                                    |
# |www.ppasnyc.org                                         |
# |http://schools.nyc.gov/SchoolPortals/05/M369/default.htm|
# |www.aupnyc.org                                          |
# |www.bxchs.org                                           |
# |www.myNEHS.info                                         |
# |www.williamsburgprep.com                                |
# |www.Teachersprep.org                                    |
# |schools.nyc.gov/schoolportals/17/k524                   |
# |www.KECSS.info                                          |
# |schools.nyc.gov/SchoolPortals/08/X349                   |
# |www.Renaissancemtt.org                                  |
# |http://schools.nyc.gov/SchoolPortals/04/M409/default.htm|
# |schools.nyc.gov/SchoolPortals/07/X221                   |
# |www.cssjbronx.org                                       |
# |www.csihighschool.org                                   |
# |www.newyorkharborschool.org                             |
# |www.sof.edu                                             |
# |http://mihs.nycdoe.org                                  |
# |www.bsmartnow.com                                       |
# |www.ihs-us.org                                          |
# |www.ihsnyc.org                                          |
# |http://schools.nyc.gov/SchoolPortals/02/M422/default.htm|
# |www.ptechnyc.org                                        |
# |www.bushwickleaders.org                                 |
# |http://schools.nyc.gov/SchoolPortals/06/M462/default.htm|
# |www.hsmp.org                                            |
# |schools.nyc.gov/SchoolPortals/21/K337                   |
# |www.bxtrumanhighschool.com                              |
# |http://schools.nyc.gov/SchoolPortals/02/M296/default.htm|
# |www.AMSbronx.org                                        |
# |schools.nyc.gov/SchoolPortals/13/K419                   |
# |www.millenniumbrooklynhs.org                            |
# |www.erhsnyc.org                                         |
# |www.eagleharlem.org                                     |
# |www.uagreencareers.org                                  |
# |www.UniversityHeightsHighSchool.org                     |
# |www.ewsis.org                                           |
# |www.hsforteaching.org                                   |
# |schools.nyc.gov/SchoolPortals/17/K382                   |
# |www.brooklynfrontiers.org                               |
# |www.MillenniumArtAcademy.wix.com/millennium             |
# |www.hphsnyc.org                                         |
# |www.newdesignhigh.com                                   |
# |http://schools.nyc.gov/SchoolPortals/02/M439/default.htm|
# |www.Hillcrestweb.com                                    |
# |schools.nyc.gov/SchoolPortals/27/Q351                   |
# |www.fashionhighschool.net                               |
# |www.LehmanHS.com                                        |
# |www.urbanassemblyschool.net                             |
# |www.uaagl.org                                           |
# |www.facinghistoryschool.org                             |
# |www.astorcollegiate.com                                 |
# |schools.nyc.gov/SchoolPortals/12/X248                   |
# |www.qhss.org                                            |
# |www.mybihs.org                                          |
# |schools.nyc.gov/SchoolPortals/29/Q272                   |
# |www.mychah.org                                          |
# |www.kaufmanmusiccenter.org/sms                          |
# |www.mecps.org                                           |
# |schools.nyc.gov/SchoolPortals/28/Q325                   |
# |schools.nyc.gov/SchoolPortals/10/X243                   |
# |schools.nyc.gov/schoolportals/18/k589                   |
# |schools.nyc.gov/SchoolPortals/18/K563                   |
# |www.kurthahnschool.org                                  |
# |schools.nyc.gov/SchoolPortals/16/K393                   |
# |www.flhfhs.org                                          |
# |www.bronxletters.org                                    |
# |schools.nyc.gov/SchoolPortals/17/K533                   |
# |schools.nyc.gov/SchoolPortals/10/X438                   |
# |schools.nyc.gov/SchoolPortals/17/K546                   |
# |www.wcbryanths.org                                      |
# |schools.nyc.gov/SchoolPortals/09/X412                   |
# |schools.nyc.gov/SchoolPortals/26/Q315                   |
# |www.AOFEHS.org                                          |
# |www.myhslps.org                                         |
# |www.bilanyc.net                                         |
# |www.foresthillshs.org                                   |
# |www.nyclabschool.org                                    |
# |www.rfkschools.org                                      |
# |www.hsflad.org                                          |
# |schools.nyc.gov/schoolportals/19/k507                   |
# |www.universityneighborhoodhs.org                        |
# |www.mckeecths.org                                       |
# |www.johnadamsnyc.org                                    |
# |www.essexstreetacademy.org                              |
# |www.hstat.org                                           |
# |www.cvsr.info                                           |
# |www.WHSAD.org                                           |
# |www.tywlsqueens.org                                     |
# |www.aohterasmus.org                                     |
# |schools.nyc.gov/SchoolPortals/08/X305                   |
# |www.in-techacademy.org                                  |
# |www.bccprep.com                                         |
# |schools.nyc.gov/SchoolPortals/11/X545                   |
# |www.newtownhighschool.org                               |
# |schools.nyc.gov/SchoolPortals/09/X517                   |
# |www.RockawayParkHS.com                                  |
# |www.bronxcompass.org                                    |
# |www.hopschool.com                                       |
# |www.foodfinancehs.org                                   |
# |schools.nyc.gov/SchoolPortals/29/Q492                   |
# |schools.nyc.gov/SchoolPortals/15/K463                   |
# |www.thebronxguildhighschool.org                         |
# |www.fthhs.org                                           |
# |www.thhs.qc.edu                                         |
# |www.clarabartonhighschool.org                           |
# |http://schools.nyc.gov/SchoolPortals/02/M520/default.htm|
# |schools.nyc.gov/SchoolPortals/22/K630                   |
# |www.nycmuseumschool.org                                 |
# |www.gradyhs.com                                         |
# |www.aesmithhs.org                                       |
# |www.johndeweyhighschool.org                             |
# |http://schools.nyc.gov/SchoolPortals/01/M292/default.htm|
# |www.bhswca.com                                          |
# |schools.nyc.gov/SchoolPortals/10/X237                   |
# |schools.nyc.gov/SchoolPortals/10/X342                   |
# |www.languageandinnovation.org                           |
# |www.validusprep.org                                     |
# |www.RachelCarsonhs.org                                  |
# |www.btahs.org                                           |
# |www.hudsonhs.com                                        |
# |http://schools.nyc.gov/schoolportals/02/M300            |
# |www.gramercyhs.org                                      |
# |http://www.uamaker.nyc                                  |
# |www.bxscience.edu                                       |
# |www.siths.org                                           |
# |www.flushinghighschool.org                              |
# |www.johnbowne.org                                       |
# |schools.nyc.gov/schoolportals/13/k670                   |
# |www.bard.edu/bhsec                                      |
# |schools.nyc.gov/SchoolPortals/11/X288                   |
# |www.petridesschool.com                                  |
# |www.bkagf.org                                           |
# |www.pelhamprepacademy.org                               |
# |schools.nyc.gov/SchoolPortals/18/K637                   |
# |schools.nyc.gov/schoolportals/10/x437                   |
# |www.gchs.info                                           |
# |www.wadleigharts.org                                    |
# |schools.nyc.gov/SchoolPortals/07/X473                   |
# |www.hs-gc.org                                           |
# |schools.nyc.gov/SchoolPortals/27/Q650                   |
# |www.millenniumhs.org                                    |
# |www.goddardhs308.org                                    |
# |schools.nyc.gov/SchoolPortals/30/Q450                   |
# |schools.nyc.gov/SchoolPortals/11/X275                   |
# |schools.nyc.gov/SchoolPortals/11/X270                   |
# |schools.nyc.gov/SchoolPortals/17/K537 or www.ycdhs.org  |
# |www.juanmorelcampos.com                                 |
# |schools.nyc.gov/SchoolPortals/14/K632                   |
# |www.hsenergytech.org                                    |
# |www.tywls-astoria.org                                   |
# |www.tottenvillehs.net                                   |
# |schools.nyc.gov/SchoolPortals/19/K659                   |
# |http://schools.nyc.gov/SchoolPortals/03/M494/default.htm|
# |www.ms223.org                                           |
# |www.inwoodearlycollege.net                              |
# |www.ls3.org                                             |
# |www.kappainternational.org                              |
# |www.academyofamericanstudies.com                        |
# |www.leadershipnyc.org                                   |
# |schools.nyc.gov/SchoolPortals/09/X260                   |
# |schools.nyc.gov/SchoolPortals/10/X213                   |
# |www.uasch.org                                           |
# |schools.nyc.gov/SchoolPortals/26/Q435                   |
# |www.landmarkhs.org                                      |
# |www.cobblehillhighschool.org                            |
# |schools.nyc.gov/SchoolPortals/21/K348                   |
# |www.LawHS.org                                           |
# |www.harvestcollegiate.org                               |
# |www.eastbronxacademy.org                                |
# |FDAVI.connectwithkids.com                               |
# |www.uamhighschool.org                                   |
# |www.sljhs.org                                           |
# |schools.nyc.gov/SchoolPortals/07/X321                   |
# |www.lyonscommunityschool.org                            |
# |http://schools.nyc.gov/SchoolPortals/05/M304/default.htm|
# |schools.nyc.gov/SchoolPortals/27/Q400                   |
# |www.nycischool.org                                      |
# |www.bronxlatin.com                                      |
# |www.bedfordacademyhs.org                                |
# |www.fda1.org                                            |
# |schools.nyc.gov/SchoolPortals/18/K642                   |
# |www.midwoodhighschool.org                               |
# |schools.nyc.gov/SchoolPortals/17/K531                   |
# |www.ermurrowhs.org                                      |
# |schools.nyc.gov/SchoolPortals/09/X250                   |
# |http://schools.nyc.gov/SchoolPortals/02/M500/default.htm|
# |schools.nyc.gov/SchoolPortals/11/X544                   |
# |www.bronxbridges.org                                    |
# |www.bard.edu/bhsec                                      |
# |schools.nyc.gov/SchoolPortals/19/K502                   |
# |schools.nyc.gov/SchoolPortals/13/K499                   |
# |www.uasem.org                                           |
# |http://schools.nyc.gov/SchoolPortals/03/M541/default.htm|
# |www.martavalle.org                                      |
# |http://schools.nyc.gov/SchoolPortals/02/M542/default.htm|
# |schools.nyc.gov/SchoolPortals/08/X348                   |
# |www.ichs.weebly.com                                     |
# |www.jamaicagateway.org                                  |
# |schools.nyc.gov/SchoolPortals/08/X559                   |
# |www.parkeasths.org                                      |
# |www.ebtbrooklyn.com                                     |
# |http://schools.nyc.gov/SchoolPortals/02/M545/default.htm|
# |www.highschoolofworldcultures.org                       |
# |www.bhsva418.com                                        |
# |www.gilpp.org                                           |
# |www.queenscollegiate.wordpress.com                      |
# |www.curtishs.org                                        |
# |www.envirostudies.org                                   |
# |schools.nyc.gov/SchoolPortals/23/K644                   |
# |schools.nyc.gov/SchoolPortals/13/K350                   |
# |www.excelsiorprephs.com                                 |
# |www.maspethhighschool.org                               |
# |www.epicschoolsnyc.org                                  |
# |www.columbiasecondary.org                               |
# |schools.nyc.gov/SchoolPortals/11/X290                   |
# |www.holcombelrucker.org                                 |
# |schools.nyc.gov/SchoolPortals/19/K583                   |
# |www.qhsls.org                                           |
# |www.thecinemaschool.org                                 |
# |www.aelnyc.org                                          |
# |www.ndssonline.org                                      |
# |www.BronxEnvision.org                                   |
# |schools.nyc.gov/schoolportals/19/k504                   |
# |schools.nyc.gov/SchoolPortals/16/K455                   |
# |www.elpuente.us                                         |
# |schools.nyc.gov/SchoolPortals/21/K559                   |
# |www.francislewishs.org                                  |
# |www.BronxInternationalHS.com                            |
# |www.automotivehs.org                                    |
# |www.uainstitute.org                                     |
# |www.brooklynstudio.org                                  |
# |www.mandelaschoolnyc.org                                |
# |www.humanitiesprep.org                                  |
# |www.lomanyc.net                                         |
# |www.brooklynprephs.org                                  |
# |www.bronxearlycollegeacademy.org                        |
# |www.brooklyncollegeacademy.com                          |
# |www.explorationsacademy.org                             |
# |www.ccbxhsm.org                                         |
# |www.baysidehighschool.org                               |
# |www.artanddesignhs.org                                  |
# |www.nycBOSS.org                                         |
# |www.bxtheatre.org                                       |
# |http://schools.nyc.gov/SchoolPortals/02/M615/default.htm|
# |schools.nyc.gov/SchoolPortals/32/K545                   |
# |schools.nyc.gov/SchoolPortals/19/K683                   |
# |schools.nyc.gov/SchoolPortals/09/X365                   |
# |schools.nyc.gov/SchoolPortals/07/X259                   |
# |www.dwchs.net                                           |
# |www.belmontprephs.org                                   |
# |schools.nyc.gov/SchoolPortals/10/X268                   |
# |http://schools.nyc.gov/SchoolPortals/06/M293/default.htm|
# |www.lmghs.org                                           |
# |www.basehighschool.org                                  |
# |www.repertorycompanyhs.org                              |
# |www.tuhsnyc.com                                         |
# |schools.nyc.gov/SchoolPortals/14/K474                   |
# |www.tywlsbronx.org                                      |
# |www.nestmk12.net                                        |
# |www.mhacademy.net                                       |
# |www.K497.org                                            |
# |www.nychscl.org                                         |
# |newcomershs.schoolwires.net                             |
# |www.actvf.org                                           |
# |www.queensvoc.org                                       |
# |schools.nyc.gov/schoolportals/08/X376                   |
# |www.eaglebronx.org                                      |
# |www.sfe-morriscampus.org                                |
# |www.maxwellhs.org                                       |
# |www.sunsetparkhighschool.org                            |
# |schools.nyc.gov/schoolportals/17/K489                   |
# |www.laguardiahs.org                                     |
# |www.tapconyc.org                                        |
# |www.hostoslincoln.org                                   |
# |www.aviationhs.net                                      |
# |www.MadisonHS.org                                       |
# |www.academyforyoungwriters.org                          |
# |schools.nyc.gov/SchoolPortals/16/K594                   |
# |www.dyprep.org                                          |
# |schools.nyc.gov/SchoolPortals/12/X692                   |
# |www.mcsm.net                                            |
# |schools.nyc.gov/SchoolPortals/12/X684                   |
# |www.uascriminaljustice.org                              |
# |www.brooklynlatin.org                                   |
# |www.withs.org                                           |
# |schools.nyc.gov/SchoolPortals/09/X564                   |
# |www.westchestersquare.org                               |
# |schools.nyc.gov/SchoolPortals/24/Q550                   |
# |www.bcs448.org                                          |
# |www.hsvd.org                                            |
# |www.humanitiesandthearts.org                            |
# |www.lacjhs.org                                          |
# |www.metropolitanels.com                                 |
# |www.macsx297.org                                        |
# |schools.nyc.gov/SchoolPortals/23/K514                   |
# |schools.nyc.gov/SchoolPortals/11/X249                   |
# |www.khalilgibranhs.org                                  |
# |schools.nyc.gov/SchoolPortals/11/X514                   |
# |www.bronxdalehs.org                                     |
# |www.originshighschool.org                               |
# |schools.nyc.gov/SchoolPortals/09/X413                   |
# |www.MottHallV.org                                       |
# |www.bths.edu                                            |
# |schools.nyc.gov/SchoolPortals/09/X276                   |
# |http://schools.nyc.gov/SchoolPortals/06/M348/default.htm|
# |www.Marblehillschool.org                                |
# |www.citypolyhs.org                                      |
# |www.fda2.org                                            |
# |www.ithsnyc.org                                         |
# |schools.nyc.gov/SchoolPortals/09/X327                   |
# |www.meca-nyc.org                                        |
# |schools.nyc.gov/SchoolPortals/10/X549                   |
# |www.aprandolph.com                                      |
# |http://www.iceschoolnyc.org/                            |
# |www.hsmse.org                                           |
# |www.brooklynhsarts.org                                  |
# |schools.nyc.gov/SchoolPortals/17/K751                   |
# |www.crotonainternationalhs.org                          |
# |http://schools.nyc.gov/SchoolPortals/04/M680/default.htm|
# |www.nycacademy.org                                      |
# |schools.nyc.gov/SchoolPortals/32/K554                   |
# |schools.nyc.gov/SchoolPortals/12/X521                   |
# |www.brooklyncaas.com                                    |
# |http://schools.nyc.gov/SchoolPortals/02/M580/default.htm|
# |www.stuy.edu                                            |
# |www.tywls.org                                           |
# |www.manhattanbusinessacademy.org                        |
# |www.bcchsnyc.net                                        |
# |schools.nyc.gov/SchoolPortals/23/K647                   |
# |JKOHS.Net                                               |
# |http://schools.nyc.gov/SchoolPortals/03/M299/default.htm|
# |www.bsge.org                                            |
# |www.mckinneyssa.com                                     |
# |www.queensmetro.com                                     |
# |www.gaynormccownels.org                                 |
# |schools.nyc.gov/SchoolPortals/19/K422                   |
# |www.victorycollegiate.org                               |
# |www.hsas-lehman.org                                     |
# |www.aoiths.org                                          |
# |http://schools.nyc.gov/SchoolPortals/05/M670/default.htm|
# |schools.nyc.gov/SchoolPortals/28/Q284                   |
# |www.rka141.org                                          |
# |www.transittechhs.org                                   |
# |www.watchnyc.org                                        |
# |www.beaconschool.org                                    |
# |www.47aslhs.org                                         |
# |bronxleadershipacademy.org                              |
# |www.mchslic.com                                         |
# |www.NewUtrechthighschoolnyc.com                         |
# |www.scholarsnyc.com                                     |
# |www.uasbyw.org                                          |
# |www.pathwaysprep.org                                    |
# |www.newworldhighschool.com                              |
# |www.hsacny.com                                          |
# |www.cardozohigh.com                                     |
# |www.digitaltechhs.com                                   |
# |www.leadersschool.net                                   |
# |www.wagnerhigh.net                                      |
# |www.portrichmondhs.org                                  |
# |schools.nyc.gov/SchoolPortals/28/Q690                   |
# |www.ihshealthsciences.org                               |
# |http://schools.nyc.gov/SchoolPortals/04/M555/default.htm|
# |www.maalnyc.org                                         |
# |www.newdorphs.org                                       |
# |www.bronxlabschool.org                                  |
# |www.brooklynlabschool.org                               |
# |www.iam-hs.org                                          |
# |www.afsenyc.org                                         |
# |www.rfwagner.org                                        |
# |http://schools.nyc.gov/SchoolPortals/06/M552/default.htm|
# |www.theveritasacademy.com                               |
# |www.starec.org                                          |
# |schools.nyc.gov/SchoolPortals/09/X252                   |
# |http://schools.nyc.gov/SchoolPortals/06/M468/default.htm|
# |www.bcamhs.org                                          |
# |schools.nyc.gov/SchoolPortals/27/Q309                   |
# |www.BronxleadershipAcademy2.org                         |
# |http://qirt.connectwithkids.com/                        |
# |www.flushinginternational.org                           |
# |www.thomasedisonhs.org                                  |
# |schools.nyc.gov/SchoolPortals/08/X530                   |
# |www.greenschoolbrooklyn.com                             |
# |www.bxdca.org                                           |
# |http://schools.nyc.gov/SchoolPortals/02/M298/default.htm|
# |www.bklawtech.com                                       |
# |www.AbrahamLincolnHS.net                                |
# |http://schools.nyc.gov/SchoolPortals/06/M423/default.htm|
# |www.theglcnyc.org                                       |
# |www.qpacademy.org                                       |
# |www.uawildlifeschool.org                                |
# |schools.nyc.gov/SchoolPortals/08/X320                   |
# |schools.nyc.gov/SchoolPortals/26/Q566                   |
# |www.energytechschool.org                                |
# |www.uagateway.org                                       |
# |www.unionsquareacademy.org                              |
# |http://schools.nyc.gov/SchoolPortals/05/M367/default.htm|
# |http://schools.nyc.gov/SchoolPortals/04/M372/default.htm|
# |schools.nyc.gov/SchoolPortals/08/X269                   |
# |www.uaglobalcommerce.org                                |
# |www.Brooklyncollegiate.net                              |
# |fdrhs.schoolwires.net                                   |
# |schools.nyc.gov/SchoolPortals/17/K539                   |
# |schools.nyc.gov/SchoolPortals/29/Q327                   |
# |schools.nyc.gov/SchoolPortals/19/K409                   |
# |www.worldviewhs.org                                     |
# |www.ihpch.org                                           |
# |www.fmhsnyc.org                                         |
# |www.parkslopecollegiate.org                             |
# |www.CLANYC.org                                          |
# |schools.nyc.gov/SchoolPortals/12/X388                   |
# |www.archimedesacademy.org                               |
# |www.thesls.net                                          |
# +--------------------------------------------------------+

# %%
ls = []
import re

# def check_website(word):
# #     grp = re.findall("^((http[s]?|ftp):\/)?\/?([^:\/\s]+)((\/\w+)*\/)([\w\-\.]+[^#?\s]+)(.*)?(#[\w\-]+)?$/", word)
#     grp = re.findall('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', str(word))
#     ls.append(grp)
#     if grp:
#         return str(word)
#     else:
#         return "0"

# def create_list(word):
#     return re.split('; |, |\*|\n|\.|\/',word)
# #     return word.split('.')

def process_website(word):
    if word=='null':
        return 0
    ls = re.split('\.|\/',word)
    lst = ['gov', 'com', 'org', 'info', 'http', 'https', 'net','edu','www']
    if any(item in ls for item in lst):
        return 1
    else:
        return 0
    print(ls)
    return ls
# def check_boro(word):
#     if word in ['MANHATTAN', 'staten island', 'BROOKLYN', 'QUEENS', 'BRONX']:
#         return word
#     else:
#         return "0"
# check_boro = F.udf(check_boro, StringType())

def check_boro(word):
    word = str(word)
    if word=="MANHATTAN":
        return word
    elif word=="BROOKLYN":
        return word
    elif word=="QUEENS":
        return word
    elif word=="BRONX":
        return word
    else:
        return "0"

# create_list = F.udf(create_list, StringType())
check_boro = F.udf(check_boro, StringType())
chk = F.udf(check_website, StringType())
process_website = F.udf(process_website, IntegerType())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-1a60e348703f> in <module>
#      48 # create_list = F.udf(create_list, StringType())
#      49 check_boro = F.udf(check_boro, StringType())
# ---> 50 chk = F.udf(check_website, StringType())
#      51 process_website = F.udf(process_website, IntegerType())
#
# NameError: name 'check_website' is not defined

# %%
df = df.withColumn('check_website', process_website(F.col('website')))
df.select('website', 'check_website').show(df.count(), truncate=False)
cnt_cond = lambda cond: F.sum(F.when(cond, 1).otherwise(0))

ctr_df = df.groupBy('check_website').agg(
    cnt_cond(F.col('check_website') == 1).alias('true_count'))
ctr_df.show()

l = []
for row in ctr_df.rdd.collect():
    l.append((row.check_website, row.true_count))
print(l)
print(df.count())
# Out:
# +--------------------------------------------------------+-------------+
# |website                                                 |check_website|
# +--------------------------------------------------------+-------------+
# |www.theclintonschool.net                                |1            |
# |schools.nyc.gov/schoolportals/21/K728                   |1            |
# |schools.nyc.gov/SchoolPortals/08/X282                   |1            |
# |www.bkmusicntheatre.com                                 |1            |
# |www.epicschoolsnyc.org                                  |1            |
# |www.preparatoryacademyforwriters.com                    |1            |
# |www.generationschools.org                               |1            |
# |www.panamericanihs.org                                  |1            |
# |www.bronxlgj.org                                        |1            |
# |www.richmondhillhs.org                                  |1            |
# |www.MatherHSNYC.org                                     |1            |
# |www.queensgateway.com                                   |1            |
# |www.wjps.org                                            |1            |
# |www.FrankSinatraSchoolOfTheArts.org                     |1            |
# |schools.nyc.gov/SchoolPortals/10/X439                   |1            |
# |schools.nyc.gov/schoolportals/29/Q313                   |1            |
# |www.eschs.org                                           |1            |
# |schools.nyc.gov/schoolportals/02/M544                   |1            |
# |www.hsmcnyc.org                                         |1            |
# |www.vanguardnyc.net                                     |1            |
# |www.queensinquiry.com                                   |1            |
# |www.ywlnetwork.org                                      |1            |
# |www.ecoandfin.org                                       |1            |
# |sites.google.com/site/bronxcollegiateacademy            |1            |
# |www.bronxsoftware.org                                   |1            |
# |www.LawandFinance.org                                   |1            |
# |www.BSSJBrooklyn.com                                    |1            |
# |www.ppasnyc.org                                         |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M369/default.htm|1            |
# |www.aupnyc.org                                          |1            |
# |www.bxchs.org                                           |1            |
# |www.myNEHS.info                                         |1            |
# |www.williamsburgprep.com                                |1            |
# |www.Teachersprep.org                                    |1            |
# |schools.nyc.gov/schoolportals/17/k524                   |1            |
# |www.KECSS.info                                          |1            |
# |schools.nyc.gov/SchoolPortals/08/X349                   |1            |
# |www.Renaissancemtt.org                                  |1            |
# |http://schools.nyc.gov/SchoolPortals/04/M409/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/07/X221                   |1            |
# |www.cssjbronx.org                                       |1            |
# |www.csihighschool.org                                   |1            |
# |www.newyorkharborschool.org                             |1            |
# |www.sof.edu                                             |1            |
# |http://mihs.nycdoe.org                                  |1            |
# |www.bsmartnow.com                                       |1            |
# |www.ihs-us.org                                          |1            |
# |www.ihsnyc.org                                          |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M422/default.htm|1            |
# |www.ptechnyc.org                                        |1            |
# |www.bushwickleaders.org                                 |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M462/default.htm|1            |
# |www.hsmp.org                                            |1            |
# |schools.nyc.gov/SchoolPortals/21/K337                   |1            |
# |www.bxtrumanhighschool.com                              |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M296/default.htm|1            |
# |www.AMSbronx.org                                        |1            |
# |schools.nyc.gov/SchoolPortals/13/K419                   |1            |
# |www.millenniumbrooklynhs.org                            |1            |
# |www.erhsnyc.org                                         |1            |
# |www.eagleharlem.org                                     |1            |
# |www.uagreencareers.org                                  |1            |
# |www.UniversityHeightsHighSchool.org                     |1            |
# |www.ewsis.org                                           |1            |
# |www.hsforteaching.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K382                   |1            |
# |www.brooklynfrontiers.org                               |1            |
# |www.MillenniumArtAcademy.wix.com/millennium             |1            |
# |www.hphsnyc.org                                         |1            |
# |www.newdesignhigh.com                                   |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M439/default.htm|1            |
# |www.Hillcrestweb.com                                    |1            |
# |schools.nyc.gov/SchoolPortals/27/Q351                   |1            |
# |www.fashionhighschool.net                               |1            |
# |www.LehmanHS.com                                        |1            |
# |www.urbanassemblyschool.net                             |1            |
# |www.uaagl.org                                           |1            |
# |www.facinghistoryschool.org                             |1            |
# |www.astorcollegiate.com                                 |1            |
# |schools.nyc.gov/SchoolPortals/12/X248                   |1            |
# |www.qhss.org                                            |1            |
# |www.mybihs.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/29/Q272                   |1            |
# |www.mychah.org                                          |1            |
# |www.kaufmanmusiccenter.org/sms                          |1            |
# |www.mecps.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/28/Q325                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X243                   |1            |
# |schools.nyc.gov/schoolportals/18/k589                   |1            |
# |schools.nyc.gov/SchoolPortals/18/K563                   |1            |
# |www.kurthahnschool.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/16/K393                   |1            |
# |www.flhfhs.org                                          |1            |
# |www.bronxletters.org                                    |1            |
# |schools.nyc.gov/SchoolPortals/17/K533                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X438                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K546                   |1            |
# |www.wcbryanths.org                                      |1            |
# |schools.nyc.gov/SchoolPortals/09/X412                   |1            |
# |schools.nyc.gov/SchoolPortals/26/Q315                   |1            |
# |www.AOFEHS.org                                          |1            |
# |www.myhslps.org                                         |1            |
# |www.bilanyc.net                                         |1            |
# |www.foresthillshs.org                                   |1            |
# |www.nyclabschool.org                                    |1            |
# |www.rfkschools.org                                      |1            |
# |www.hsflad.org                                          |1            |
# |schools.nyc.gov/schoolportals/19/k507                   |1            |
# |www.universityneighborhoodhs.org                        |1            |
# |www.mckeecths.org                                       |1            |
# |www.johnadamsnyc.org                                    |1            |
# |www.essexstreetacademy.org                              |1            |
# |www.hstat.org                                           |1            |
# |www.cvsr.info                                           |1            |
# |www.WHSAD.org                                           |1            |
# |www.tywlsqueens.org                                     |1            |
# |www.aohterasmus.org                                     |1            |
# |schools.nyc.gov/SchoolPortals/08/X305                   |1            |
# |www.in-techacademy.org                                  |1            |
# |www.bccprep.com                                         |1            |
# |schools.nyc.gov/SchoolPortals/11/X545                   |1            |
# |www.newtownhighschool.org                               |1            |
# |schools.nyc.gov/SchoolPortals/09/X517                   |1            |
# |www.RockawayParkHS.com                                  |1            |
# |www.bronxcompass.org                                    |1            |
# |www.hopschool.com                                       |1            |
# |www.foodfinancehs.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/29/Q492                   |1            |
# |schools.nyc.gov/SchoolPortals/15/K463                   |1            |
# |www.thebronxguildhighschool.org                         |1            |
# |www.fthhs.org                                           |1            |
# |www.thhs.qc.edu                                         |1            |
# |www.clarabartonhighschool.org                           |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M520/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/22/K630                   |1            |
# |www.nycmuseumschool.org                                 |1            |
# |www.gradyhs.com                                         |1            |
# |www.aesmithhs.org                                       |1            |
# |www.johndeweyhighschool.org                             |1            |
# |http://schools.nyc.gov/SchoolPortals/01/M292/default.htm|1            |
# |www.bhswca.com                                          |1            |
# |schools.nyc.gov/SchoolPortals/10/X237                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X342                   |1            |
# |www.languageandinnovation.org                           |1            |
# |www.validusprep.org                                     |1            |
# |www.RachelCarsonhs.org                                  |1            |
# |www.btahs.org                                           |1            |
# |www.hudsonhs.com                                        |1            |
# |http://schools.nyc.gov/schoolportals/02/M300            |1            |
# |www.gramercyhs.org                                      |1            |
# |http://www.uamaker.nyc                                  |1            |
# |www.bxscience.edu                                       |1            |
# |www.siths.org                                           |1            |
# |www.flushinghighschool.org                              |1            |
# |www.johnbowne.org                                       |1            |
# |schools.nyc.gov/schoolportals/13/k670                   |1            |
# |www.bard.edu/bhsec                                      |1            |
# |schools.nyc.gov/SchoolPortals/11/X288                   |1            |
# |www.petridesschool.com                                  |1            |
# |www.bkagf.org                                           |1            |
# |www.pelhamprepacademy.org                               |1            |
# |schools.nyc.gov/SchoolPortals/18/K637                   |1            |
# |schools.nyc.gov/schoolportals/10/x437                   |1            |
# |www.gchs.info                                           |1            |
# |www.wadleigharts.org                                    |1            |
# |schools.nyc.gov/SchoolPortals/07/X473                   |1            |
# |www.hs-gc.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/27/Q650                   |1            |
# |www.millenniumhs.org                                    |1            |
# |www.goddardhs308.org                                    |1            |
# |schools.nyc.gov/SchoolPortals/30/Q450                   |1            |
# |schools.nyc.gov/SchoolPortals/11/X275                   |1            |
# |schools.nyc.gov/SchoolPortals/11/X270                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K537 or www.ycdhs.org  |1            |
# |www.juanmorelcampos.com                                 |1            |
# |schools.nyc.gov/SchoolPortals/14/K632                   |1            |
# |www.hsenergytech.org                                    |1            |
# |www.tywls-astoria.org                                   |1            |
# |www.tottenvillehs.net                                   |1            |
# |schools.nyc.gov/SchoolPortals/19/K659                   |1            |
# |http://schools.nyc.gov/SchoolPortals/03/M494/default.htm|1            |
# |www.ms223.org                                           |1            |
# |www.inwoodearlycollege.net                              |1            |
# |www.ls3.org                                             |1            |
# |www.kappainternational.org                              |1            |
# |www.academyofamericanstudies.com                        |1            |
# |www.leadershipnyc.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/09/X260                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X213                   |1            |
# |www.uasch.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/26/Q435                   |1            |
# |www.landmarkhs.org                                      |1            |
# |www.cobblehillhighschool.org                            |1            |
# |schools.nyc.gov/SchoolPortals/21/K348                   |1            |
# |www.LawHS.org                                           |1            |
# |www.harvestcollegiate.org                               |1            |
# |www.eastbronxacademy.org                                |1            |
# |FDAVI.connectwithkids.com                               |1            |
# |www.uamhighschool.org                                   |1            |
# |www.sljhs.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/07/X321                   |1            |
# |www.lyonscommunityschool.org                            |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M304/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/27/Q400                   |1            |
# |www.nycischool.org                                      |1            |
# |www.bronxlatin.com                                      |1            |
# |www.bedfordacademyhs.org                                |1            |
# |www.fda1.org                                            |1            |
# |schools.nyc.gov/SchoolPortals/18/K642                   |1            |
# |www.midwoodhighschool.org                               |1            |
# |schools.nyc.gov/SchoolPortals/17/K531                   |1            |
# |www.ermurrowhs.org                                      |1            |
# |schools.nyc.gov/SchoolPortals/09/X250                   |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M500/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/11/X544                   |1            |
# |www.bronxbridges.org                                    |1            |
# |www.bard.edu/bhsec                                      |1            |
# |schools.nyc.gov/SchoolPortals/19/K502                   |1            |
# |schools.nyc.gov/SchoolPortals/13/K499                   |1            |
# |www.uasem.org                                           |1            |
# |http://schools.nyc.gov/SchoolPortals/03/M541/default.htm|1            |
# |www.martavalle.org                                      |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M542/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/08/X348                   |1            |
# |www.ichs.weebly.com                                     |1            |
# |www.jamaicagateway.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/08/X559                   |1            |
# |www.parkeasths.org                                      |1            |
# |www.ebtbrooklyn.com                                     |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M545/default.htm|1            |
# |www.highschoolofworldcultures.org                       |1            |
# |www.bhsva418.com                                        |1            |
# |www.gilpp.org                                           |1            |
# |www.queenscollegiate.wordpress.com                      |1            |
# |www.curtishs.org                                        |1            |
# |www.envirostudies.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/23/K644                   |1            |
# |schools.nyc.gov/SchoolPortals/13/K350                   |1            |
# |www.excelsiorprephs.com                                 |1            |
# |www.maspethhighschool.org                               |1            |
# |www.epicschoolsnyc.org                                  |1            |
# |www.columbiasecondary.org                               |1            |
# |schools.nyc.gov/SchoolPortals/11/X290                   |1            |
# |www.holcombelrucker.org                                 |1            |
# |schools.nyc.gov/SchoolPortals/19/K583                   |1            |
# |www.qhsls.org                                           |1            |
# |www.thecinemaschool.org                                 |1            |
# |www.aelnyc.org                                          |1            |
# |www.ndssonline.org                                      |1            |
# |www.BronxEnvision.org                                   |1            |
# |schools.nyc.gov/schoolportals/19/k504                   |1            |
# |schools.nyc.gov/SchoolPortals/16/K455                   |1            |
# |www.elpuente.us                                         |1            |
# |schools.nyc.gov/SchoolPortals/21/K559                   |1            |
# |www.francislewishs.org                                  |1            |
# |www.BronxInternationalHS.com                            |1            |
# |www.automotivehs.org                                    |1            |
# |www.uainstitute.org                                     |1            |
# |www.brooklynstudio.org                                  |1            |
# |www.mandelaschoolnyc.org                                |1            |
# |www.humanitiesprep.org                                  |1            |
# |www.lomanyc.net                                         |1            |
# |www.brooklynprephs.org                                  |1            |
# |www.bronxearlycollegeacademy.org                        |1            |
# |www.brooklyncollegeacademy.com                          |1            |
# |www.explorationsacademy.org                             |1            |
# |www.ccbxhsm.org                                         |1            |
# |www.baysidehighschool.org                               |1            |
# |www.artanddesignhs.org                                  |1            |
# |www.nycBOSS.org                                         |1            |
# |www.bxtheatre.org                                       |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M615/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/32/K545                   |1            |
# |schools.nyc.gov/SchoolPortals/19/K683                   |1            |
# |schools.nyc.gov/SchoolPortals/09/X365                   |1            |
# |schools.nyc.gov/SchoolPortals/07/X259                   |1            |
# |www.dwchs.net                                           |1            |
# |www.belmontprephs.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X268                   |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M293/default.htm|1            |
# |www.lmghs.org                                           |1            |
# |www.basehighschool.org                                  |1            |
# |www.repertorycompanyhs.org                              |1            |
# |www.tuhsnyc.com                                         |1            |
# |schools.nyc.gov/SchoolPortals/14/K474                   |1            |
# |www.tywlsbronx.org                                      |1            |
# |www.nestmk12.net                                        |1            |
# |www.mhacademy.net                                       |1            |
# |www.K497.org                                            |1            |
# |www.nychscl.org                                         |1            |
# |newcomershs.schoolwires.net                             |1            |
# |www.actvf.org                                           |1            |
# |www.queensvoc.org                                       |1            |
# |schools.nyc.gov/schoolportals/08/X376                   |1            |
# |www.eaglebronx.org                                      |1            |
# |www.sfe-morriscampus.org                                |1            |
# |www.maxwellhs.org                                       |1            |
# |www.sunsetparkhighschool.org                            |1            |
# |schools.nyc.gov/schoolportals/17/K489                   |1            |
# |www.laguardiahs.org                                     |1            |
# |www.tapconyc.org                                        |1            |
# |www.hostoslincoln.org                                   |1            |
# |www.aviationhs.net                                      |1            |
# |www.MadisonHS.org                                       |1            |
# |www.academyforyoungwriters.org                          |1            |
# |schools.nyc.gov/SchoolPortals/16/K594                   |1            |
# |www.dyprep.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/12/X692                   |1            |
# |www.mcsm.net                                            |1            |
# |schools.nyc.gov/SchoolPortals/12/X684                   |1            |
# |www.uascriminaljustice.org                              |1            |
# |www.brooklynlatin.org                                   |1            |
# |www.withs.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/09/X564                   |1            |
# |www.westchestersquare.org                               |1            |
# |schools.nyc.gov/SchoolPortals/24/Q550                   |1            |
# |www.bcs448.org                                          |1            |
# |www.hsvd.org                                            |1            |
# |www.humanitiesandthearts.org                            |1            |
# |www.lacjhs.org                                          |1            |
# |www.metropolitanels.com                                 |1            |
# |www.macsx297.org                                        |1            |
# |schools.nyc.gov/SchoolPortals/23/K514                   |1            |
# |schools.nyc.gov/SchoolPortals/11/X249                   |1            |
# |www.khalilgibranhs.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/11/X514                   |1            |
# |www.bronxdalehs.org                                     |1            |
# |www.originshighschool.org                               |1            |
# |schools.nyc.gov/SchoolPortals/09/X413                   |1            |
# |www.MottHallV.org                                       |1            |
# |www.bths.edu                                            |1            |
# |schools.nyc.gov/SchoolPortals/09/X276                   |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M348/default.htm|1            |
# |www.Marblehillschool.org                                |1            |
# |www.citypolyhs.org                                      |1            |
# |www.fda2.org                                            |1            |
# |www.ithsnyc.org                                         |1            |
# |schools.nyc.gov/SchoolPortals/09/X327                   |1            |
# |www.meca-nyc.org                                        |1            |
# |schools.nyc.gov/SchoolPortals/10/X549                   |1            |
# |www.aprandolph.com                                      |1            |
# |http://www.iceschoolnyc.org/                            |1            |
# |www.hsmse.org                                           |1            |
# |www.brooklynhsarts.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/17/K751                   |1            |
# |www.crotonainternationalhs.org                          |1            |
# |http://schools.nyc.gov/SchoolPortals/04/M680/default.htm|1            |
# |www.nycacademy.org                                      |1            |
# |schools.nyc.gov/SchoolPortals/32/K554                   |1            |
# |schools.nyc.gov/SchoolPortals/12/X521                   |1            |
# |www.brooklyncaas.com                                    |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M580/default.htm|1            |
# |www.stuy.edu                                            |1            |
# |www.tywls.org                                           |1            |
# |www.manhattanbusinessacademy.org                        |1            |
# |www.bcchsnyc.net                                        |1            |
# |schools.nyc.gov/SchoolPortals/23/K647                   |1            |
# |JKOHS.Net                                               |0            |
# |http://schools.nyc.gov/SchoolPortals/03/M299/default.htm|1            |
# |www.bsge.org                                            |1            |
# |www.mckinneyssa.com                                     |1            |
# |www.queensmetro.com                                     |1            |
# |www.gaynormccownels.org                                 |1            |
# |schools.nyc.gov/SchoolPortals/19/K422                   |1            |
# |www.victorycollegiate.org                               |1            |
# |www.hsas-lehman.org                                     |1            |
# |www.aoiths.org                                          |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M670/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/28/Q284                   |1            |
# |www.rka141.org                                          |1            |
# |www.transittechhs.org                                   |1            |
# |www.watchnyc.org                                        |1            |
# |www.beaconschool.org                                    |1            |
# |www.47aslhs.org                                         |1            |
# |bronxleadershipacademy.org                              |1            |
# |www.mchslic.com                                         |1            |
# |www.NewUtrechthighschoolnyc.com                         |1            |
# |www.scholarsnyc.com                                     |1            |
# |www.uasbyw.org                                          |1            |
# |www.pathwaysprep.org                                    |1            |
# |www.newworldhighschool.com                              |1            |
# |www.hsacny.com                                          |1            |
# |www.cardozohigh.com                                     |1            |
# |www.digitaltechhs.com                                   |1            |
# |www.leadersschool.net                                   |1            |
# |www.wagnerhigh.net                                      |1            |
# |www.portrichmondhs.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/28/Q690                   |1            |
# |www.ihshealthsciences.org                               |1            |
# |http://schools.nyc.gov/SchoolPortals/04/M555/default.htm|1            |
# |www.maalnyc.org                                         |1            |
# |www.newdorphs.org                                       |1            |
# |www.bronxlabschool.org                                  |1            |
# |www.brooklynlabschool.org                               |1            |
# |www.iam-hs.org                                          |1            |
# |www.afsenyc.org                                         |1            |
# |www.rfwagner.org                                        |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M552/default.htm|1            |
# |www.theveritasacademy.com                               |1            |
# |www.starec.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/09/X252                   |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M468/default.htm|1            |
# |www.bcamhs.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/27/Q309                   |1            |
# |www.BronxleadershipAcademy2.org                         |1            |
# |http://qirt.connectwithkids.com/                        |1            |
# |www.flushinginternational.org                           |1            |
# |www.thomasedisonhs.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/08/X530                   |1            |
# |www.greenschoolbrooklyn.com                             |1            |
# |www.bxdca.org                                           |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M298/default.htm|1            |
# |www.bklawtech.com                                       |1            |
# |www.AbrahamLincolnHS.net                                |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M423/default.htm|1            |
# |www.theglcnyc.org                                       |1            |
# |www.qpacademy.org                                       |1            |
# |www.uawildlifeschool.org                                |1            |
# |schools.nyc.gov/SchoolPortals/08/X320                   |1            |
# |schools.nyc.gov/SchoolPortals/26/Q566                   |1            |
# |www.energytechschool.org                                |1            |
# |www.uagateway.org                                       |1            |
# |www.unionsquareacademy.org                              |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M367/default.htm|1            |
# |http://schools.nyc.gov/SchoolPortals/04/M372/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/08/X269                   |1            |
# |www.uaglobalcommerce.org                                |1            |
# |www.Brooklyncollegiate.net                              |1            |
# |fdrhs.schoolwires.net                                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K539                   |1            |
# |schools.nyc.gov/SchoolPortals/29/Q327                   |1            |
# |schools.nyc.gov/SchoolPortals/19/K409                   |1            |
# |www.worldviewhs.org                                     |1            |
# |www.ihpch.org                                           |1            |
# |www.fmhsnyc.org                                         |1            |
# |www.parkslopecollegiate.org                             |1            |
# |www.CLANYC.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/12/X388                   |1            |
# |www.archimedesacademy.org                               |1            |
# |www.thesls.net                                          |1            |
# +--------------------------------------------------------+-------------+
# +-------------+----------+
# |check_website|true_count|
# +-------------+----------+
# |            1|       439|
# |            0|         0|
# +-------------+----------+
#
# [(1, 439), (0, 0)]
# 440

# %%
newdf = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2014_-_2015_DOE_High_School_Directory.tsv")

# %%
# For each dataset in the cluster file do:
# find the column name. 
# Call best match for this column name
# call function corresponding to bestMatch on this column
# return the count of non NULL values.

# %%
# newdf.select('website').show(truncate=False)
# newdf = newdf.na.fill("e", "webiste")
print(newdf.count())
newdf = newdf.na.fill("null")
# newdf.select("website").show(truncate=False)
newdf = newdf.withColumn('check_website', process_website(F.col('website')))
# newdf.select('website', 'check_website').show(newdf.count(),truncate=False)
cnt_cond = lambda cond: F.sum(F.when(cond, 1).otherwise(0))

ctr_df = newdf.groupBy('check_website').agg(
    cnt_cond(F.col('check_website') == 1).alias('true_count'))

l = []
for row in ctr_df.rdd.collect():
    l.append((row.check_website, row.true_count))
print(l)
# Out:
# 1305
# [(1, 429), (0, 0)]

# %%
def generate_json(function, df, col):
    return function(df, col)
with open('../Downloads/cluster2.txt') as fp:
    data = list(fp)
    
data = data[0][1:-1]
data = data.split(",")
for row in data:
    ls = row.split('.')
    fl = ls[0].strip()[1:]
    col = ls[1]
    flname = "/NYCOpenData/"+fl

# %%
# Code for website checking. RUN THIS AND READ A FILE AND CALL json_for_website(dataframe, original_col_name)
def preprocess(df):
    df = df.na.fill("null")
    return df

def check_website(word):
    if word=='null':
        return "Other"
    ls = re.split('\.|\/',word)
    lst = ['gov', 'com', 'org', 'info', 'http', 'https', 'net','edu','www']
    if any(item in ls for item in lst):
        return "Website"
    else:
        return "Other"

check_website = F.udf(check_website, StringType())

def json_for_website(df, col):
    df = preprocess(df)
    df = df.withColumn("check", check_website(F.col(col)))
    df.createOrReplaceTempView("df")
    temp = spark.sql("select check, count(*) as ctr from df group by check")
    ls = []
    for row in temp.rdd.collect():
        if row.check=="0":
            ls.append(("Other", row.ctr))
        else:
            ls.append((row.check, row.ctr))
    return {"semantic_type":checkType(col), "count":ls}

# %%
web1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2017_DOE_High_School_Directory.tsv")
# print(web1.columns)
web2 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2014_-_2015_DOE_High_School_Directory.tsv")

# web1.select("dbn").show()
print(json_for_website(web1, "website"))
print(json_for_website(web2, "website"))
# Out:
# {'semantic_type': 'Websites', 'count': [('Other', 1), ('Website', 439)]}
# {'semantic_type': 'Websites', 'count': [('Other', 876), ('Website', 429)]}

# %%
# Code for borough checking. RUN THIS AND READ A FILE AND CALL json_for_borough(dataframe, original_col_name)
def check_borough(word):
    word = word.lower()
    if word in ["manhattan", "brooklyn", "bronx", "staten island", "queens"]:
        return word
    else:
        return "0"

check_borough = F.udf(check_borough, StringType())

def preprocess(df):
    df = df.na.fill("null")
    return df


def json_for_borough(df, col):
    df = preprocess(df)
    df = df.withColumn("check", check_borough(F.col(col)))
    df.createOrReplaceTempView("df")
    temp = spark.sql("select check, count(*) as ctr from df group by check")
    ls = []
    for row in temp.rdd.collect():
        if row.check=="0":
            ls.append(("Other", row.ctr))
        else:
            ls.append((row.check, row.ctr))
    return {"semantic_type":checkType(col), "count":ls}

# %%
bor1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/DYCD_after-school_programs__NDA_Youth_Employment_Programs.tsv")
bor2 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/HIV_Testing_Locations.tsv")

print(json_for_borough(bor1,"BOROUGH / COMMUNITY"))
print(json_for_borough(bor2, "Borough"))
print(json_for_website(bor1, "BOROUGH / COMMUNITY"))
print(json_for_website(bor2, "Borough"))
# Out:
# {'semantic_type': 'Borough', 'count': [('bronx', 25), ('Other', 229), ('manhattan', 19), ('brooklyn', 43), ('queens', 17), ('staten island', 1)]}
# {'semantic_type': 'Borough', 'count': [('bronx', 143), ('Other', 79), ('manhattan', 156), ('brooklyn', 136), ('queens', 58), ('staten island', 27)]}
# {'semantic_type': 'Borough', 'count': [('Other', 334)]}
# {'semantic_type': 'Borough', 'count': [('Other', 599)]}

# %%
# temp = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Charges.tsv")
temp = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2003_Campaign_Contributions.tsv")

# %%
print(temp.columns)
# temp.filter(temp.City == "BROOKLYN").select("ELECTION", "COMMITTEE").show()
# temp.select("ELECTION", "City").distinct().show(1000,truncate=False)
# Out:
# ['ELECTION', 'OFFICECD', 'CANDID', 'CANCLASS', 'CANDLAST', 'CANDFIRST', 'CANDMI', 'COMMITTEE', 'FILING', 'SCHEDULE', 'PAGENO', 'SEQUENCENO', 'REFNO', 'DATE', 'REFUNDDATE', 'NAME', 'C_CODE', 'STRNO', 'STRNAME', 'APARTMENT', 'BOROUGH', 'City', 'State', 'Postcode', 'OCCUPATION', 'EMPNAME', 'EMPSTRNO', 'EMPSTRNAME', 'AMNT', 'MATCHAMNT', 'PREVAMNT', 'PAY_METHOD', 'INTERMNO', 'INTERMNAME', 'INTSTRNO', 'INTSTRNM', 'INTAPTNO', 'INTST', 'INTZIP', 'INTEMPNAME', 'INTEMPSTNO', 'INTEMPSTNM', 'INTEMPCITY', 'INTEMPST', 'INTOCCUPA', 'PURPOSECD', 'EXEMPTCD', 'ADJTYPECD', 'RR_IND', 'SEG_IND', 'INT_C_CODE', 'Latitude', 'Longitude', 'Community Board', 'Community Council ', 'Census Tract', 'BIN', 'BBL', 'NTA', 'EMPCITY', 'EMPSTATE', 'INTCITY']

# %%
# Code for City checking. RUN THIS AND READ A FILE AND CALL json_for_city(dataframe, original_col_name)

def check_city(word):
    word = word.lower()
    if word in ["manhattan", "brooklyn", "bronx", "staten island", "queens"]:
        return "City"
    else:
        return "Other"

check_city = F.udf(check_city, StringType())

def preprocess(df):
    df = df.na.fill("null")
    return df


def json_for_city(df, col):
    df = preprocess(df)
    df = df.withColumn("check", check_city(F.col(col)))
    df.createOrReplaceTempView("df")
    temp = spark.sql("select check, count(*) as ctr from df group by check")
    ls = []
    for row in temp.rdd.collect():
        if row.check=="0":
            ls.append(("Other", row.ctr))
        else:
            ls.append((row.check, row.ctr))
    return {"semantic_type":checkType(col), "count":ls}

# %%
temp = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2003_Campaign_Contributions.tsv")
print(json_for_city(temp,"City"))
# Out:
# {'semantic_type': 'City agency', 'count': [('Other', 14638), ('City', 20173)]}

# %% [markdown]
# # Graphing the JSON

# %%
import json
with open('2003_Campaign_Contributions.tsv.json') as f:
  data = json.load(f)
# Output: {'name': 'Bob', 'languages': ['English', 'Fench']}
# print(data)
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "columns": [
#         {
#             "column_name": "ELECTION",
#             "dataTypes": [
#                 {
#                     "count": 34811,
#                     "max_val": 2003,
#                     "mean": 2003,
#                     "min_val": 2003,
#                     "std_dev": 0.0,
#                     "type": "Integer"
#                 }
#             ],
#             "frequent_values": [
#                 "2003"
#             ],
#             "number_distinct_values": 1,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "OFFICECD",
#             "dataTypes": [
#                 {
#                     "count": 34811,
#                     "max_val": 6,
#                     "mean": 5.000775616902703,
#                     "min_val": 5,
#                     "std_dev": 0.027839496857537997,
#                     "type": "Integer"
#                 }
#             ],
#             "frequent_values": [
#                 "5",
#                 "6"
#             ],
#             "number_distinct_values": 2,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "CANDID",
#             "dataTypes": [
#                 {
#                     "count": 25080,
#                     "max_val": 794,
#                     "mean": 458.867663476874,
#                     "min_val": 51,
#                     "std_dev": 197.7907785112357,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 2.0,
#                     "count": 9731,
#                     "longest_values": [
#                         "AI",
#                         "BH",
#                         "BW",
#                         "C8",
#                         "CB"
#                     ],
#                     "shortest_values": [
#                         "AI",
#                         "BH",
#                         "BW",
#                         "C8",
#                         "CB"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "418",
#                 "232",
#                 "271",
#                 "767",
#                 "MJ"
#             ],
#             "number_distinct_values": 107,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "CANCLASS",
#             "dataTypes": [
#                 {
#                     "average_length": 1.0007756169027031,
#                     "count": 34811,
#                     "longest_values": [
#                         "NP",
#                         "P"
#                     ],
#                     "shortest_values": [
#                         "P",
#                         "NP"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "P",
#                 "NP"
#             ],
#             "number_distinct_values": 2,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "CANDLAST",
#             "dataTypes": [
#                 {
#                     "average_length": 6.72632213955359,
#                     "count": 34811,
#                     "longest_values": [
#                         "Cooper-Gregory",
#                         "Alamo-Estrada",
#                         "Betancourt Jr",
#                         "Mark-Viverito",
#                         "Younger-Nolan"
#                     ],
#                     "shortest_values": [
#                         "Cox",
#                         "Liu",
#                         "Baez",
#                         "Kann",
#                         "Katz"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "Martinez",
#                 "Gioia",
#                 "Weprin",
#                 "McMahon",
#                 "Palma"
#             ],
#             "number_distinct_values": 102,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "CANDFIRST",
#             "dataTypes": [
#                 {
#                     "average_length": 5.863721237539858,
#                     "count": 34811,
#                     "longest_values": [
#                         "Helen Diane",
#                         "A. Gifford",
#                         "Pasqualino",
#                         "Christine",
#                         "G. Oliver"
#                     ],
#                     "shortest_values": [
#                         "Eva",
#                         "Jay",
#                         "Alan",
#                         "Bill",
#                         "Eric"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "David",
#                 "James",
#                 "Michael",
#                 "Bill",
#                 "Eric"
#             ],
#             "number_distinct_values": 91,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "CANDMI",
#             "dataTypes": [
#                 {
#                     "average_length": 2.3600011490620783,
#                     "count": 34811,
#                     "longest_values": [
#                         "None",
#                         "A",
#                         "B",
#                         "C",
#                         "D"
#                     ],
#                     "shortest_values": [
#                         "A",
#                         "B",
#                         "C",
#                         "D",
#                         "E"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "A",
#                 "M",
#                 "J",
#                 "E"
#             ],
#             "number_distinct_values": 19,
#             "number_empty_cells": 15781,
#             "number_non_empty_cells": 19030
#         },
#         {
#             "column_name": "COMMITTEE",
#             "dataTypes": [
#                 {
#                     "average_length": 1.0,
#                     "count": 34811,
#                     "longest_values": [
#                         "H",
#                         "I",
#                         "J",
#                         "K",
#                         "L"
#                     ],
#                     "shortest_values": [
#                         "H",
#                         "I",
#                         "J",
#                         "K",
#                         "L"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "I",
#                 "H",
#                 "J",
#                 "L",
#                 "K"
#             ],
#             "number_distinct_values": 5,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "FILING",
#             "dataTypes": [
#                 {
#                     "count": 34811,
#                     "max_val": 11,
#                     "mean": 4.950733963402373,
#                     "min_val": 1,
#                     "std_dev": 2.4816274554324846,
#                     "type": "Integer"
#                 }
#             ],
#             "frequent_values": [
#                 "4",
#                 "2",
#                 "5",
#                 "10",
#                 "9"
#             ],
#             "number_distinct_values": 11,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "SCHEDULE",
#             "dataTypes": [
#                 {
#                     "average_length": 2.969492401827009,
#                     "count": 34811,
#                     "longest_values": [
#                         "ABC",
#                         "D",
#                         "M",
#                         "N"
#                     ],
#                     "shortest_values": [
#                         "D",
#                         "M",
#                         "N",
#                         "ABC"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "ABC",
#                 "M",
#                 "D",
#                 "N"
#             ],
#             "number_distinct_values": 4,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "PAGENO",
#             "dataTypes": [
#                 {
#                     "average_length": 4.0,
#                     "count": 34811,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None"
#             ],
#             "number_distinct_values": 1,
#             "number_empty_cells": 34811,
#             "number_non_empty_cells": 0
#         },
#         {
#             "column_name": "SEQUENCENO",
#             "dataTypes": [
#                 {
#                     "average_length": 4.0,
#                     "count": 34811,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None"
#             ],
#             "number_distinct_values": 1,
#             "number_empty_cells": 34811,
#             "number_non_empty_cells": 0
#         },
#         {
#             "column_name": "REFNO",
#             "dataTypes": [
#                 {
#                     "average_length": 8.0,
#                     "count": 34811,
#                     "longest_values": [
#                         "R0000003",
#                         "R0000004",
#                         "R0000005",
#                         "R0000006",
#                         "R0000007"
#                     ],
#                     "shortest_values": [
#                         "R0000003",
#                         "R0000004",
#                         "R0000005",
#                         "R0000006",
#                         "R0000007"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "R0000672",
#                 "R0000731",
#                 "R0000676",
#                 "R0000113",
#                 "R0000699"
#             ],
#             "number_distinct_values": 2935,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "DATE",
#             "dataTypes": [
#                 {
#                     "average_length": 4.0,
#                     "count": 36,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 34775,
#                     "max_value": "2004-01-11 00:00:00",
#                     "min_value": "2000-12-12 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "7/10/2003 0:00",
#                 "3/6/2003 0:00",
#                 "7/11/2003 0:00",
#                 "10/30/2003 0:00",
#                 "8/25/2003 0:00"
#             ],
#             "number_distinct_values": 708,
#             "number_empty_cells": 36,
#             "number_non_empty_cells": 34775
#         },
#         {
#             "column_name": "REFUNDDATE",
#             "dataTypes": [
#                 {
#                     "average_length": 4.0,
#                     "count": 34513,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 298,
#                     "max_value": "2003-12-26 00:00:00",
#                     "min_value": "2002-01-11 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "8/8/2003 0:00",
#                 "1/11/2003 0:00",
#                 "9/16/2003 0:00",
#                 "10/28/2003 0:00"
#             ],
#             "number_distinct_values": 132,
#             "number_empty_cells": 34513,
#             "number_non_empty_cells": 298
#         },
#         {
#             "column_name": "NAME",
#             "dataTypes": [
#                 {
#                     "average_length": 15.893453218810146,
#                     "count": 34811,
#                     "longest_values": [
#                         "Diamonstein-Spielvogel, Barbaralee",
#                         "Hernandez de Trujillo, Angelica",
#                         "MONTGOMERY-KENDRICKS, REV. MARY",
#                         "NONNENMACHER, D.M.D., FRANCIS V",
#                         "REILLY & COLLUM, PHILIP& MAGGIE"
#                     ],
#                     "shortest_values": [
#                         "OSA",
#                         "PBA",
#                         "UFT",
#                         "32BJ",
#                         "HOWE"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "RWDSU LOCAL 338",
#                 "UNITED FEDERATION OF TEACHERS",
#                 "PANAGIOTOPOULOS, VASOS",
#                 "WAGNER, CLAUDIA",
#                 "KATZ 2003"
#             ],
#             "number_distinct_values": 26716,
#             "number_empty_cells": 0,
#             "number_non_empty_cells": 34811
#         },
#         {
#             "column_name": "C_CODE",
#             "dataTypes": [
#                 {
#                     "average_length": 3.1253913992703457,
#                     "count": 34811,
#                     "longest_values": [
#                         "PCOMC",
#                         "PCOMP",
#                         "PCOMZ",
#                         "CORP",
#                         "EMPO"
#                     ],
#                     "shortest_values": [
#                         "CAN",
#                         "FAM",
#                         "IND",
#                         "LLC",
#                         "SPO"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "IND",
#                 "PCOMP",
#                 "EMPO",
#                 "OTHR",
#                 "PART"
#             ],
#             "number_distinct_values": 13,
#             "number_empty_cells": 1,
#             "number_non_empty_cells": 34810
#         },
#         {
#             "column_name": "STRNO",
#             "dataTypes": [
#                 {
#                     "count": 2465,
#                     "max_val": 215048,
#                     "mean": 854.7602434077079,
#                     "min_val": 1,
#                     "std_dev": 6255.871303240219,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.013279141199466,
#                     "count": 32231,
#                     "longest_values": [
#                         "331-337",
#                         "358/360",
#                         "36-22 A",
#                         "520-525",
#                         "629-639"
#                     ],
#                     "shortest_values": [
#                         "9B",
#                         "ONE",
#                         "One",
#                         "18 E",
#                         "21 E"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 115,
#                     "max_value": "2062-07-03 00:00:00",
#                     "min_value": "0104-04-03 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "125",
#                 "123",
#                 "16",
#                 "25"
#             ],
#             "number_distinct_values": 556,
#             "number_empty_cells": 31839,
#             "number_non_empty_cells": 2972
#         },
#         {
#             "column_name": "STRNAME",
#             "dataTypes": [
#                 {
#                     "count": 1,
#                     "max_val": 16,
#                     "mean": 16,
#                     "min_val": 16,
#                     "std_dev": "Cannot compute variance with only one datapoint",
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.787204690463873,
#                     "count": 34794,
#                     "longest_values": [
#                         "ADAM CLAYTON POWELL JR BOULEVARD",
#                         "HORACE HARDING EXPY POBOX 650454",
#                         "P.O. BOX 618 HAMILTON GRANGE STA",
#                         "WESTCH. AVE.CHERYL L. FOSTERTREA",
#                         "PO BOX - MANHATTANVILLE STATION"
#                     ],
#                     "shortest_values": [
#                         "3 AV",
#                         "BDWY",
#                         "E 42",
#                         "East",
#                         "None"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 16,
#                     "max_value": "2063-12-03 00:00:00",
#                     "min_value": "0149-12-03 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "BROADWAY",
#                 "Broadway",
#                 "BARCLAY STREET",
#                 "WILLIAM STREET"
#             ],
#             "number_distinct_values": 1014,
#             "number_empty_cells": 31748,
#             "number_non_empty_cells": 3063
#         },
#         {
#             "column_name": "APARTMENT",
#             "dataTypes": [
#                 {
#                     "count": 262,
#                     "max_val": 13000,
#                     "mean": 698.5229007633587,
#                     "min_val": -1650,
#                     "std_dev": 1322.1634328447094,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 3.9995939675174013,
#                     "count": 34480,
#                     "longest_values": [
#                         "10 FL",
#                         "11 FL",
#                         "13 FL",
#                         "14 FL",
#                         "14 Fl"
#                     ],
#                     "shortest_values": [
#                         "1B",
#                         "1R",
#                         "2C",
#                         "2G",
#                         "2L"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 69,
#                     "max_value": "2045-12-03 00:00:00",
#                     "min_value": "2019-12-01 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "401",
#                 "201",
#                 "707",
#                 "4 FL"
#             ],
#             "number_distinct_values": 187,
#             "number_empty_cells": 34290,
#             "number_non_empty_cells": 521
#         },
#         {
#             "column_name": "BOROUGH",
#             "dataTypes": [
#                 {
#                     "average_length": 1.0282669271207376,
#                     "count": 34811,
#                     "longest_values": [
#                         "None",
#                         "K",
#                         "M",
#                         "Q",
#                         "S"
#                     ],
#                     "shortest_values": [
#                         "K",
#                         "M",
#                         "Q",
#                         "S",
#                         "X"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "M",
#                 "K",
#                 "Q",
#                 "X",
#                 "Z"
#             ],
#             "number_distinct_values": 7,
#             "number_empty_cells": 328,
#             "number_non_empty_cells": 34483
#         },
#         {
#             "column_name": "City",
#             "dataTypes": [
#                 {
#                     "average_length": 7.80816408606475,
#                     "count": 34811,
#                     "longest_values": [
#                         "ADDISLEIGH PARK",
#                         "ATLANTIC HIGHLA",
#                         "BEDFORD CORNERS",
#                         "BEDFOTD CORNERS",
#                         "BELLEROSE MANOR"
#                     ],
#                     "shortest_values": [
#                         "K",
#                         "AB",
#                         "BX",
#                         "GN",
#                         "LA"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "NEW YORK",
#                 "BROOKLYN",
#                 "QUEENS",
#                 "BRONX",
#                 "Brooklyn"
#             ],
#             "number_distinct_values": 1226,
#             "number_empty_cells": 292,
#             "number_non_empty_cells": 34519
#         },
#         {
#             "column_name": "State",
#             "dataTypes": [
#                 {
#                     "average_length": 2.0162305018528626,
#                     "count": 34811,
#                     "longest_values": [
#                         "Brooklyn",
#                         "None",
#                         "AK",
#                         "AL",
#                         "AR"
#                     ],
#                     "shortest_values": [
#                         "Y",
#                         "AK",
#                         "AL",
#                         "AR",
#                         "AZ"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "NY",
#                 "NJ",
#                 "None",
#                 "DC",
#                 "CT"
#             ],
#             "number_distinct_values": 45,
#             "number_empty_cells": 280,
#             "number_non_empty_cells": 34531
#         },
#         {
#             "column_name": "Postcode",
#             "dataTypes": [
#                 {
#                     "count": 34234,
#                     "max_val": 99708,
#                     "mean": 11049.350996085763,
#                     "min_val": 731,
#                     "std_dev": 4352.275401871285,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 3.996533795493934,
#                     "count": 577,
#                     "longest_values": [
#                         "None",
#                         "NY"
#                     ],
#                     "shortest_values": [
#                         "NY",
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "10021",
#                 "10025",
#                 "None",
#                 "11201",
#                 "11215"
#             ],
#             "number_distinct_values": 1073,
#             "number_empty_cells": 576,
#             "number_non_empty_cells": 34235
#         },
#         {
#             "column_name": "OCCUPATION",
#             "dataTypes": [
#                 {
#                     "average_length": 9.015713423917727,
#                     "count": 34811,
#                     "longest_values": [
#                         "ADMINISTRATOR AND MEETING PLAN",
#                         "ADMINISTRATOR REAL PROPERTY MA",
#                         "ADULT LITERACY STAFF DEVELOPER",
#                         "ASS'T DIR- OFF OF STUDENT SER.",
#                         "ASSIS GEN MANAGER, QUEENS BORO"
#                     ],
#                     "shortest_values": [
#                         "-",
#                         "?",
#                         "??",
#                         "AP",
#                         "BA"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "RETIRED",
#                 "ATTORNEY",
#                 "HOMEMAKER",
#                 "TEACHER"
#             ],
#             "number_distinct_values": 4869,
#             "number_empty_cells": 8702,
#             "number_non_empty_cells": 26109
#         },
#         {
#             "column_name": "EMPNAME",
#             "dataTypes": [
#                 {
#                     "count": 89,
#                     "max_val": 1199,
#                     "mean": 1186.8651685393259,
#                     "min_val": 119,
#                     "std_dev": 114.47977104068688,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 11.809112378319222,
#                     "count": 34722,
#                     "longest_values": [
#                         ",86-11,101ST AVENUE,QUEENS,NY,65.00,0,0,2,,,,,,,,,,,,,,,,,,N,N,",
#                         "1199 SEIU HOME CARE EMPLOYEE F",
#                         "1199 SEIU TRAINING AND UPGRADI",
#                         "1332 FULTON AVENUE DAY CARE CE",
#                         "217 Street St. Ann's Food Corp"
#                     ],
#                     "shortest_values": [
#                         "-",
#                         "5W",
#                         "BA",
#                         "FB",
#                         "NA"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "SELF EMPLOYED",
#                 "RETIRED",
#                 "SELF-EMPLOYED",
#                 "SELF"
#             ],
#             "number_distinct_values": 10651,
#             "number_empty_cells": 13575,
#             "number_non_empty_cells": 21236
#         },
#         {
#             "column_name": "EMPSTRNO",
#             "dataTypes": [
#                 {
#                     "count": 13884,
#                     "max_val": 71444,
#                     "mean": 823.008571016998,
#                     "min_val": 1,
#                     "std_dev": 1652.6655874378148,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.110149799772581,
#                     "count": 20227,
#                     "longest_values": [
#                         "NYC Police Department",
#                         "125 WORH",
#                         "125 WORT",
#                         "164-01 B",
#                         "1655-200"
#                     ],
#                     "shortest_values": [
#                         "-",
#                         "I",
#                         "X",
#                         "#5",
#                         "5O"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 700,
#                     "max_value": "2068-02-03 00:00:00",
#                     "min_value": "0100-04-03 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "1",
#                 "250",
#                 "310",
#                 "2"
#             ],
#             "number_distinct_values": 3051,
#             "number_empty_cells": 18335,
#             "number_non_empty_cells": 16476
#         },
#         {
#             "column_name": "EMPSTRNAME",
#             "dataTypes": [
#                 {
#                     "count": 42,
#                     "max_val": 720128,
#                     "mean": 106257.69047619047,
#                     "min_val": 28,
#                     "std_dev": 228840.70714923163,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 8.243000634993939,
#                     "count": 34646,
#                     "longest_values": [
#                         "181 ST. STREET, UNIVERSITY AVENU",
#                         "E 81 ST APT 2B - WORKS FROM HOME",
#                         "JACOBI HOSPITAL - PELHAM PARKWAY",
#                         "P.O. BOX 1259 MADISON SQUARE ST.",
#                         "P.O. Box 143  Kensington Station"
#                     ],
#                     "shortest_values": [
#                         "-",
#                         "AUS",
#                         "BQE",
#                         "CPS",
#                         "HSC"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 123,
#                     "max_value": "2063-12-03 00:00:00",
#                     "min_value": "0104-12-03 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "BROADWAY",
#                 "PARK AVENUE",
#                 "Broadway",
#                 "MADISON AVENUE"
#             ],
#             "number_distinct_values": 5208,
#             "number_empty_cells": 17949,
#             "number_non_empty_cells": 16862
#         },
#         {
#             "column_name": "AMNT",
#             "dataTypes": [
#                 {
#                     "count": 34809,
#                     "max_val": 8000,
#                     "mean": 186.45284265563504,
#                     "min_val": -5204,
#                     "std_dev": 361.264174617918,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 2,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "100",
#                 "250",
#                 "50",
#                 "25",
#                 "10"
#             ],
#             "number_distinct_values": 281,
#             "number_empty_cells": 2,
#             "number_non_empty_cells": 34809
#         },
#         {
#             "column_name": "MATCHAMNT",
#             "dataTypes": [
#                 {
#                     "count": 34810,
#                     "max_val": 250,
#                     "mean": 67.72516518241885,
#                     "min_val": 0,
#                     "std_dev": 83.8930239212272,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 1,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "0",
#                 "250",
#                 "100",
#                 "50",
#                 "25"
#             ],
#             "number_distinct_values": 105,
#             "number_empty_cells": 1,
#             "number_non_empty_cells": 34810
#         },
#         {
#             "column_name": "PREVAMNT",
#             "dataTypes": [
#                 {
#                     "count": 34810,
#                     "max_val": 4310,
#                     "mean": 33.7283251939098,
#                     "min_val": 0,
#                     "std_dev": 154.7427952918792,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 1,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "0",
#                 "100",
#                 "250",
#                 "50",
#                 "500"
#             ],
#             "number_distinct_values": 183,
#             "number_empty_cells": 1,
#             "number_non_empty_cells": 34810
#         },
#         {
#             "column_name": "PAY_METHOD",
#             "dataTypes": [
#                 {
#                     "count": 34810,
#                     "max_val": 5,
#                     "mean": 1.8661878770468256,
#                     "min_val": 0,
#                     "std_dev": 0.6759112926095776,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 1,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "2",
#                 "1",
#                 "5",
#                 "0",
#                 "4"
#             ],
#             "number_distinct_values": 7,
#             "number_empty_cells": 1,
#             "number_non_empty_cells": 34810
#         },
#         {
#             "column_name": "INTERMNO",
#             "dataTypes": [
#                 {
#                     "count": 1029,
#                     "max_val": 456,
#                     "mean": 19.782312925170068,
#                     "min_val": 1,
#                     "std_dev": 49.82078034102981,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 33782,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "1",
#                 "2",
#                 "7",
#                 "5"
#             ],
#             "number_distinct_values": 27,
#             "number_empty_cells": 33782,
#             "number_non_empty_cells": 1029
#         },
#         {
#             "column_name": "INTERMNAME",
#             "dataTypes": [
#                 {
#                     "average_length": 4.320617046335928,
#                     "count": 34811,
#                     "longest_values": [
#                         "PARKSIDE PUBLIC AFFAIRS LLC",
#                         "MONTVEL-COHEN, THOMAS A",
#                         "SCHLOEGEL HYNES, HEIDI",
#                         "VECONI, GILBERT, JR. J",
#                         "BANK, KAREN & JEFFREY"
#                     ],
#                     "shortest_values": [
#                         "None",
#                         "CHIN, YUIEN",
#                         "FINE, PETER",
#                         "LEWIS, AURY",
#                         "Matos, Rose"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "HOCHBERG, FRED",
#                 "Perez II, Radame",
#                 "ROSARIO, ANTONIO",
#                 "RICCI, FRANK"
#             ],
#             "number_distinct_values": 109,
#             "number_empty_cells": 33783,
#             "number_non_empty_cells": 1028
#         },
#         {
#             "column_name": "INTSTRNO",
#             "dataTypes": [
#                 {
#                     "count": 30,
#                     "max_val": 74,
#                     "mean": 13.333333333333334,
#                     "min_val": 9,
#                     "std_dev": 16.49102856066006,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.000028751329749,
#                     "count": 34781,
#                     "longest_values": [
#                         "19-02",
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None",
#                         "19-02"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "9",
#                 "74",
#                 "19-02"
#             ],
#             "number_distinct_values": 4,
#             "number_empty_cells": 34780,
#             "number_non_empty_cells": 31
#         },
#         {
#             "column_name": "INTSTRNM",
#             "dataTypes": [
#                 {
#                     "average_length": 4.011461894228836,
#                     "count": 34811,
#                     "longest_values": [
#                         "WHITESTONE EXPRESSWAY",
#                         "EAST 40TH. STREET",
#                         "TRINITY PLACE",
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None",
#                         "TRINITY PLACE",
#                         "EAST 40TH. STREET",
#                         "WHITESTONE EXPRESSWAY"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "EAST 40TH. STREET",
#                 "TRINITY PLACE",
#                 "WHITESTONE EXPRESSWAY"
#             ],
#             "number_distinct_values": 4,
#             "number_empty_cells": 34780,
#             "number_non_empty_cells": 31
#         },
#         {
#             "column_name": "INTAPTNO",
#             "dataTypes": [
#                 {
#                     "count": 2,
#                     "max_val": 1200,
#                     "mean": 1200,
#                     "min_val": 1200,
#                     "std_dev": 0.0,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 34809,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "1200"
#             ],
#             "number_distinct_values": 2,
#             "number_empty_cells": 34809,
#             "number_non_empty_cells": 2
#         },
#         {
#             "column_name": "INTST",
#             "dataTypes": [
#                 {
#                     "average_length": 3.942776708511677,
#                     "count": 34811,
#                     "longest_values": [
#                         "None",
#                         "CA",
#                         "CT",
#                         "DC",
#                         "NJ"
#                     ],
#                     "shortest_values": [
#                         "CA",
#                         "CT",
#                         "DC",
#                         "NJ",
#                         "NY"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "NY",
#                 "CT",
#                 "NJ",
#                 "CA"
#             ],
#             "number_distinct_values": 6,
#             "number_empty_cells": 33815,
#             "number_non_empty_cells": 996
#         },
#         {
#             "column_name": "INTZIP",
#             "dataTypes": [
#                 {
#                     "count": 985,
#                     "max_val": 94115,
#                     "mean": 10961.496446700508,
#                     "min_val": 6851,
#                     "std_dev": 6590.335917872779,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 33826,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "10011",
#                 "10469",
#                 "10025",
#                 "10468"
#             ],
#             "number_distinct_values": 69,
#             "number_empty_cells": 33826,
#             "number_non_empty_cells": 985
#         },
#         {
#             "column_name": "INTEMPNAME",
#             "dataTypes": [
#                 {
#                     "average_length": 4.395306081411048,
#                     "count": 34811,
#                     "longest_values": [
#                         "CITIZENS' COMMITTEE FOR CHILDR",
#                         "EAST NEW YORK URBAN YOUTH CORP",
#                         "Jeffrey A Sachs Associates, In",
#                         "Kantor, Davidoff, Wolfe, Mande",
#                         "PAUL WEISS,RIFKIND,WARTON&CARR"
#                     ],
#                     "shortest_values": [
#                         "N/A",
#                         "RSA",
#                         "n/a",
#                         "None",
#                         "NILICO"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "HEYDEY CONMPANY",
#                 "Mastermind Management, LTD",
#                 "1199 SEIU",
#                 "CONSOLIDATED EDISON COMPANY"
#             ],
#             "number_distinct_values": 87,
#             "number_empty_cells": 33881,
#             "number_non_empty_cells": 930
#         },
#         {
#             "column_name": "INTEMPSTNO",
#             "dataTypes": [
#                 {
#                     "count": 802,
#                     "max_val": 4802,
#                     "mean": 510.8827930174564,
#                     "min_val": 1,
#                     "std_dev": 711.4859141056245,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.002264839108183,
#                     "count": 33998,
#                     "longest_values": [
#                         "BUILDING",
#                         "23-10",
#                         "30-17",
#                         "39-20",
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None",
#                         "23-10",
#                         "30-17",
#                         "39-20",
#                         "BUILDING"
#                     ],
#                     "type": "Text"
#                 },
#                 {
#                     "count": 11,
#                     "max_value": "2003-05-03 00:00:00",
#                     "min_value": "0172-12-03 00:00:00",
#                     "type": "Date/Time"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "101",
#                 "668",
#                 "123",
#                 "310"
#             ],
#             "number_distinct_values": 67,
#             "number_empty_cells": 33951,
#             "number_non_empty_cells": 860
#         },
#         {
#             "column_name": "INTEMPSTNM",
#             "dataTypes": [
#                 {
#                     "average_length": 4.2287208066415785,
#                     "count": 34811,
#                     "longest_values": [
#                         "QUENTIN-ROOSEVELT BLVD.",
#                         "266 BROOKLYN NAVY YARD",
#                         "Avenue of the Americas",
#                         "CHASE METROTECH CENTER",
#                         "Coney Island Avenue"
#                     ],
#                     "shortest_values": [
#                         "None",
#                         "AVE V",
#                         "7th av",
#                         "E 42 ST",
#                         "JOHN ST"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "FIFTH AVENUE",
#                 "Crescent Ave.",
#                 "FLATBUSH AVENUE",
#                 "BROADWAY"
#             ],
#             "number_distinct_values": 74,
#             "number_empty_cells": 33951,
#             "number_non_empty_cells": 860
#         },
#         {
#             "column_name": "INTEMPCITY",
#             "dataTypes": [
#                 {
#                     "average_length": 4.089195943810864,
#                     "count": 34811,
#                     "longest_values": [
#                         "STATEN ISLAND",
#                         "STONEY BROOK",
#                         "GARDEN CITY",
#                         "MAMARONECK",
#                         "BROOKLYN"
#                     ],
#                     "shortest_values": [
#                         "NY",
#                         "None",
#                         "BRONX",
#                         "Bronx",
#                         "QUEENS"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "NEW YORK",
#                 "BROOKLYN",
#                 "New York",
#                 "BRONX"
#             ],
#             "number_distinct_values": 13,
#             "number_empty_cells": 33897,
#             "number_non_empty_cells": 914
#         },
#         {
#             "column_name": "INTEMPST",
#             "dataTypes": [
#                 {
#                     "average_length": 3.9470856913044727,
#                     "count": 34811,
#                     "longest_values": [
#                         "None",
#                         "NJ",
#                         "NY"
#                     ],
#                     "shortest_values": [
#                         "NJ",
#                         "NY",
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "NY",
#                 "NJ"
#             ],
#             "number_distinct_values": 3,
#             "number_empty_cells": 33890,
#             "number_non_empty_cells": 921
#         },
#         {
#             "column_name": "INTOCCUPA",
#             "dataTypes": [
#                 {
#                     "average_length": 4.237712217402545,
#                     "count": 34811,
#                     "longest_values": [
#                         "SENIOR CONGRESSIONAL ASSISTANT",
#                         "SR. GOV'T RELATIONS SPECIALIST",
#                         "DIRECTOR OF CORPORATE AFFAIRS",
#                         "DIRECTOR GOVERNMENT AFFAIRS",
#                         "Gov't Affairs Professional"
#                     ],
#                     "shortest_values": [
#                         "CEO",
#                         "None",
#                         "ADMIN",
#                         "CLERK",
#                         "OWNER"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "CEO",
#                 "Executive Vice President",
#                 "ATTORNEY",
#                 "EXECUTIVE DIRECTOR"
#             ],
#             "number_distinct_values": 66,
#             "number_empty_cells": 33877,
#             "number_non_empty_cells": 934
#         },
#         {
#             "column_name": "PURPOSECD",
#             "dataTypes": [
#                 {
#                     "average_length": 4.0056591307345375,
#                     "count": 34811,
# ...
#                         "C",
#                         "P",
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "C",
#                 "P"
#             ],
#             "number_distinct_values": 3,
#             "number_empty_cells": 34782,
#             "number_non_empty_cells": 29
#         },
#         {
#             "column_name": "ADJTYPECD",
#             "dataTypes": [
#                 {
#                     "count": 298,
#                     "max_val": 5,
#                     "mean": 2.0167785234899327,
#                     "min_val": 1,
#                     "std_dev": 1.036239165129679,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 34513,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "2",
#                 "1",
#                 "5"
#             ],
#             "number_distinct_values": 4,
#             "number_empty_cells": 34513,
#             "number_non_empty_cells": 298
#         },
#         {
#             "column_name": "RR_IND",
#             "dataTypes": [
#                 {
#                     "average_length": 1.0001723593117118,
#                     "count": 34811,
#                     "longest_values": [
#                         "None",
#                         "N"
#                     ],
#                     "shortest_values": [
#                         "N",
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "N",
#                 "None"
#             ],
#             "number_distinct_values": 2,
#             "number_empty_cells": 2,
#             "number_non_empty_cells": 34809
#         },
#         {
#             "column_name": "SEG_IND",
#             "dataTypes": [
#                 {
#                     "average_length": 1.0170635718594696,
#                     "count": 34811,
#                     "longest_values": [
#                         "None",
#                         "N"
#                     ],
#                     "shortest_values": [
#                         "N",
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "N",
#                 "None"
#             ],
#             "number_distinct_values": 2,
#             "number_empty_cells": 198,
#             "number_non_empty_cells": 34613
#         },
#         {
#             "column_name": "INT_C_CODE",
#             "dataTypes": [
#                 {
#                     "average_length": 3.971244721496079,
#                     "count": 34811,
#                     "longest_values": [
#                         "CORP",
#                         "None",
#                         "OTHR",
#                         "FAM",
#                         "IND"
#                     ],
#                     "shortest_values": [
#                         "N",
#                         "FAM",
#                         "IND",
#                         "LLC",
#                         "CORP"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "IND",
#                 "OTHR",
#                 "FAM",
#                 "CORP"
#             ],
#             "number_distinct_values": 7,
#             "number_empty_cells": 33782,
#             "number_non_empty_cells": 1029
#         },
#         {
#             "column_name": "Latitude",
#             "dataTypes": [
#                 {
#                     "count": 2344,
#                     "max_val": 40.907312,
#                     "mean": 40.73712678284983,
#                     "min_val": 40.577538,
#                     "std_dev": 0.04579954734482907,
#                     "type": "Real"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 32467,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "40.714181",
#                 "40.709112",
#                 "40.693445",
#                 "40.733043"
#             ],
#             "number_distinct_values": 502,
#             "number_empty_cells": 32467,
#             "number_non_empty_cells": 2344
#         },
#         {
#             "column_name": "Longitude",
#             "dataTypes": [
#                 {
#                     "count": 2344,
#                     "max_val": -73.708437,
#                     "mean": -73.96107147098976,
#                     "min_val": -74.035439,
#                     "std_dev": 0.0627535963788375,
#                     "type": "Real"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 32467,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "-74.012845",
#                 "-74.006893",
#                 "-73.990577",
#                 "-73.99116"
#             ],
#             "number_distinct_values": 502,
#             "number_empty_cells": 32467,
#             "number_non_empty_cells": 2344
#         },
#         {
#             "column_name": "Community Board",
#             "dataTypes": [
#                 {
#                     "count": 2344,
#                     "max_val": 18,
#                     "mean": 4.322952218430034,
#                     "min_val": 1,
#                     "std_dev": 3.275676676851856,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 32467,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "1",
#                 "5",
#                 "2",
#                 "6"
#             ],
#             "number_distinct_values": 18,
#             "number_empty_cells": 32467,
#             "number_non_empty_cells": 2344
#         },
#         {
#             "column_name": "Community Council ",
#             "dataTypes": [
#                 {
#                     "count": 2344,
#                     "max_val": 48,
#                     "mean": 10.647184300341298,
#                     "min_val": 1,
#                     "std_dev": 12.748983731206458,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 32467,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "1",
#                 "3",
#                 "4",
#                 "2"
#             ],
#             "number_distinct_values": 48,
#             "number_empty_cells": 32467,
#             "number_non_empty_cells": 2344
#         },
#         {
#             "column_name": "Census Tract",
#             "dataTypes": [
#                 {
#                     "count": 2344,
#                     "max_val": 157903,
#                     "mean": 6214.307593856655,
#                     "min_val": 1,
#                     "std_dev": 22020.113418727753,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 32467,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "21",
#                 "1502",
#                 "33",
#                 "9"
#             ],
#             "number_distinct_values": 269,
#             "number_empty_cells": 32467,
#             "number_non_empty_cells": 2344
#         },
#         {
#             "column_name": "BIN",
#             "dataTypes": [
#                 {
#                     "count": 2310,
#                     "max_val": 4617481,
#                     "mean": 1844487.6584415585,
#                     "min_val": 1000000,
#                     "std_dev": 1253568.2237700915,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 32501,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "1001417",
#                 "1079063",
#                 "3002108",
#                 "1024992"
#             ],
#             "number_distinct_values": 487,
#             "number_empty_cells": 32501,
#             "number_non_empty_cells": 2310
#         },
#         {
#             "column_name": "BBL",
#             "dataTypes": [
#                 {
#                     "count": 2310,
#                     "max_val": 4141730075,
#                     "mean": 1797705016.478788,
#                     "min_val": 1000090029,
#                     "std_dev": 1213523647.017527,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 4.0,
#                     "count": 32501,
#                     "longest_values": [
#                         "None"
#                     ],
#                     "shortest_values": [
#                         "None"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "1001280026",
#                 "1000780004",
#                 "3002500044",
#                 "1010350036"
#             ],
#             "number_distinct_values": 490,
#             "number_empty_cells": 32501,
#             "number_non_empty_cells": 2310
#         },
#         {
#             "column_name": "NTA",
#             "dataTypes": [
#                 {
#                     "average_length": 5.456263824653127,
#                     "count": 34811,
#                     "longest_values": [
#                         "DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill",
#                         "Sheepshead Bay-Gerritsen Beach-Manhattan Beach",
#                         "Hudson Yards-Chelsea-Flatiron-Union Square",
#                         "Carroll Gardens-Columbia Street-Red Hook",
#                         "Queensbridge-Ravenswood-Long Island City"
#                     ],
#                     "shortest_values": [
#                         "None",
#                         "Corona",
#                         "Astoria",
#                         "Bedford",
#                         "Belmont"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "SoHo-TriBeCa-Civic Center-Little Italy",
#                 "Battery Park City-Lower Manhattan",
#                 "Midtown-Midtown South",
#                 "Hudson Yards-Chelsea-Flatiron-Union Square"
#             ],
#             "number_distinct_values": 122,
#             "number_empty_cells": 32467,
#             "number_non_empty_cells": 2344
#         },
#         {
#             "column_name": "EMPCITY",
#             "dataTypes": [
#                 {
#                     "average_length": 6.101490908046308,
#                     "count": 34811,
#                     "longest_values": [
#                         "CAMBRIA HEIGHTS",
#                         "Cambria Heights",
#                         "ENGLEWOOD CLIFF",
#                         "ENGLEWOOD CLIFS",
#                         "FRANKLIN SQUARE"
#                     ],
#                     "shortest_values": [
#                         "BX",
#                         "GN",
#                         "NY",
#                         "LIC",
#                         "N Y"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "NEW YORK",
#                 "BROOKLYN",
#                 "New York",
#                 "QUEENS"
#             ],
#             "number_distinct_values": 600,
#             "number_empty_cells": 15743,
#             "number_non_empty_cells": 19068
#         },
#         {
#             "column_name": "EMPSTATE",
#             "dataTypes": [
#                 {
#                     "count": 2,
#                     "max_val": 11,
#                     "mean": 10.5,
#                     "min_val": 10,
#                     "std_dev": 0.7071067811865476,
#                     "type": "Integer"
#                 },
#                 {
#                     "average_length": 2.9042489011462553,
#                     "count": 34809,
#                     "longest_values": [
#                         "Brooklyn",
#                         "None",
#                         "AK",
#                         "AL",
#                         "AZ"
#                     ],
#                     "shortest_values": [
#                         "AK",
#                         "AL",
#                         "AZ",
#                         "BY",
#                         "CA"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "NY",
#                 "None",
#                 "NJ",
#                 "DC",
#                 "CT"
#             ],
#             "number_distinct_values": 40,
#             "number_empty_cells": 15735,
#             "number_non_empty_cells": 19076
#         },
#         {
#             "column_name": "INTCITY",
#             "dataTypes": [
#                 {
#                     "average_length": 4.104306110137601,
#                     "count": 34811,
#                     "longest_values": [
#                         "WASHINGTONVILLE",
#                         "PLEASANTVILLE",
#                         "SAN FRANCISCO",
#                         "STATEN ISLAND",
#                         "WEST NEW YORK"
#                     ],
#                     "shortest_values": [
#                         "Deal",
#                         "None",
#                         "BRONX",
#                         "Bronx",
#                         "QUEENS"
#                     ],
#                     "type": "Text"
#                 }
#             ],
#             "frequent_values": [
#                 "None",
#                 "NEW YORK",
#                 "BROOKLYN",
#                 "BRONX",
#                 "QUEENS"
#             ],
#             "number_distinct_values": 28,
#             "number_empty_cells": 33815,
#             "number_non_empty_cells": 996
#         }
#     ],
#     "dataset_name": "2003_Campaign_Contributions.tsv",
#     "end time": "2019-12-03 12:08:38.916274",
#     "key_column_candidates": [
#         "NAME"
#     ],
#     "start time": "2019-12-03 12:06:40.625857"
# }

# %%
ls = []
for col in data["columns"]:
    l=[]
    for tp in col["dataTypes"]:
        dt = tp["type"]
        l.append(dt)
    ls.append(l)
print(ls)
# Out:
# [['Integer'], ['Integer'], ['Integer', 'Text'], ['Text'], ['Text'], ['Text'], ['Text'], ['Text'], ['Integer'], ['Text'], ['Text'], ['Text'], ['Text'], ['Text', 'Date/Time'], ['Text', 'Date/Time'], ['Text'], ['Text'], ['Integer', 'Text', 'Date/Time'], ['Integer', 'Text', 'Date/Time'], ['Integer', 'Text', 'Date/Time'], ['Text'], ['Text'], ['Text'], ['Integer', 'Text'], ['Text'], ['Integer', 'Text'], ['Integer', 'Text', 'Date/Time'], ['Integer', 'Text', 'Date/Time'], ['Integer', 'Text'], ['Integer', 'Text'], ['Integer', 'Text'], ['Integer', 'Text'], ['Integer', 'Text'], ['Text'], ['Integer', 'Text'], ['Text'], ['Integer', 'Text'], ['Text'], ['Integer', 'Text'], ['Text'], ['Integer', 'Text', 'Date/Time'], ['Text'], ['Text'], ['Text'], ['Text'], ['Text'], ['Text'], ['Integer', 'Text'], ['Text'], ['Text'], ['Text'], ['Real', 'Text'], ['Real', 'Text'], ['Integer', 'Text'], ['Integer', 'Text'], ['Integer', 'Text'], ['Integer', 'Text'], ['Integer', 'Text'], ['Text'], ['Text'], ['Integer', 'Text'], ['Text']]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

def print_frequent_itemsets(jsonfilename):
    with open('2003_Campaign_Contributions.tsv.json') as f:
        data = json.load(f)
    ls = []
    for col in data["columns"]:
        l=[]
        for tp in col["dataTypes"]:
            dt = tp["type"]
            l.append(dt)
        ls.append(l)
        
    te = TransactionEncoder()
    te_ary = te.fit(ls).transform(ls)
    df = pd.DataFrame(te_ary, columns=te.columns_)
    fi = apriori(df, min_support=0.1, use_colnames=True)
    fi['length'] = fi['itemsets'].apply(lambda x: len(x))
    for i in range(2,4):
        print(i,"frequent itemset")
        print("------------------------------------")
        tm = fi[ (fi['length'] == i) & (fi['support'] >= 0.1) ]
        if tm.size==0:
            print("No itemsets present")
        else:
            print(tm["itemsets"].to_string())
        print("------------------------------------\n")
# Out:
# 2 frequent itemset
# ------------------------------------
# 3    (Date/Time, Text)
# 4      (Integer, Text)
# ------------------------------------
#
# 3 frequent itemset
# ------------------------------------
# No itemsets present
# ------------------------------------

# %%
import json


def plot_graph_for_json(jsonfilename):
    with open(jsonfilename) as f:
        data = json.load(f)
    dtct = {}
    for col in data["columns"]:
        for tp in col["dataTypes"]:
            dt = tp["type"]
            if dt not in dtct.keys():
                dtct[dt] = 1
            else:
                dtct[dt] += 1
    filename = jsonfilename.split('.')[0]
    plt.bar(range(len(dtct)), list(dtct.values()), align='center')
    st=0
    for x,y in dtct.items():
        x=st
        label = y
        plt.annotate(label,(x,y),textcoords="offset points",xytext=(0,2),ha='center',weight='bold')
        st+=1
    plt.xticks(range(len(dtct)), list(dtct.keys()))
    plt.title("Histogram for {}".format(filename), weight='bold')
    plt.show()

# %%
plot_graph_for_json("2003_Campaign_Contributions.tsv.json")
print_frequent_itemsets("2003_Campaign_Contributions.tsv.json")
# Out:
# 2 frequent itemset
# ------------------------------------
# 3    (Date/Time, Text)
# 4      (Integer, Text)
# ------------------------------------
#
# 3 frequent itemset
# ------------------------------------
# No itemsets present
# ------------------------------------
