# %%
# useful to have this code snippet to avoid getting an error in case forgeting 
# to close spark

try:
    spark.stop()
except:
    pass

# Using findspark to find automatically the spark folder
# !pip install --user findspark
import findspark
findspark.init()

# import python libraries

# initialize
from pyspark.sql import Row
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.types import StringType
from pyspark.sql.types import DoubleType
from pyspark.sql.types import IntegerType
from pyspark.sql import functions as F
from pyspark.sql import Row

# from pyspark.ml.feature import HashingTF, IDF, RegexTokenizer, StringIndexer, NGram
# from pyspark.ml.classification import LogisticRegression
# from pyspark.ml import Pipeline
# from pyspark.mllib.evaluation import MulticlassMetrics

spark = SparkSession.builder.master("local[*]").getOrCreate()
# num_samples = 100000000

# def inside(p):
#     x, y = random.random(), random.random()
#     return x*x + y*y < 1

# count = spark.sparkContext.parallelize(range(0, num_samples)).filter(inside).count()
# pi = 4 * count / num_samples
# print(pi)
# Out:
# Requirement already satisfied: findspark in /Users/anjan/anaconda3/lib/python3.7/site-packages (1.3.0)

# %%
# !pip install --user pandas 
# !pip install --user matplotlib
# !pip install --user fuzzywuzzy
# !pip install --user jellyfish
import pandas as pd
import matplotlib.pyplot as plt
from fuzzywuzzy import fuzz
from jellyfish import soundex
from jellyfish import levenshtein_distance as ld
import re

# %%
with open('../Downloads/cluster2.txt') as fp:
    data = [line for line in fp]
data = data[0].split(",")
# print(data[1])
for row in data:
    l = row.split(".")
#     print(l[1])
    if l[1]=='First_Name':
        print(l[0],l[1])
# Out:
#  'mdcw-n682 First_Name
#  't8hj-ruu2 First_Name
#  'qu8g-sxqf First_Name

# %%
types = [row.split('.')[1] for row in data]
# print(types)

list_to_match = ["Person name (Last name, First name, Middle name, Full name)","Business name", "Phone Number",
                 "Address", "Street name","City","Neighborhood", "Latitude Longitude", "Zip", "Borough",
                 "School name", "Color", "Car make", "City agency",
                 "Areas of study", "Subjects",
                 "School Levels", "College/University names","Websites",
                 "Building Classification","Vehicle Type",
                 "Type of location"]

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass
 
    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
 
    return False

def process(word):
    word = word.strip()
    lsword = word.split('_')
#     print(lsword)
    wr = ""
    for w in lsword:
        if is_number(w):
#             print("It comes",w)
            continue
        wr += w
#     print(lsword)
#     print("This",wr)
#     word = ''.join(ls)
#     word = word.replace('_', "")
#     re.sub('\\d', "", word)
    return wr.lower()


# word = "CORE_COURSE__MS_CORE_and_9_12_ONLY_"
# print(process(word))

for row in types:
#     print(row)
    newrow = process(row)
    ls = []
    for list_name in list_to_match:
        ls.append( (fuzz.partial_ratio(newrow, list_name.lower()), list_name))
#         print(row, fuzz.partial_ratio(row, list_name))
    ls.sort(reverse=True)
#     print(ls)
    print(row," is most likely : ", ls[0][1])
def checkType(row):
    newrow = process(row)
    ls = []
    for list_name in list_to_match:
        ls.append( (fuzz.partial_ratio(newrow, list_name.lower()), list_name))
    ls.sort(reverse=True)
    return ls[0][1]
# Out:
# website  is most likely :  Websites
# BOROUGH___COMMUNITY  is most likely :  Borough
# CORE_SUBJECT  is most likely :  Subjects
# Location  is most likely :  Type of location
# Agency  is most likely :  City agency
# Incident_Zip  is most likely :  Zip
# Phone  is most likely :  Phone Number
# First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Vehicle_Color  is most likely :  Color
# Vehicle_Color  is most likely :  Color
# SCHOOL_LEVEL_  is most likely :  School Levels
# Violation_Location__City_  is most likely :  City
# interest  is most likely :  College/University names
# MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Neighborhood  is most likely :  Neighborhood
# Address_1  is most likely :  Address
# PERSON_FIRST_NAME  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Last_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Owner_Last_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# DBA  is most likely :  Websites
# City  is most likely :  City agency
# AGENCY_NAME  is most likely :  City agency
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# interest1  is most likely :  College/University names
# COMPARABLE_RENTAL___2__Neighborhood  is most likely :  Neighborhood
# SCHOOL_LEVEL_  is most likely :  School Levels
# independentwebsite  is most likely :  Websites
# Location__Lat__Long_  is most likely :  Latitude Longitude
# Agency  is most likely :  City agency
# PRINCIPAL_PHONE_NUMBER  is most likely :  Phone Number
# Borough  is most likely :  Borough
# Borough  is most likely :  Borough
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# BUSINESS_NAME2  is most likely :  Business name
# website  is most likely :  Websites
# Vehicle_Make  is most likely :  Vehicle Type
# CORE_SUBJECT___MS_CORE_and__9_12_ONLY_  is most likely :  Subjects
# Vehicle_Body_Type  is most likely :  Vehicle Type
# address  is most likely :  Address
# Vehicle_Color  is most likely :  Color
# Agency  is most likely :  City agency
# CORE_SUBJECT__MS_CORE_and_9_12_ONLY_  is most likely :  Subjects
# School_Type  is most likely :  School Levels
# Vehicle_Make  is most likely :  Vehicle Type
# Vehicle_Body_Type  is most likely :  Vehicle Type
# COMPARABLE_RENTAL___2__Building_Classification  is most likely :  Building Classification
# interest1  is most likely :  College/University names
# QUEENS_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# SCHOOL_LEVEL_  is most likely :  School Levels
# ZIP  is most likely :  Zip
# Vehicle_Color  is most likely :  Color
# PHONE  is most likely :  Phone Number
# MI  is most likely :  Zip
# PREM_TYP_DESC  is most likely :  Vehicle Type
# SCHOOL  is most likely :  School name
# ADDRESS  is most likely :  Address
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# Owner_s_House_Zip_Code  is most likely :  Zip
# company_phone  is most likely :  Phone Number
# MI  is most likely :  Zip
# VEHICLE_MAKE  is most likely :  Vehicle Type
# SCHOOL_NAME  is most likely :  School name
# BusinessName  is most likely :  Business name
# Location  is most likely :  Type of location
# CORE_SUBJECT  is most likely :  Subjects
# Street_Name  is most likely :  Street name
# MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Building_Classification  is most likely :  Building Classification
# FirstName  is most likely :  Person name (Last name, First name, Middle name, Full name)
# SCHOOL_LEVEL_  is most likely :  School Levels
# VEHICLE_TYPE_CODE_2  is most likely :  Vehicle Type
# Vehicle_Make  is most likely :  Vehicle Type
# Intersection_Street_2  is most likely :  Subjects
# Street_Name  is most likely :  Street name
# Park_Facility_Name  is most likely :  City
# parkname  is most likely :  Person name (Last name, First name, Middle name, Full name)
# CORE_COURSE__MS_CORE_and_9_12_ONLY_  is most likely :  Color
# SCHOOL  is most likely :  School name
# Website  is most likely :  Websites
# License_Business_City  is most likely :  City
# PERSON_LAST_NAME  is most likely :  Person name (Last name, First name, Middle name, Full name)
# CORE_SUBJECT  is most likely :  Subjects
# Neighborhood_2  is most likely :  Neighborhood
# DBA  is most likely :  Websites
# BROOKLYN_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# neighborhood  is most likely :  Neighborhood
# Vehicle_Make  is most likely :  Vehicle Type
# Name__Last__First_  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Street  is most likely :  Street name
# COMPARABLE_RENTAL___1__Neighborhood  is most likely :  Neighborhood
# org_neighborhood  is most likely :  Neighborhood
# ZIP  is most likely :  Zip
# Landmark  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Borough  is most likely :  Borough
# Violation_Location__Zip_Code_  is most likely :  Zip
# School_Name  is most likely :  School name
# SCHOOL_LEVEL_  is most likely :  School Levels
# PRINCIPAL_PHONE_NUMBER  is most likely :  Phone Number
# STATEN_ISLAND_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# City  is most likely :  City agency
# Intersection_Street_2  is most likely :  Subjects
# Last_Name__only_2014_15_  is most likely :  Person name (Last name, First name, Middle name, Full name)
# RESPONDENT_CITY  is most likely :  City
# CANDMI  is most likely :  Type of location
# Street_Name  is most likely :  Street name
# School_Name  is most likely :  School name
# COMPARABLE_RENTAL___2___Neighborhood  is most likely :  Neighborhood
# Agency  is most likely :  City agency
# LOCATION  is most likely :  Type of location
# INTEREST  is most likely :  College/University names
# First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# AUTH_REP_FIRST_NAME  is most likely :  Person name (Last name, First name, Middle name, Full name)
# PREM_TYP_DESC  is most likely :  Vehicle Type
# VEHICLE_TYPE_CODE_3  is most likely :  Vehicle Type
# SCHOOL_LEVEL_  is most likely :  School Levels
# Location  is most likely :  Type of location
# Agency  is most likely :  City agency
# CANDMI  is most likely :  Type of location
# TOP_VEHICLE_MODELS___5  is most likely :  Vehicle Type
# ZIP  is most likely :  Zip
# SCHOOL_LEVEL_  is most likely :  School Levels
# Cross_Street_2  is most likely :  Street name
# SCHOOL_LEVEL_  is most likely :  School Levels
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# NeighborhoodName  is most likely :  Neighborhood
# CrossStreetName  is most likely :  Street name
# Site_Safety_Mgr_s_Last_Name  is most likely :  Street name
# Borough  is most likely :  Borough
# School_Name  is most likely :  School name
# CITY  is most likely :  City agency
# Vehicle_Color  is most likely :  Color
# Location_1  is most likely :  Type of location
# Incident_Zip  is most likely :  Zip
# INPUT_1_Borough  is most likely :  Borough
# Business_Phone_Number  is most likely :  Phone Number
# Cross_Street_1  is most likely :  Street name
# Owner_s_Business_Name  is most likely :  Business name
# Respondent_Address__Zip_Code_  is most likely :  Zip
# Street_Name  is most likely :  Street name
# Prequalified_Vendor_Address  is most likely :  Address
# Vehicle_Make  is most likely :  Vehicle Type
# DVC_MAKE  is most likely :  Car make
# Color  is most likely :  Color
# Park_Facility_Name  is most likely :  City
# Owner_First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# SCHOOL_LEVEL_  is most likely :  School Levels
# DBA  is most likely :  Websites
# StartCity  is most likely :  City
# MI  is most likely :  Zip
# COMPARABLE_RENTAL_2__Building_Classification  is most likely :  Building Classification
# SCHOOL_LEVEL_  is most likely :  School Levels
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Vehicle_Make  is most likely :  Vehicle Type
# interest4  is most likely :  College/University names
# CrossStreet2  is most likely :  Street name
# Cross_Street_2  is most likely :  Street name
# SCHOOL_LEVEL_  is most likely :  School Levels
# BRONX_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# interest3  is most likely :  College/University names
# Zip  is most likely :  Zip
# CANDMI  is most likely :  Type of location
# DVV_MAKE  is most likely :  Car make
# BROOKLYN_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# Applicant_s_First_Name  is most likely :  Street name
# Vehicle_Color  is most likely :  Color
# BOROUGH  is most likely :  Borough
# Location  is most likely :  Type of location
# Establishment_Street  is most likely :  Street name
# StreetName  is most likely :  Street name
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Respondent_Address__City_  is most likely :  City
# Cross_Street_1  is most likely :  Street name
# address_1  is most likely :  Address
# Filing_Representative_First_Name  is most likely :  College/University names
# PRINCIPAL_PHONE_NUMBER  is most likely :  Phone Number
# CrossStreet2  is most likely :  Street name
# School_Name  is most likely :  School name
# _Phone  is most likely :  Phone Number
# School_Name  is most likely :  School name
# Vehicle_Make  is most likely :  Vehicle Type
# CrossStreet2  is most likely :  Street name
# School_Name  is most likely :  School name
# interest1  is most likely :  College/University names
# BRONX_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# Agency_ID  is most likely :  City agency
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Location  is most likely :  Type of location
# VEHICLE_TYPE_CODE_4  is most likely :  Vehicle Type
# Street_Address  is most likely :  Address
# FromStreetName  is most likely :  Street name
# Incident_Zip  is most likely :  Zip
# STATEN_ISLAND_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# CANDMI  is most likely :  Type of location
# Provider_First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# School_Name  is most likely :  School name
# School_Name  is most likely :  School name
# DVT_MAKE  is most likely :  Car make
# SCHOOL_LEVEL_  is most likely :  School Levels
# Website  is most likely :  Websites
# Provider_Last_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# interest4  is most likely :  College/University names
# TruckMake  is most likely :  Car make
# website  is most likely :  Websites
# owner_city  is most likely :  City
# HOUSE_NUMBER  is most likely :  Phone Number
# BROOKLYN___COOPERATIVES_COMPARABLE_PROPERTIES___Building_Classification  is most likely :  Building Classification
# Agency  is most likely :  City agency
# City  is most likely :  City agency
# Vendor_DBA  is most likely :  Color
# Borough  is most likely :  Borough
# School_Name  is most likely :  School name
# interest6  is most likely :  College/University names
# Agency_Website  is most likely :  Websites
# APPLICANT_FIRST_NAME  is most likely :  Street name
# Incident_Zip  is most likely :  Zip
# DBA  is most likely :  Websites
# BOROUGH  is most likely :  Borough
# telephone  is most likely :  Latitude Longitude
# StreetName  is most likely :  Street name
# COMPARABLE_RENTAL___1__Building_Classification  is most likely :  Building Classification
# CORE_SUBJECT_9_12_ONLY_  is most likely :  Subjects
# TOSTREETNAME  is most likely :  Street name
# BORO  is most likely :  Borough
# Middle_Initial  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Agency  is most likely :  City agency
# LOCATION  is most likely :  Type of location
# WEBSITE  is most likely :  Websites
# Owner_s__Phone__  is most likely :  School name
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# Agency  is most likely :  City agency
# AUTH_REP_LAST_NAME  is most likely :  Street name
# Website  is most likely :  Websites
# VEHICLE_TYPE_CODE_5  is most likely :  Vehicle Type
# Park_Facility_Name  is most likely :  City
# Site_Safety_Mgr_s_Last_Name  is most likely :  Street name
# VEHICLE_TYPE_CODE_1  is most likely :  Vehicle Type
# Site_Safety_Mgr_s_First_Name  is most likely :  Street name
# City  is most likely :  City agency
# BORO  is most likely :  Borough
# Address_1__self_reported_  is most likely :  Address
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Neighborhood  is most likely :  Neighborhood
# CORE_COURSE_9_12_ONLY_  is most likely :  Color
# School_Name  is most likely :  School name
# Address_1__self_reported_  is most likely :  Address
# Address  is most likely :  Address
# SCHOOL_LEVEL_  is most likely :  School Levels
# Park_Site_Name  is most likely :  College/University names
# Address  is most likely :  Address
# STREET_NAME  is most likely :  Street name
# interest5  is most likely :  College/University names
# Vehicle_Color  is most likely :  Color
# School_Name  is most likely :  School name
# CORE_SUBJECT___MS_CORE_and__09_12_ONLY_  is most likely :  Subjects
# Vehicle_Make  is most likely :  Vehicle Type
# MANHATTAN___COOPERATIVES_COMPARABLE_PROPERTIES___Building_Classification  is most likely :  Building Classification
# BORO  is most likely :  Borough
# LastName  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Location_1  is most likely :  Type of location
# BOROUGH  is most likely :  Borough
# Agency  is most likely :  City agency
# QUEENS_CONDOMINIUM_PROPERTY_Neighborhood  is most likely :  Neighborhood
# First_Name  is most likely :  Person name (Last name, First name, Middle name, Full name)
# Park_Facility_Name  is most likely :  City
# Vehicle_Make  is most likely :  Vehicle Type
# Agency_Name  is most likely :  City agency
# BROOKLYN_CONDOMINIUM_PROPERTY_Building_Classification  is most likely :  Building Classification
# OWNER_BUS_STREET_NAME  is most likely :  Street name
# CORE_COURSE__MS_CORE_and_9_12_ONLY_  is most likely :  Color
# CITY  is most likely :  City agency
# Applicant_Last_Name  is most likely :  Street name
# Address1  is most likely :  Address
# Vehicle_Body_Type  is most likely :  Vehicle Type
# Phone_Number  is most likely :  Phone Number

# %%
df = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/.tsv")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o29.csv.
# : org.apache.spark.sql.AnalysisException: Path does not exist: file:/home/vijay/Downloads/.tsv;
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:558)
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:545)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike$class.flatMap(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.flatMap(List.scala:355)
# 	at org.apache.spark.sql.execution.datasources.DataSource.org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary(DataSource.scala:545)
# 	at org.apache.spark.sql.execution.datasources.DataSource.resolveRelation(DataSource.scala:359)
# 	at org.apache.spark.sql.DataFrameReader.loadV1Source(DataFrameReader.scala:223)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:211)
# 	at org.apache.spark.sql.DataFrameReader.csv(DataFrameReader.scala:618)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-9-a5d4030e7c9a> in <module>
# ----> 1 df = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/.tsv")
#
# /opt/spark/python/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue)
#     474             path = [path]
#     475         if type(path) == list:
# --> 476             return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     477         elif isinstance(path, RDD):
#     478             def func(iterator):
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'Path does not exist: file:/home/vijay/Downloads/.tsv;'

# %%
df = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2017_DOE_High_School_Directory.tsv")

# %%
df.select('website').show(df.count(),truncate=False)
# Out:
# +--------------------------------------------------------+
# |website                                                 |
# +--------------------------------------------------------+
# |www.theclintonschool.net                                |
# |schools.nyc.gov/schoolportals/21/K728                   |
# |schools.nyc.gov/SchoolPortals/08/X282                   |
# |www.bkmusicntheatre.com                                 |
# |www.epicschoolsnyc.org                                  |
# |www.preparatoryacademyforwriters.com                    |
# |www.generationschools.org                               |
# |www.panamericanihs.org                                  |
# |www.bronxlgj.org                                        |
# |www.richmondhillhs.org                                  |
# |www.MatherHSNYC.org                                     |
# |www.queensgateway.com                                   |
# |www.wjps.org                                            |
# |www.FrankSinatraSchoolOfTheArts.org                     |
# |schools.nyc.gov/SchoolPortals/10/X439                   |
# |schools.nyc.gov/schoolportals/29/Q313                   |
# |www.eschs.org                                           |
# |schools.nyc.gov/schoolportals/02/M544                   |
# |www.hsmcnyc.org                                         |
# |www.vanguardnyc.net                                     |
# |www.queensinquiry.com                                   |
# |www.ywlnetwork.org                                      |
# |www.ecoandfin.org                                       |
# |sites.google.com/site/bronxcollegiateacademy            |
# |www.bronxsoftware.org                                   |
# |www.LawandFinance.org                                   |
# |www.BSSJBrooklyn.com                                    |
# |www.ppasnyc.org                                         |
# |http://schools.nyc.gov/SchoolPortals/05/M369/default.htm|
# |www.aupnyc.org                                          |
# |www.bxchs.org                                           |
# |www.myNEHS.info                                         |
# |www.williamsburgprep.com                                |
# |www.Teachersprep.org                                    |
# |schools.nyc.gov/schoolportals/17/k524                   |
# |www.KECSS.info                                          |
# |schools.nyc.gov/SchoolPortals/08/X349                   |
# |www.Renaissancemtt.org                                  |
# |http://schools.nyc.gov/SchoolPortals/04/M409/default.htm|
# |schools.nyc.gov/SchoolPortals/07/X221                   |
# |www.cssjbronx.org                                       |
# |www.csihighschool.org                                   |
# |www.newyorkharborschool.org                             |
# |www.sof.edu                                             |
# |http://mihs.nycdoe.org                                  |
# |www.bsmartnow.com                                       |
# |www.ihs-us.org                                          |
# |www.ihsnyc.org                                          |
# |http://schools.nyc.gov/SchoolPortals/02/M422/default.htm|
# |www.ptechnyc.org                                        |
# |www.bushwickleaders.org                                 |
# |http://schools.nyc.gov/SchoolPortals/06/M462/default.htm|
# |www.hsmp.org                                            |
# |schools.nyc.gov/SchoolPortals/21/K337                   |
# |www.bxtrumanhighschool.com                              |
# |http://schools.nyc.gov/SchoolPortals/02/M296/default.htm|
# |www.AMSbronx.org                                        |
# |schools.nyc.gov/SchoolPortals/13/K419                   |
# |www.millenniumbrooklynhs.org                            |
# |www.erhsnyc.org                                         |
# |www.eagleharlem.org                                     |
# |www.uagreencareers.org                                  |
# |www.UniversityHeightsHighSchool.org                     |
# |www.ewsis.org                                           |
# |www.hsforteaching.org                                   |
# |schools.nyc.gov/SchoolPortals/17/K382                   |
# |www.brooklynfrontiers.org                               |
# |www.MillenniumArtAcademy.wix.com/millennium             |
# |www.hphsnyc.org                                         |
# |www.newdesignhigh.com                                   |
# |http://schools.nyc.gov/SchoolPortals/02/M439/default.htm|
# |www.Hillcrestweb.com                                    |
# |schools.nyc.gov/SchoolPortals/27/Q351                   |
# |www.fashionhighschool.net                               |
# |www.LehmanHS.com                                        |
# |www.urbanassemblyschool.net                             |
# |www.uaagl.org                                           |
# |www.facinghistoryschool.org                             |
# |www.astorcollegiate.com                                 |
# |schools.nyc.gov/SchoolPortals/12/X248                   |
# |www.qhss.org                                            |
# |www.mybihs.org                                          |
# |schools.nyc.gov/SchoolPortals/29/Q272                   |
# |www.mychah.org                                          |
# |www.kaufmanmusiccenter.org/sms                          |
# |www.mecps.org                                           |
# |schools.nyc.gov/SchoolPortals/28/Q325                   |
# |schools.nyc.gov/SchoolPortals/10/X243                   |
# |schools.nyc.gov/schoolportals/18/k589                   |
# |schools.nyc.gov/SchoolPortals/18/K563                   |
# |www.kurthahnschool.org                                  |
# |schools.nyc.gov/SchoolPortals/16/K393                   |
# |www.flhfhs.org                                          |
# |www.bronxletters.org                                    |
# |schools.nyc.gov/SchoolPortals/17/K533                   |
# |schools.nyc.gov/SchoolPortals/10/X438                   |
# |schools.nyc.gov/SchoolPortals/17/K546                   |
# |www.wcbryanths.org                                      |
# |schools.nyc.gov/SchoolPortals/09/X412                   |
# |schools.nyc.gov/SchoolPortals/26/Q315                   |
# |www.AOFEHS.org                                          |
# |www.myhslps.org                                         |
# |www.bilanyc.net                                         |
# |www.foresthillshs.org                                   |
# |www.nyclabschool.org                                    |
# |www.rfkschools.org                                      |
# |www.hsflad.org                                          |
# |schools.nyc.gov/schoolportals/19/k507                   |
# |www.universityneighborhoodhs.org                        |
# |www.mckeecths.org                                       |
# |www.johnadamsnyc.org                                    |
# |www.essexstreetacademy.org                              |
# |www.hstat.org                                           |
# |www.cvsr.info                                           |
# |www.WHSAD.org                                           |
# |www.tywlsqueens.org                                     |
# |www.aohterasmus.org                                     |
# |schools.nyc.gov/SchoolPortals/08/X305                   |
# |www.in-techacademy.org                                  |
# |www.bccprep.com                                         |
# |schools.nyc.gov/SchoolPortals/11/X545                   |
# |www.newtownhighschool.org                               |
# |schools.nyc.gov/SchoolPortals/09/X517                   |
# |www.RockawayParkHS.com                                  |
# |www.bronxcompass.org                                    |
# |www.hopschool.com                                       |
# |www.foodfinancehs.org                                   |
# |schools.nyc.gov/SchoolPortals/29/Q492                   |
# |schools.nyc.gov/SchoolPortals/15/K463                   |
# |www.thebronxguildhighschool.org                         |
# |www.fthhs.org                                           |
# |www.thhs.qc.edu                                         |
# |www.clarabartonhighschool.org                           |
# |http://schools.nyc.gov/SchoolPortals/02/M520/default.htm|
# |schools.nyc.gov/SchoolPortals/22/K630                   |
# |www.nycmuseumschool.org                                 |
# |www.gradyhs.com                                         |
# |www.aesmithhs.org                                       |
# |www.johndeweyhighschool.org                             |
# |http://schools.nyc.gov/SchoolPortals/01/M292/default.htm|
# |www.bhswca.com                                          |
# |schools.nyc.gov/SchoolPortals/10/X237                   |
# |schools.nyc.gov/SchoolPortals/10/X342                   |
# |www.languageandinnovation.org                           |
# |www.validusprep.org                                     |
# |www.RachelCarsonhs.org                                  |
# |www.btahs.org                                           |
# |www.hudsonhs.com                                        |
# |http://schools.nyc.gov/schoolportals/02/M300            |
# |www.gramercyhs.org                                      |
# |http://www.uamaker.nyc                                  |
# |www.bxscience.edu                                       |
# |www.siths.org                                           |
# |www.flushinghighschool.org                              |
# |www.johnbowne.org                                       |
# |schools.nyc.gov/schoolportals/13/k670                   |
# |www.bard.edu/bhsec                                      |
# |schools.nyc.gov/SchoolPortals/11/X288                   |
# |www.petridesschool.com                                  |
# |www.bkagf.org                                           |
# |www.pelhamprepacademy.org                               |
# |schools.nyc.gov/SchoolPortals/18/K637                   |
# |schools.nyc.gov/schoolportals/10/x437                   |
# |www.gchs.info                                           |
# |www.wadleigharts.org                                    |
# |schools.nyc.gov/SchoolPortals/07/X473                   |
# |www.hs-gc.org                                           |
# |schools.nyc.gov/SchoolPortals/27/Q650                   |
# |www.millenniumhs.org                                    |
# |www.goddardhs308.org                                    |
# |schools.nyc.gov/SchoolPortals/30/Q450                   |
# |schools.nyc.gov/SchoolPortals/11/X275                   |
# |schools.nyc.gov/SchoolPortals/11/X270                   |
# |schools.nyc.gov/SchoolPortals/17/K537 or www.ycdhs.org  |
# |www.juanmorelcampos.com                                 |
# |schools.nyc.gov/SchoolPortals/14/K632                   |
# |www.hsenergytech.org                                    |
# |www.tywls-astoria.org                                   |
# |www.tottenvillehs.net                                   |
# |schools.nyc.gov/SchoolPortals/19/K659                   |
# |http://schools.nyc.gov/SchoolPortals/03/M494/default.htm|
# |www.ms223.org                                           |
# |www.inwoodearlycollege.net                              |
# |www.ls3.org                                             |
# |www.kappainternational.org                              |
# |www.academyofamericanstudies.com                        |
# |www.leadershipnyc.org                                   |
# |schools.nyc.gov/SchoolPortals/09/X260                   |
# |schools.nyc.gov/SchoolPortals/10/X213                   |
# |www.uasch.org                                           |
# |schools.nyc.gov/SchoolPortals/26/Q435                   |
# |www.landmarkhs.org                                      |
# |www.cobblehillhighschool.org                            |
# |schools.nyc.gov/SchoolPortals/21/K348                   |
# |www.LawHS.org                                           |
# |www.harvestcollegiate.org                               |
# |www.eastbronxacademy.org                                |
# |FDAVI.connectwithkids.com                               |
# |www.uamhighschool.org                                   |
# |www.sljhs.org                                           |
# |schools.nyc.gov/SchoolPortals/07/X321                   |
# |www.lyonscommunityschool.org                            |
# |http://schools.nyc.gov/SchoolPortals/05/M304/default.htm|
# |schools.nyc.gov/SchoolPortals/27/Q400                   |
# |www.nycischool.org                                      |
# |www.bronxlatin.com                                      |
# |www.bedfordacademyhs.org                                |
# |www.fda1.org                                            |
# |schools.nyc.gov/SchoolPortals/18/K642                   |
# |www.midwoodhighschool.org                               |
# |schools.nyc.gov/SchoolPortals/17/K531                   |
# |www.ermurrowhs.org                                      |
# |schools.nyc.gov/SchoolPortals/09/X250                   |
# |http://schools.nyc.gov/SchoolPortals/02/M500/default.htm|
# |schools.nyc.gov/SchoolPortals/11/X544                   |
# |www.bronxbridges.org                                    |
# |www.bard.edu/bhsec                                      |
# |schools.nyc.gov/SchoolPortals/19/K502                   |
# |schools.nyc.gov/SchoolPortals/13/K499                   |
# |www.uasem.org                                           |
# |http://schools.nyc.gov/SchoolPortals/03/M541/default.htm|
# |www.martavalle.org                                      |
# |http://schools.nyc.gov/SchoolPortals/02/M542/default.htm|
# |schools.nyc.gov/SchoolPortals/08/X348                   |
# |www.ichs.weebly.com                                     |
# |www.jamaicagateway.org                                  |
# |schools.nyc.gov/SchoolPortals/08/X559                   |
# |www.parkeasths.org                                      |
# |www.ebtbrooklyn.com                                     |
# |http://schools.nyc.gov/SchoolPortals/02/M545/default.htm|
# |www.highschoolofworldcultures.org                       |
# |www.bhsva418.com                                        |
# |www.gilpp.org                                           |
# |www.queenscollegiate.wordpress.com                      |
# |www.curtishs.org                                        |
# |www.envirostudies.org                                   |
# |schools.nyc.gov/SchoolPortals/23/K644                   |
# |schools.nyc.gov/SchoolPortals/13/K350                   |
# |www.excelsiorprephs.com                                 |
# |www.maspethhighschool.org                               |
# |www.epicschoolsnyc.org                                  |
# |www.columbiasecondary.org                               |
# |schools.nyc.gov/SchoolPortals/11/X290                   |
# |www.holcombelrucker.org                                 |
# |schools.nyc.gov/SchoolPortals/19/K583                   |
# |www.qhsls.org                                           |
# |www.thecinemaschool.org                                 |
# |www.aelnyc.org                                          |
# |www.ndssonline.org                                      |
# |www.BronxEnvision.org                                   |
# |schools.nyc.gov/schoolportals/19/k504                   |
# |schools.nyc.gov/SchoolPortals/16/K455                   |
# |www.elpuente.us                                         |
# |schools.nyc.gov/SchoolPortals/21/K559                   |
# |www.francislewishs.org                                  |
# |www.BronxInternationalHS.com                            |
# |www.automotivehs.org                                    |
# |www.uainstitute.org                                     |
# |www.brooklynstudio.org                                  |
# |www.mandelaschoolnyc.org                                |
# |www.humanitiesprep.org                                  |
# |www.lomanyc.net                                         |
# |www.brooklynprephs.org                                  |
# |www.bronxearlycollegeacademy.org                        |
# |www.brooklyncollegeacademy.com                          |
# |www.explorationsacademy.org                             |
# |www.ccbxhsm.org                                         |
# |www.baysidehighschool.org                               |
# |www.artanddesignhs.org                                  |
# |www.nycBOSS.org                                         |
# |www.bxtheatre.org                                       |
# |http://schools.nyc.gov/SchoolPortals/02/M615/default.htm|
# |schools.nyc.gov/SchoolPortals/32/K545                   |
# |schools.nyc.gov/SchoolPortals/19/K683                   |
# |schools.nyc.gov/SchoolPortals/09/X365                   |
# |schools.nyc.gov/SchoolPortals/07/X259                   |
# |www.dwchs.net                                           |
# |www.belmontprephs.org                                   |
# |schools.nyc.gov/SchoolPortals/10/X268                   |
# |http://schools.nyc.gov/SchoolPortals/06/M293/default.htm|
# |www.lmghs.org                                           |
# |www.basehighschool.org                                  |
# |www.repertorycompanyhs.org                              |
# |www.tuhsnyc.com                                         |
# |schools.nyc.gov/SchoolPortals/14/K474                   |
# |www.tywlsbronx.org                                      |
# |www.nestmk12.net                                        |
# |www.mhacademy.net                                       |
# |www.K497.org                                            |
# |www.nychscl.org                                         |
# |newcomershs.schoolwires.net                             |
# |www.actvf.org                                           |
# |www.queensvoc.org                                       |
# |schools.nyc.gov/schoolportals/08/X376                   |
# |www.eaglebronx.org                                      |
# |www.sfe-morriscampus.org                                |
# |www.maxwellhs.org                                       |
# |www.sunsetparkhighschool.org                            |
# |schools.nyc.gov/schoolportals/17/K489                   |
# |www.laguardiahs.org                                     |
# |www.tapconyc.org                                        |
# |www.hostoslincoln.org                                   |
# |www.aviationhs.net                                      |
# |www.MadisonHS.org                                       |
# |www.academyforyoungwriters.org                          |
# |schools.nyc.gov/SchoolPortals/16/K594                   |
# |www.dyprep.org                                          |
# |schools.nyc.gov/SchoolPortals/12/X692                   |
# |www.mcsm.net                                            |
# |schools.nyc.gov/SchoolPortals/12/X684                   |
# |www.uascriminaljustice.org                              |
# |www.brooklynlatin.org                                   |
# |www.withs.org                                           |
# |schools.nyc.gov/SchoolPortals/09/X564                   |
# |www.westchestersquare.org                               |
# |schools.nyc.gov/SchoolPortals/24/Q550                   |
# |www.bcs448.org                                          |
# |www.hsvd.org                                            |
# |www.humanitiesandthearts.org                            |
# |www.lacjhs.org                                          |
# |www.metropolitanels.com                                 |
# |www.macsx297.org                                        |
# |schools.nyc.gov/SchoolPortals/23/K514                   |
# |schools.nyc.gov/SchoolPortals/11/X249                   |
# |www.khalilgibranhs.org                                  |
# |schools.nyc.gov/SchoolPortals/11/X514                   |
# |www.bronxdalehs.org                                     |
# |www.originshighschool.org                               |
# |schools.nyc.gov/SchoolPortals/09/X413                   |
# |www.MottHallV.org                                       |
# |www.bths.edu                                            |
# |schools.nyc.gov/SchoolPortals/09/X276                   |
# |http://schools.nyc.gov/SchoolPortals/06/M348/default.htm|
# |www.Marblehillschool.org                                |
# |www.citypolyhs.org                                      |
# |www.fda2.org                                            |
# |www.ithsnyc.org                                         |
# |schools.nyc.gov/SchoolPortals/09/X327                   |
# |www.meca-nyc.org                                        |
# |schools.nyc.gov/SchoolPortals/10/X549                   |
# |www.aprandolph.com                                      |
# |http://www.iceschoolnyc.org/                            |
# |www.hsmse.org                                           |
# |www.brooklynhsarts.org                                  |
# |schools.nyc.gov/SchoolPortals/17/K751                   |
# |www.crotonainternationalhs.org                          |
# |http://schools.nyc.gov/SchoolPortals/04/M680/default.htm|
# |www.nycacademy.org                                      |
# |schools.nyc.gov/SchoolPortals/32/K554                   |
# |schools.nyc.gov/SchoolPortals/12/X521                   |
# |www.brooklyncaas.com                                    |
# |http://schools.nyc.gov/SchoolPortals/02/M580/default.htm|
# |www.stuy.edu                                            |
# |www.tywls.org                                           |
# |www.manhattanbusinessacademy.org                        |
# |www.bcchsnyc.net                                        |
# |schools.nyc.gov/SchoolPortals/23/K647                   |
# |JKOHS.Net                                               |
# |http://schools.nyc.gov/SchoolPortals/03/M299/default.htm|
# |www.bsge.org                                            |
# |www.mckinneyssa.com                                     |
# |www.queensmetro.com                                     |
# |www.gaynormccownels.org                                 |
# |schools.nyc.gov/SchoolPortals/19/K422                   |
# |www.victorycollegiate.org                               |
# |www.hsas-lehman.org                                     |
# |www.aoiths.org                                          |
# |http://schools.nyc.gov/SchoolPortals/05/M670/default.htm|
# |schools.nyc.gov/SchoolPortals/28/Q284                   |
# |www.rka141.org                                          |
# |www.transittechhs.org                                   |
# |www.watchnyc.org                                        |
# |www.beaconschool.org                                    |
# |www.47aslhs.org                                         |
# |bronxleadershipacademy.org                              |
# |www.mchslic.com                                         |
# |www.NewUtrechthighschoolnyc.com                         |
# |www.scholarsnyc.com                                     |
# |www.uasbyw.org                                          |
# |www.pathwaysprep.org                                    |
# |www.newworldhighschool.com                              |
# |www.hsacny.com                                          |
# |www.cardozohigh.com                                     |
# |www.digitaltechhs.com                                   |
# |www.leadersschool.net                                   |
# |www.wagnerhigh.net                                      |
# |www.portrichmondhs.org                                  |
# |schools.nyc.gov/SchoolPortals/28/Q690                   |
# |www.ihshealthsciences.org                               |
# |http://schools.nyc.gov/SchoolPortals/04/M555/default.htm|
# |www.maalnyc.org                                         |
# |www.newdorphs.org                                       |
# |www.bronxlabschool.org                                  |
# |www.brooklynlabschool.org                               |
# |www.iam-hs.org                                          |
# |www.afsenyc.org                                         |
# |www.rfwagner.org                                        |
# |http://schools.nyc.gov/SchoolPortals/06/M552/default.htm|
# |www.theveritasacademy.com                               |
# |www.starec.org                                          |
# |schools.nyc.gov/SchoolPortals/09/X252                   |
# |http://schools.nyc.gov/SchoolPortals/06/M468/default.htm|
# |www.bcamhs.org                                          |
# |schools.nyc.gov/SchoolPortals/27/Q309                   |
# |www.BronxleadershipAcademy2.org                         |
# |http://qirt.connectwithkids.com/                        |
# |www.flushinginternational.org                           |
# |www.thomasedisonhs.org                                  |
# |schools.nyc.gov/SchoolPortals/08/X530                   |
# |www.greenschoolbrooklyn.com                             |
# |www.bxdca.org                                           |
# |http://schools.nyc.gov/SchoolPortals/02/M298/default.htm|
# |www.bklawtech.com                                       |
# |www.AbrahamLincolnHS.net                                |
# |http://schools.nyc.gov/SchoolPortals/06/M423/default.htm|
# |www.theglcnyc.org                                       |
# |www.qpacademy.org                                       |
# |www.uawildlifeschool.org                                |
# |schools.nyc.gov/SchoolPortals/08/X320                   |
# |schools.nyc.gov/SchoolPortals/26/Q566                   |
# |www.energytechschool.org                                |
# |www.uagateway.org                                       |
# |www.unionsquareacademy.org                              |
# |http://schools.nyc.gov/SchoolPortals/05/M367/default.htm|
# |http://schools.nyc.gov/SchoolPortals/04/M372/default.htm|
# |schools.nyc.gov/SchoolPortals/08/X269                   |
# |www.uaglobalcommerce.org                                |
# |www.Brooklyncollegiate.net                              |
# |fdrhs.schoolwires.net                                   |
# |schools.nyc.gov/SchoolPortals/17/K539                   |
# |schools.nyc.gov/SchoolPortals/29/Q327                   |
# |schools.nyc.gov/SchoolPortals/19/K409                   |
# |www.worldviewhs.org                                     |
# |www.ihpch.org                                           |
# |www.fmhsnyc.org                                         |
# |www.parkslopecollegiate.org                             |
# |www.CLANYC.org                                          |
# |schools.nyc.gov/SchoolPortals/12/X388                   |
# |www.archimedesacademy.org                               |
# |www.thesls.net                                          |
# +--------------------------------------------------------+

# %%
ls = []
import re

# def check_website(word):
# #     grp = re.findall("^((http[s]?|ftp):\/)?\/?([^:\/\s]+)((\/\w+)*\/)([\w\-\.]+[^#?\s]+)(.*)?(#[\w\-]+)?$/", word)
#     grp = re.findall('https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+', str(word))
#     ls.append(grp)
#     if grp:
#         return str(word)
#     else:
#         return "0"

# def create_list(word):
#     return re.split('; |, |\*|\n|\.|\/',word)
# #     return word.split('.')

def process_website(word):
    if word=='null':
        return 0
    ls = re.split('\.|\/',word)
    lst = ['gov', 'com', 'org', 'info', 'http', 'https', 'net','edu','www']
    if any(item in ls for item in lst):
        return 1
    else:
        return 0
    print(ls)
    return ls
# def check_boro(word):
#     if word in ['MANHATTAN', 'staten island', 'BROOKLYN', 'QUEENS', 'BRONX']:
#         return word
#     else:
#         return "0"
# check_boro = F.udf(check_boro, StringType())

def check_boro(word):
    word = str(word)
    if word=="MANHATTAN":
        return word
    elif word=="BROOKLYN":
        return word
    elif word=="QUEENS":
        return word
    elif word=="BRONX":
        return word
    else:
        return "0"

#create_list = F.udf(create_list, StringType())
#check_boro = F.udf(check_boro, StringType())
#chk = F.udf(check_website, StringType())
process_website = F.udf(process_website, IntegerType())

# %%
df = df.withColumn('check_website', process_website(F.col('website')))
df.select('website', 'check_website').show(df.count(), truncate=False)
cnt_cond = lambda cond: F.sum(F.when(cond, 1).otherwise(0))

ctr_df = df.groupBy('check_website').agg(
    cnt_cond(F.col('check_website') == 1).alias('true_count'))
ctr_df.show()

l = []
for row in ctr_df.rdd.collect():
    l.append((row.check_website, row.true_count))
print(l)
print(df.count())
# Out:
# +--------------------------------------------------------+-------------+
# |website                                                 |check_website|
# +--------------------------------------------------------+-------------+
# |www.theclintonschool.net                                |1            |
# |schools.nyc.gov/schoolportals/21/K728                   |1            |
# |schools.nyc.gov/SchoolPortals/08/X282                   |1            |
# |www.bkmusicntheatre.com                                 |1            |
# |www.epicschoolsnyc.org                                  |1            |
# |www.preparatoryacademyforwriters.com                    |1            |
# |www.generationschools.org                               |1            |
# |www.panamericanihs.org                                  |1            |
# |www.bronxlgj.org                                        |1            |
# |www.richmondhillhs.org                                  |1            |
# |www.MatherHSNYC.org                                     |1            |
# |www.queensgateway.com                                   |1            |
# |www.wjps.org                                            |1            |
# |www.FrankSinatraSchoolOfTheArts.org                     |1            |
# |schools.nyc.gov/SchoolPortals/10/X439                   |1            |
# |schools.nyc.gov/schoolportals/29/Q313                   |1            |
# |www.eschs.org                                           |1            |
# |schools.nyc.gov/schoolportals/02/M544                   |1            |
# |www.hsmcnyc.org                                         |1            |
# |www.vanguardnyc.net                                     |1            |
# |www.queensinquiry.com                                   |1            |
# |www.ywlnetwork.org                                      |1            |
# |www.ecoandfin.org                                       |1            |
# |sites.google.com/site/bronxcollegiateacademy            |1            |
# |www.bronxsoftware.org                                   |1            |
# |www.LawandFinance.org                                   |1            |
# |www.BSSJBrooklyn.com                                    |1            |
# |www.ppasnyc.org                                         |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M369/default.htm|1            |
# |www.aupnyc.org                                          |1            |
# |www.bxchs.org                                           |1            |
# |www.myNEHS.info                                         |1            |
# |www.williamsburgprep.com                                |1            |
# |www.Teachersprep.org                                    |1            |
# |schools.nyc.gov/schoolportals/17/k524                   |1            |
# |www.KECSS.info                                          |1            |
# |schools.nyc.gov/SchoolPortals/08/X349                   |1            |
# |www.Renaissancemtt.org                                  |1            |
# |http://schools.nyc.gov/SchoolPortals/04/M409/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/07/X221                   |1            |
# |www.cssjbronx.org                                       |1            |
# |www.csihighschool.org                                   |1            |
# |www.newyorkharborschool.org                             |1            |
# |www.sof.edu                                             |1            |
# |http://mihs.nycdoe.org                                  |1            |
# |www.bsmartnow.com                                       |1            |
# |www.ihs-us.org                                          |1            |
# |www.ihsnyc.org                                          |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M422/default.htm|1            |
# |www.ptechnyc.org                                        |1            |
# |www.bushwickleaders.org                                 |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M462/default.htm|1            |
# |www.hsmp.org                                            |1            |
# |schools.nyc.gov/SchoolPortals/21/K337                   |1            |
# |www.bxtrumanhighschool.com                              |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M296/default.htm|1            |
# |www.AMSbronx.org                                        |1            |
# |schools.nyc.gov/SchoolPortals/13/K419                   |1            |
# |www.millenniumbrooklynhs.org                            |1            |
# |www.erhsnyc.org                                         |1            |
# |www.eagleharlem.org                                     |1            |
# |www.uagreencareers.org                                  |1            |
# |www.UniversityHeightsHighSchool.org                     |1            |
# |www.ewsis.org                                           |1            |
# |www.hsforteaching.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K382                   |1            |
# |www.brooklynfrontiers.org                               |1            |
# |www.MillenniumArtAcademy.wix.com/millennium             |1            |
# |www.hphsnyc.org                                         |1            |
# |www.newdesignhigh.com                                   |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M439/default.htm|1            |
# |www.Hillcrestweb.com                                    |1            |
# |schools.nyc.gov/SchoolPortals/27/Q351                   |1            |
# |www.fashionhighschool.net                               |1            |
# |www.LehmanHS.com                                        |1            |
# |www.urbanassemblyschool.net                             |1            |
# |www.uaagl.org                                           |1            |
# |www.facinghistoryschool.org                             |1            |
# |www.astorcollegiate.com                                 |1            |
# |schools.nyc.gov/SchoolPortals/12/X248                   |1            |
# |www.qhss.org                                            |1            |
# |www.mybihs.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/29/Q272                   |1            |
# |www.mychah.org                                          |1            |
# |www.kaufmanmusiccenter.org/sms                          |1            |
# |www.mecps.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/28/Q325                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X243                   |1            |
# |schools.nyc.gov/schoolportals/18/k589                   |1            |
# |schools.nyc.gov/SchoolPortals/18/K563                   |1            |
# |www.kurthahnschool.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/16/K393                   |1            |
# |www.flhfhs.org                                          |1            |
# |www.bronxletters.org                                    |1            |
# |schools.nyc.gov/SchoolPortals/17/K533                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X438                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K546                   |1            |
# |www.wcbryanths.org                                      |1            |
# |schools.nyc.gov/SchoolPortals/09/X412                   |1            |
# |schools.nyc.gov/SchoolPortals/26/Q315                   |1            |
# |www.AOFEHS.org                                          |1            |
# |www.myhslps.org                                         |1            |
# |www.bilanyc.net                                         |1            |
# |www.foresthillshs.org                                   |1            |
# |www.nyclabschool.org                                    |1            |
# |www.rfkschools.org                                      |1            |
# |www.hsflad.org                                          |1            |
# |schools.nyc.gov/schoolportals/19/k507                   |1            |
# |www.universityneighborhoodhs.org                        |1            |
# |www.mckeecths.org                                       |1            |
# |www.johnadamsnyc.org                                    |1            |
# |www.essexstreetacademy.org                              |1            |
# |www.hstat.org                                           |1            |
# |www.cvsr.info                                           |1            |
# |www.WHSAD.org                                           |1            |
# |www.tywlsqueens.org                                     |1            |
# |www.aohterasmus.org                                     |1            |
# |schools.nyc.gov/SchoolPortals/08/X305                   |1            |
# |www.in-techacademy.org                                  |1            |
# |www.bccprep.com                                         |1            |
# |schools.nyc.gov/SchoolPortals/11/X545                   |1            |
# |www.newtownhighschool.org                               |1            |
# |schools.nyc.gov/SchoolPortals/09/X517                   |1            |
# |www.RockawayParkHS.com                                  |1            |
# |www.bronxcompass.org                                    |1            |
# |www.hopschool.com                                       |1            |
# |www.foodfinancehs.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/29/Q492                   |1            |
# |schools.nyc.gov/SchoolPortals/15/K463                   |1            |
# |www.thebronxguildhighschool.org                         |1            |
# |www.fthhs.org                                           |1            |
# |www.thhs.qc.edu                                         |1            |
# |www.clarabartonhighschool.org                           |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M520/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/22/K630                   |1            |
# |www.nycmuseumschool.org                                 |1            |
# |www.gradyhs.com                                         |1            |
# |www.aesmithhs.org                                       |1            |
# |www.johndeweyhighschool.org                             |1            |
# |http://schools.nyc.gov/SchoolPortals/01/M292/default.htm|1            |
# |www.bhswca.com                                          |1            |
# |schools.nyc.gov/SchoolPortals/10/X237                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X342                   |1            |
# |www.languageandinnovation.org                           |1            |
# |www.validusprep.org                                     |1            |
# |www.RachelCarsonhs.org                                  |1            |
# |www.btahs.org                                           |1            |
# |www.hudsonhs.com                                        |1            |
# |http://schools.nyc.gov/schoolportals/02/M300            |1            |
# |www.gramercyhs.org                                      |1            |
# |http://www.uamaker.nyc                                  |1            |
# |www.bxscience.edu                                       |1            |
# |www.siths.org                                           |1            |
# |www.flushinghighschool.org                              |1            |
# |www.johnbowne.org                                       |1            |
# |schools.nyc.gov/schoolportals/13/k670                   |1            |
# |www.bard.edu/bhsec                                      |1            |
# |schools.nyc.gov/SchoolPortals/11/X288                   |1            |
# |www.petridesschool.com                                  |1            |
# |www.bkagf.org                                           |1            |
# |www.pelhamprepacademy.org                               |1            |
# |schools.nyc.gov/SchoolPortals/18/K637                   |1            |
# |schools.nyc.gov/schoolportals/10/x437                   |1            |
# |www.gchs.info                                           |1            |
# |www.wadleigharts.org                                    |1            |
# |schools.nyc.gov/SchoolPortals/07/X473                   |1            |
# |www.hs-gc.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/27/Q650                   |1            |
# |www.millenniumhs.org                                    |1            |
# |www.goddardhs308.org                                    |1            |
# |schools.nyc.gov/SchoolPortals/30/Q450                   |1            |
# |schools.nyc.gov/SchoolPortals/11/X275                   |1            |
# |schools.nyc.gov/SchoolPortals/11/X270                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K537 or www.ycdhs.org  |1            |
# |www.juanmorelcampos.com                                 |1            |
# |schools.nyc.gov/SchoolPortals/14/K632                   |1            |
# |www.hsenergytech.org                                    |1            |
# |www.tywls-astoria.org                                   |1            |
# |www.tottenvillehs.net                                   |1            |
# |schools.nyc.gov/SchoolPortals/19/K659                   |1            |
# |http://schools.nyc.gov/SchoolPortals/03/M494/default.htm|1            |
# |www.ms223.org                                           |1            |
# |www.inwoodearlycollege.net                              |1            |
# |www.ls3.org                                             |1            |
# |www.kappainternational.org                              |1            |
# |www.academyofamericanstudies.com                        |1            |
# |www.leadershipnyc.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/09/X260                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X213                   |1            |
# |www.uasch.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/26/Q435                   |1            |
# |www.landmarkhs.org                                      |1            |
# |www.cobblehillhighschool.org                            |1            |
# |schools.nyc.gov/SchoolPortals/21/K348                   |1            |
# |www.LawHS.org                                           |1            |
# |www.harvestcollegiate.org                               |1            |
# |www.eastbronxacademy.org                                |1            |
# |FDAVI.connectwithkids.com                               |1            |
# |www.uamhighschool.org                                   |1            |
# |www.sljhs.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/07/X321                   |1            |
# |www.lyonscommunityschool.org                            |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M304/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/27/Q400                   |1            |
# |www.nycischool.org                                      |1            |
# |www.bronxlatin.com                                      |1            |
# |www.bedfordacademyhs.org                                |1            |
# |www.fda1.org                                            |1            |
# |schools.nyc.gov/SchoolPortals/18/K642                   |1            |
# |www.midwoodhighschool.org                               |1            |
# |schools.nyc.gov/SchoolPortals/17/K531                   |1            |
# |www.ermurrowhs.org                                      |1            |
# |schools.nyc.gov/SchoolPortals/09/X250                   |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M500/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/11/X544                   |1            |
# |www.bronxbridges.org                                    |1            |
# |www.bard.edu/bhsec                                      |1            |
# |schools.nyc.gov/SchoolPortals/19/K502                   |1            |
# |schools.nyc.gov/SchoolPortals/13/K499                   |1            |
# |www.uasem.org                                           |1            |
# |http://schools.nyc.gov/SchoolPortals/03/M541/default.htm|1            |
# |www.martavalle.org                                      |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M542/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/08/X348                   |1            |
# |www.ichs.weebly.com                                     |1            |
# |www.jamaicagateway.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/08/X559                   |1            |
# |www.parkeasths.org                                      |1            |
# |www.ebtbrooklyn.com                                     |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M545/default.htm|1            |
# |www.highschoolofworldcultures.org                       |1            |
# |www.bhsva418.com                                        |1            |
# |www.gilpp.org                                           |1            |
# |www.queenscollegiate.wordpress.com                      |1            |
# |www.curtishs.org                                        |1            |
# |www.envirostudies.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/23/K644                   |1            |
# |schools.nyc.gov/SchoolPortals/13/K350                   |1            |
# |www.excelsiorprephs.com                                 |1            |
# |www.maspethhighschool.org                               |1            |
# |www.epicschoolsnyc.org                                  |1            |
# |www.columbiasecondary.org                               |1            |
# |schools.nyc.gov/SchoolPortals/11/X290                   |1            |
# |www.holcombelrucker.org                                 |1            |
# |schools.nyc.gov/SchoolPortals/19/K583                   |1            |
# |www.qhsls.org                                           |1            |
# |www.thecinemaschool.org                                 |1            |
# |www.aelnyc.org                                          |1            |
# |www.ndssonline.org                                      |1            |
# |www.BronxEnvision.org                                   |1            |
# |schools.nyc.gov/schoolportals/19/k504                   |1            |
# |schools.nyc.gov/SchoolPortals/16/K455                   |1            |
# |www.elpuente.us                                         |1            |
# |schools.nyc.gov/SchoolPortals/21/K559                   |1            |
# |www.francislewishs.org                                  |1            |
# |www.BronxInternationalHS.com                            |1            |
# |www.automotivehs.org                                    |1            |
# |www.uainstitute.org                                     |1            |
# |www.brooklynstudio.org                                  |1            |
# |www.mandelaschoolnyc.org                                |1            |
# |www.humanitiesprep.org                                  |1            |
# |www.lomanyc.net                                         |1            |
# |www.brooklynprephs.org                                  |1            |
# |www.bronxearlycollegeacademy.org                        |1            |
# |www.brooklyncollegeacademy.com                          |1            |
# |www.explorationsacademy.org                             |1            |
# |www.ccbxhsm.org                                         |1            |
# |www.baysidehighschool.org                               |1            |
# |www.artanddesignhs.org                                  |1            |
# |www.nycBOSS.org                                         |1            |
# |www.bxtheatre.org                                       |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M615/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/32/K545                   |1            |
# |schools.nyc.gov/SchoolPortals/19/K683                   |1            |
# |schools.nyc.gov/SchoolPortals/09/X365                   |1            |
# |schools.nyc.gov/SchoolPortals/07/X259                   |1            |
# |www.dwchs.net                                           |1            |
# |www.belmontprephs.org                                   |1            |
# |schools.nyc.gov/SchoolPortals/10/X268                   |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M293/default.htm|1            |
# |www.lmghs.org                                           |1            |
# |www.basehighschool.org                                  |1            |
# |www.repertorycompanyhs.org                              |1            |
# |www.tuhsnyc.com                                         |1            |
# |schools.nyc.gov/SchoolPortals/14/K474                   |1            |
# |www.tywlsbronx.org                                      |1            |
# |www.nestmk12.net                                        |1            |
# |www.mhacademy.net                                       |1            |
# |www.K497.org                                            |1            |
# |www.nychscl.org                                         |1            |
# |newcomershs.schoolwires.net                             |1            |
# |www.actvf.org                                           |1            |
# |www.queensvoc.org                                       |1            |
# |schools.nyc.gov/schoolportals/08/X376                   |1            |
# |www.eaglebronx.org                                      |1            |
# |www.sfe-morriscampus.org                                |1            |
# |www.maxwellhs.org                                       |1            |
# |www.sunsetparkhighschool.org                            |1            |
# |schools.nyc.gov/schoolportals/17/K489                   |1            |
# |www.laguardiahs.org                                     |1            |
# |www.tapconyc.org                                        |1            |
# |www.hostoslincoln.org                                   |1            |
# |www.aviationhs.net                                      |1            |
# |www.MadisonHS.org                                       |1            |
# |www.academyforyoungwriters.org                          |1            |
# |schools.nyc.gov/SchoolPortals/16/K594                   |1            |
# |www.dyprep.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/12/X692                   |1            |
# |www.mcsm.net                                            |1            |
# |schools.nyc.gov/SchoolPortals/12/X684                   |1            |
# |www.uascriminaljustice.org                              |1            |
# |www.brooklynlatin.org                                   |1            |
# |www.withs.org                                           |1            |
# |schools.nyc.gov/SchoolPortals/09/X564                   |1            |
# |www.westchestersquare.org                               |1            |
# |schools.nyc.gov/SchoolPortals/24/Q550                   |1            |
# |www.bcs448.org                                          |1            |
# |www.hsvd.org                                            |1            |
# |www.humanitiesandthearts.org                            |1            |
# |www.lacjhs.org                                          |1            |
# |www.metropolitanels.com                                 |1            |
# |www.macsx297.org                                        |1            |
# |schools.nyc.gov/SchoolPortals/23/K514                   |1            |
# |schools.nyc.gov/SchoolPortals/11/X249                   |1            |
# |www.khalilgibranhs.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/11/X514                   |1            |
# |www.bronxdalehs.org                                     |1            |
# |www.originshighschool.org                               |1            |
# |schools.nyc.gov/SchoolPortals/09/X413                   |1            |
# |www.MottHallV.org                                       |1            |
# |www.bths.edu                                            |1            |
# |schools.nyc.gov/SchoolPortals/09/X276                   |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M348/default.htm|1            |
# |www.Marblehillschool.org                                |1            |
# |www.citypolyhs.org                                      |1            |
# |www.fda2.org                                            |1            |
# |www.ithsnyc.org                                         |1            |
# |schools.nyc.gov/SchoolPortals/09/X327                   |1            |
# |www.meca-nyc.org                                        |1            |
# |schools.nyc.gov/SchoolPortals/10/X549                   |1            |
# |www.aprandolph.com                                      |1            |
# |http://www.iceschoolnyc.org/                            |1            |
# |www.hsmse.org                                           |1            |
# |www.brooklynhsarts.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/17/K751                   |1            |
# |www.crotonainternationalhs.org                          |1            |
# |http://schools.nyc.gov/SchoolPortals/04/M680/default.htm|1            |
# |www.nycacademy.org                                      |1            |
# |schools.nyc.gov/SchoolPortals/32/K554                   |1            |
# |schools.nyc.gov/SchoolPortals/12/X521                   |1            |
# |www.brooklyncaas.com                                    |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M580/default.htm|1            |
# |www.stuy.edu                                            |1            |
# |www.tywls.org                                           |1            |
# |www.manhattanbusinessacademy.org                        |1            |
# |www.bcchsnyc.net                                        |1            |
# |schools.nyc.gov/SchoolPortals/23/K647                   |1            |
# |JKOHS.Net                                               |0            |
# |http://schools.nyc.gov/SchoolPortals/03/M299/default.htm|1            |
# |www.bsge.org                                            |1            |
# |www.mckinneyssa.com                                     |1            |
# |www.queensmetro.com                                     |1            |
# |www.gaynormccownels.org                                 |1            |
# |schools.nyc.gov/SchoolPortals/19/K422                   |1            |
# |www.victorycollegiate.org                               |1            |
# |www.hsas-lehman.org                                     |1            |
# |www.aoiths.org                                          |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M670/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/28/Q284                   |1            |
# |www.rka141.org                                          |1            |
# |www.transittechhs.org                                   |1            |
# |www.watchnyc.org                                        |1            |
# |www.beaconschool.org                                    |1            |
# |www.47aslhs.org                                         |1            |
# |bronxleadershipacademy.org                              |1            |
# |www.mchslic.com                                         |1            |
# |www.NewUtrechthighschoolnyc.com                         |1            |
# |www.scholarsnyc.com                                     |1            |
# |www.uasbyw.org                                          |1            |
# |www.pathwaysprep.org                                    |1            |
# |www.newworldhighschool.com                              |1            |
# |www.hsacny.com                                          |1            |
# |www.cardozohigh.com                                     |1            |
# |www.digitaltechhs.com                                   |1            |
# |www.leadersschool.net                                   |1            |
# |www.wagnerhigh.net                                      |1            |
# |www.portrichmondhs.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/28/Q690                   |1            |
# |www.ihshealthsciences.org                               |1            |
# |http://schools.nyc.gov/SchoolPortals/04/M555/default.htm|1            |
# |www.maalnyc.org                                         |1            |
# |www.newdorphs.org                                       |1            |
# |www.bronxlabschool.org                                  |1            |
# |www.brooklynlabschool.org                               |1            |
# |www.iam-hs.org                                          |1            |
# |www.afsenyc.org                                         |1            |
# |www.rfwagner.org                                        |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M552/default.htm|1            |
# |www.theveritasacademy.com                               |1            |
# |www.starec.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/09/X252                   |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M468/default.htm|1            |
# |www.bcamhs.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/27/Q309                   |1            |
# |www.BronxleadershipAcademy2.org                         |1            |
# |http://qirt.connectwithkids.com/                        |1            |
# |www.flushinginternational.org                           |1            |
# |www.thomasedisonhs.org                                  |1            |
# |schools.nyc.gov/SchoolPortals/08/X530                   |1            |
# |www.greenschoolbrooklyn.com                             |1            |
# |www.bxdca.org                                           |1            |
# |http://schools.nyc.gov/SchoolPortals/02/M298/default.htm|1            |
# |www.bklawtech.com                                       |1            |
# |www.AbrahamLincolnHS.net                                |1            |
# |http://schools.nyc.gov/SchoolPortals/06/M423/default.htm|1            |
# |www.theglcnyc.org                                       |1            |
# |www.qpacademy.org                                       |1            |
# |www.uawildlifeschool.org                                |1            |
# |schools.nyc.gov/SchoolPortals/08/X320                   |1            |
# |schools.nyc.gov/SchoolPortals/26/Q566                   |1            |
# |www.energytechschool.org                                |1            |
# |www.uagateway.org                                       |1            |
# |www.unionsquareacademy.org                              |1            |
# |http://schools.nyc.gov/SchoolPortals/05/M367/default.htm|1            |
# |http://schools.nyc.gov/SchoolPortals/04/M372/default.htm|1            |
# |schools.nyc.gov/SchoolPortals/08/X269                   |1            |
# |www.uaglobalcommerce.org                                |1            |
# |www.Brooklyncollegiate.net                              |1            |
# |fdrhs.schoolwires.net                                   |1            |
# |schools.nyc.gov/SchoolPortals/17/K539                   |1            |
# |schools.nyc.gov/SchoolPortals/29/Q327                   |1            |
# |schools.nyc.gov/SchoolPortals/19/K409                   |1            |
# |www.worldviewhs.org                                     |1            |
# |www.ihpch.org                                           |1            |
# |www.fmhsnyc.org                                         |1            |
# |www.parkslopecollegiate.org                             |1            |
# |www.CLANYC.org                                          |1            |
# |schools.nyc.gov/SchoolPortals/12/X388                   |1            |
# |www.archimedesacademy.org                               |1            |
# |www.thesls.net                                          |1            |
# +--------------------------------------------------------+-------------+
# +-------------+----------+
# |check_website|true_count|
# +-------------+----------+
# |            1|       439|
# |            0|         0|
# +-------------+----------+
#
# [(1, 439), (0, 0)]
# 440

# %%
newdf = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2014_-_2015_DOE_High_School_Directory.tsv")

# %%
# For each dataset in the cluster file do:
# find the column name. 
# Call best match for this column name
# call function corresponding to bestMatch on this column
# return the count of non NULL values.

# %%
# newdf.select('website').show(truncate=False)
# newdf = newdf.na.fill("e", "webiste")
print(newdf.count())
newdf = newdf.na.fill("null")
# newdf.select("website").show(truncate=False)
newdf = newdf.withColumn('check_website', process_website(F.col('website')))
# newdf.select('website', 'check_website').show(newdf.count(),truncate=False)
cnt_cond = lambda cond: F.sum(F.when(cond, 1).otherwise(0))

ctr_df = newdf.groupBy('check_website').agg(
    cnt_cond(F.col('check_website') == 1).alias('true_count'))

l = []
for row in ctr_df.rdd.collect():
    l.append((row.check_website, row.true_count))
print(l)
# Out:
# 1305
# [(1, 429), (0, 0)]

# %%
def generate_json(function, df, col):
    return function(df, col)
with open('../Downloads/cluster2.txt') as fp:
    data = list(fp)
    
data = data[0][1:-1]
data = data.split(",")
for row in data:
    ls = row.split('.')
    fl = ls[0].strip()[1:]
    col = ls[1]
    flname = "/NYCOpenData/"+fl

# %%
# # Code for website checking. RUN THIS AND READ A FILE AND CALL json_for_website(dataframe, original_col_name)
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def check_website(word):
#     if word=='null':
#         return "other"
#     ls = re.split('\.|\/',word)
#     lst = ['gov', 'com', 'org', 'info', 'http', 'https', 'net','edu','www']
#     if any(item in ls for item in lst):
#         return "website"
#     else:
#         return "other"

# check_website = F.udf(check_website, StringType())

# def json_for_website(df, col):
#     df = preprocess(df)
#     df = df.withColumn("check", check_website(F.col(col)))
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="0":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
web1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2017_DOE_High_School_Directory.tsv")
web2 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2014_-_2015_DOE_High_School_Directory.tsv")
print(json_for_website(web1, "website"))
print(json_for_website(web2, "website"))
# Out:
# {'semantic_type': 'Websites', 'count': [('Other', 1), ('Website', 439)]}
# {'semantic_type': 'Websites', 'count': [('Other', 876), ('Website', 429)]}

# %%
# # Code for borough checking. RUN THIS AND READ A FILE AND CALL json_for_borough(dataframe, original_col_name)
# def check_borough(word):
#     word = word.lower()
#     if word in ["manhattan", "brooklyn", "bronx", "staten island", "queens"]:
#         return "borough"
#     else:
#         return "other"

# check_borough = F.udf(check_borough, StringType())

# def preprocess(df):
#     df = df.na.fill("null")
#     return df


# def json_for_borough(df, col):
#     df = preprocess(df)
#     df = df.withColumn("check", check_borough(F.col(col)))
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="0":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
#bor1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/DYCD_after-school_programs__NDA_Youth_Employment_Programs.tsv")
bor2 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/HIV_Testing_Locations.tsv")

#print(json_for_borough(bor1,"BOROUGH / COMMUNITY"))
print(json_for_borough(bor2, "Borough"))
# Out:
# {'semantic_type': 'Borough', 'count': [('bronx', 143), ('Other', 79), ('manhattan', 156), ('brooklyn', 136), ('queens', 58), ('staten island', 27)]}

# %%
wr = "347-881-8075"
wr = wr.replace("-","")
wr
# Out:
# '3478818075'

# %%
# # Code for phone checking. RUN THIS AND READ A FILE AND CALL json_for_phone(dataframe, original_col_name)
# def check_phoneNum(number):
#     number = number.strip()
#     number = number.replace("-","")
#     number = number.replace(".","")
#     if number == 'null':
#         return "other"
#     if len(number)!= 10:
#         return "other"
#     if not number.isdigit():
#         return "other"
        
#     return "phone_number"
        
# check_phoneNum = F.udf(check_phoneNum, StringType())
    
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_phone(df, col):
#     df = preprocess(df)
#     df = df.withColumn("check", check_phoneNum(F.col(col)))
#     #df.select(["Phone", "check"]).show(df.count())
#     #print(df.filter(df.Phone == "null").count())
#     #code to display the invalid phone numbers ['N', 'Y', 'null']
#     #dummy = df.filter(df.check == 'Other')
#     #dummy.select("Phone").show(dummy.count())
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
#'pqg4-dm6b.Phone.txt.gz'
phone = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/NYC_Women_s_Resource_Network_Database.tsv")
print(json_for_phone(phone, "Phone"))
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /usr/local/opt/apache-spark/libexec/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /usr/local/opt/apache-spark/libexec/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o4090.csv.
# : org.apache.spark.sql.AnalysisException: Path does not exist: file:/Users/anjan/Downloads/NYC_Women_s_Resource_Network_Database.tsv;
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:558)
# 	at org.apache.spark.sql.execution.datasources.DataSource$$anonfun$org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary$1.apply(DataSource.scala:545)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.TraversableLike$$anonfun$flatMap$1.apply(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike$class.flatMap(TraversableLike.scala:241)
# 	at scala.collection.immutable.List.flatMap(List.scala:355)
# 	at org.apache.spark.sql.execution.datasources.DataSource.org$apache$spark$sql$execution$datasources$DataSource$$checkAndGlobPathIfNecessary(DataSource.scala:545)
# 	at org.apache.spark.sql.execution.datasources.DataSource.resolveRelation(DataSource.scala:359)
# 	at org.apache.spark.sql.DataFrameReader.loadV1Source(DataFrameReader.scala:223)
# 	at org.apache.spark.sql.DataFrameReader.load(DataFrameReader.scala:211)
# 	at org.apache.spark.sql.DataFrameReader.csv(DataFrameReader.scala:618)
# 	at sun.reflect.GeneratedMethodAccessor152.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-259-ca14f43ba04a> in <module>
#       1 #'pqg4-dm6b.Phone.txt.gz'
# ----> 2 phone = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/NYC_Women_s_Resource_Network_Database.tsv")
#       3 print(json_for_phone(phone, "Phone"))
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue)
#     474             path = [path]
#     475         if type(path) == list:
# --> 476             return self._df(self._jreader.csv(self._spark._sc._jvm.PythonUtils.toSeq(path)))
#     477         elif isinstance(path, RDD):
#     478             def func(iterator):
#
# /usr/local/opt/apache-spark/libexec/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /usr/local/opt/apache-spark/libexec/python/pyspark/sql/utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'Path does not exist: file:/Users/anjan/Downloads/NYC_Women_s_Resource_Network_Database.tsv;'

# %%
# Code for longitude validation
def check_long(number):
    number = number.strip()
    if number == "null":
        return "Other"
    if re.search('[a-zA-Z]', number): #check if any alphabet is present
        return "Other"
    number = float(number)  #convert string to float
    if -180 <= number <= 180: #validation check for longitude
        return "Longitude"
    else:
        return "Other"
    
check_long = F.udf(check_long, StringType())
    
def preprocess(df):
    df = df.na.fill("null")
    return df

def json_for_Long(df, col):
    df = preprocess(df)
    df = df.withColumn("check", check_long(F.col(col)))
    df.createOrReplaceTempView("df")
    temp = spark.sql("select check, count(*) as ctr from df group by check")
    ls = []
    for row in temp.rdd.collect():
        if row.check=="Other":
            ls.append(("Other", row.ctr))
        else:
            ls.append((row.check, row.ctr))
    return {"semantic_type":checkType(col), "count":ls}

# %%
#'yjub-udmw.Location__Lat__Long_.txt.gz'
Long = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/NYC_Wi-Fi_Hotspot_Locations.tsv")
print(json_for_Long(Long, "Longitude"))
# Out:
# {'semantic_type': 'Latitude Longitude', 'count': [('Other', 3), ('Longitude', 3318)]}

# %%
# Code for latitude validation
def check_lat(number):
    if number == "null":
        return "Other"
    number = number.strip()
    if re.search('[a-zA-Z]', number): #check if any alphabet is present
        return "Other"
    number = float(number)  #convert string to float
    if -90 <= number <= 90: #validation check for longitude
        return "Latitude"
    else:
        return "Other"
    
check_lat = F.udf(check_lat, StringType())
    
def preprocess(df):
    df = df.na.fill("null")
    return df

def json_for_Lat(df, col):
    df = preprocess(df)
    df = df.withColumn("check", check_lat(F.col(col)))
    df.createOrReplaceTempView("df")
    temp = spark.sql("select check, count(*) as ctr from df group by check")
    ls = []
    for row in temp.rdd.collect():
        if row.check=="Other":
            ls.append(("Other", row.ctr))
        else:
            ls.append((row.check, row.ctr))
    return {"semantic_type":checkType(col), "count":ls}

# %%
#'yjub-udmw.Location__Lat__Long_.txt.gz'
lat = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/NYC_Wi-Fi_Hotspot_Locations.tsv")
print(json_for_Lat(lat, "Latitude"))
# Out:
# {'semantic_type': 'Latitude Longitude', 'count': [('Other', 3), ('Latitude', 3318)]}

# %%
# # Code for zipcode validation
# def check_zipCode(number):
#     number = number.strip()
#     if number == "null":
#         return "Other"
    
#     zip_re = re.compile('^[0-9]{5}(?:-[0-9]{4})?$') #accepts 11209 as well as 11209-1234
#     if not zip_re.match(number):
#         return "Other"
    
#     code = number[:5]
#     if int(code)<10000 or int(code)>19999:
#         return "Other"
#     return "Zipcode"    
    
# check_zipCode = F.udf(check_zipCode, StringType())
    
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_zipCode(df, col):
#     df = preprocess(df)
#     df = df.withColumn("check", check_zipCode(F.col(col)))
#     #dummy = df.filter(df.check == 'Other')
#     #dummy.select("Incident Zip").show(dummy.count())
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
#'yjub-udmw.Location__Lat__Long_.txt.gz'
zipcode = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/311_Service_Requests_for_2009.tsv")
print(json_for_zipCode(zipcode, "Incident Zip"))
# Out:
# {'semantic_type': 'Zip', 'count': [('Zipcode', 1659146), ('Other', 123987)]}

# %%
# # Code for business Name validation
# def check_bizName(name):
#     name = name.strip()
#     if name == "null":
#         return "Other"
#     ls = re.split('\.|\/',name)
#     lst = []
#     if any(item in ls for item in lst):
#         return "Business"
#     else:
#         return "Other"
        
    
# check_bizName = F.udf(check_bizName, StringType())
    
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_bizName(df, col):
#     df = preprocess(df)
#     #df.select("BUSINESS_NAME2").show(100)
#     df = df.withColumn("check", check_bizName(F.col(col)))
#     #dummy = df.filter(df.check == 'Other')
#     #dummy.select("Incident Zip").show(dummy.count())
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
#'qcdj-rwhu.BUSINESS_NAME2.txt.gz'
bizName = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Sidewalk_Caf__Licenses_and_Applications.tsv")
print(json_for_bizName(bizName, "BUSINESS_NAME2"))
# Out:
# +--------------------+
# |      BUSINESS_NAME2|
# +--------------------+
# |            TOASTIES|
# |                null|
# |              RAFELE|
# |       LE SINGE VERT|
# |  PAOLA'S RESTAURANT|
# |   LE PAIN QUOTIDIEN|
# |       KISH KASH NYC|
# |            PASCALOU|
# |TIMMY'S BY THE RIVER|
# |               MAMAK|
# | TEDDY'S BAR & GRILL|
# |                null|
# |                null|
# |                null|
# |              PAGANI|
# |SOLE BISTRO ITALIANO|
# |            THE MILL|
# |            ASELLINA|
# |    MEDI WINEBAR LLC|
# |             LADUREE|
# |                null|
# |                null|
# |   MOCA ASIAN BISTRO|
# |          BAREBURGER|
# | TAORMINA RESTAURANT|
# |                null|
# |            LA NONNA|
# |            DALTON'S|
# |                null|
# |                null|
# |         LE ZIE 2000|
# |                null|
# |     BUDDHA TACO BAR|
# |       LOCANDA VERDE|
# |          GYRO WORLD|
# |      PASQUALE JONES|
# |          SARABETH'S|
# |WOODPECKER BY DAV...|
# |                null|
# |             GLADY'S|
# |    MEL'S BURGER BAR|
# |                null|
# |             LAVAGNA|
# |                null|
# |   JACK'S WIFE FREDA|
# |                null|
# |                null|
# |CERVECERIA HAVEMEYER|
# |   THE BRAZEN TAVERN|
# |LITE BITES CAFE &...|
# |         WA-HI DINER|
# |                null|
# |FOKKUS ROOM & CUCINE|
# |       MADAME SOUSOU|
# |           LAFAYETTE|
# |             BELLINI|
# |                null|
# |EAST HARLEM BOTTL...|
# |                null|
# |                null|
# |           JACKSON'S|
# |     MARLOW AND SONS|
# |                null|
# |PIZZETTERIA BRUNETTI|
# |THE GRANGE BAR & ...|
# |        44 SOUTHWEST|
# |              VANDAL|
# |       DUNKIN DONUTS|
# |               VIC'S|
# |                null|
# |                null|
# |             NATSUMI|
# |             DZIUPLA|
# |        MEDITERRANEO|
# |        THE SHADMOOR|
# |           GRAY MARE|
# |                null|
# |    CORNERSTONE CAFE|
# |BILL'S BAR AND BU...|
# | LA PEQUENA COLOMBIA|
# |       BLEND ASTORIA|
# |              BALZEM|
# |         PIERRE LOTI|
# |           THE SMITH|
# |                null|
# |        PICCOLO CAFE|
# |         CAFE BOULUD|
# |            REGIONAL|
# |SENN THAI COMFORT...|
# |                null|
# |                null|
# |               SAUCE|
# |              SAPORI|
# |               DINER|
# |                null|
# |     NY BRAT FACTORY|
# |        CAFFE NAPOLI|
# |         LAS RAMBLAS|
# |          BAR ITALIA|
# |BIER INTERNATIONA...|
# +--------------------+
# only showing top 100 rows
#
# None

# %%
# # Code for address validation
# def check_address(word):
#     word = word.strip()
#     word = word.lower()
#     if word == "null":
#         return "Other"
#     #TODO: use regex to validate address
#     ls = word.split()
#     lst = ['boulevard', 'parkway', 'east', 'west', 'street', 'avenue', 'lane', 'place' , 'road', 'broadway', 'beach', 'drive']
#     if any(item in ls for item in lst):
#         return "Address"
#     else:
#         return "Other"
        
    
# check_address = F.udf(check_address, StringType())
    
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_address(df, col):
#     df = preprocess(df)
#     df = df.withColumn("check", check_address(F.col(col)))
#     #dummy = df.filter(df.check == 'Other')
#     #dummy.select("Address 1").show(dummy.count())
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
#'446w-773i.Address_1.txt.gz'
address = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2018_School_Quality_Report_Results_for_PreK.tsv")
print(json_for_address(address, "Address 1"))
# Out:
# +--------------------+
# |           Address 1|
# +--------------------+
# |        Site_Address|
# |         1 Peck Slip|
# |     202 Sherman Ave|
# |580 Crotona Park ...|
# |275 Harlem River ...|
# | 3030 Godwin Terrace|
# |2880 Kingsbridge ...|
# |   86-35 235th Court|
# |65-10 Dieterle Cr...|
# |178-37 146th Terrace|
# |300 Richmond Terrace|
# |   715 Ocean Terrace|
# | 110-51 Guy R Brewer|
# |  5566 KINGS HIGHWAY|
# |    110 Kosciusko St|
# |133 Kings First Walk|
# |   105 Kings Highway|
# |   412 Kings Highway|
# |165 Prospect Park...|
# |          4 NY Plaza|
# |4 Washington Squa...|
# |89-89 Van Wyck Ex...|
# |95-15 Horace Hard...|
# |1 Jamaica Center ...|
# |9825 Horace Hardi...|
# |     11515 101st Ave|
# |JFK Airport Build...|
# |6248 Mt. Olivet C...|
# |167-01 Union Turn...|
# |178-36 Wexford Te...|
# |1000 Richmond Ter...|
# |    1298 Woodrow Rad|
# | 20 Park Hill Circle|
# |1345 Grand Concourse|
# |  2169 Blackrock Ave|
# |3031 Grand Concourse|
# |1925 Grand Concourse|
# |785 Crotona Park ...|
# |1130 Grand Concourse|
# |3101 Kingsbridge ...|
# |1125 Grand Concourse|
# | 475 Grand Concourse|
# |       2010 Sedgwick|
# |2169 Grand Concourse|
# |1926 Cross Bronx ...|
# |2195 Grand Concourse|
# |         1 Peck Slip|
# |      10 Bouck Court|
# +--------------------+
#
# {'semantic_type': 'Address', 'count': [('Other', 48), ('Address', 1936)]}

# %%
# # Code for school level validation
# def check_schLvl(word):
#     word = word.strip()
#     word = word.lower()
#     if word == "null":
#         return "Other"
#     lst = ['elementary', 'middle', 'k-2', 'k-3', 'k-8', 'high school' , 'high school transfer', 'yabc']
#     if word in lst:
#         return word        
#     else:
#         return "Other"
                
# check_schLvl = F.udf(check_schLvl, StringType())
    
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_schLvl(df, col):
#     df = preprocess(df)
#     #df.select("SCHOOL LEVEL*").show(100)
#     df = df.withColumn("check", check_schLvl(F.col(col)))
#     #dummy = df.filter(df.check == 'Other')
#     #dummy.select("SCHOOL LEVEL*").show(dummy.count())
    
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
#'mjux-q9d4.SCHOOL_LEVEL_.txt.gz'
# schLvl = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2011-2012_School_Progress_Report_-_All_Schools.tsv")
# print(json_for_schLvl(schLvl, "SCHOOL LEVEL*"))
# Out:
# {'semantic_type': 'School Levels', 'count': [('yabc', 22), ('k-2', 11), ('k-8', 170), ('elementary', 626), ('high school transfer', 49), ('middle', 394), ('high school', 444), ('k-3', 27)]}

# %%
# colordata = spark.read.option("sep", ",").option("header", "true").csv("../Downloads/wikipedia_color_names.csv")
# colordata.columns
# # colordata = spark.read.option("sep", "|").option("header", "true").csv("../Downloads/wikipedia_color_names.csv")
# clr = colordata.select("Name").rdd.flatMap(lambda x: x).collect()
# lclr = [c.lower() for c in clr]
# print(lclr)
# print(len(lclr))
# soundclr = [soundex(c) for c in lclr]
# print(len(soundclr))

# %%
# # Code for vehicle color validation
# # colordata = spark.read.option("sep", ",").option("header", "true").csv("../Downloads/wikipedia_color_names.csv")
# colordata = spark.read.option("sep", ",").option("header", "true").csv("../Downloads/colors.csv")
# clr = colordata.select("name").rdd.flatMap(lambda x: x).collect()
# lclr = []
# for c in clr:
#     l = c.split(" ")
#     if len(l)>1:
#         for li in l:
#             lclr.append(li.lower())
#     lclr.append(c.lower())
# # lclr = [c.lower() for c in clr]

# soundclr = [soundex(c) for c in lclr]
# def check_color(word, lclr, soundclr):
#     word = word.strip()
#     word = word.lower()
#     if word == "null":
#         return "Other"
#     if word in lclr:
#         return "Color" 
# #     if soundex(word) in soundclr:
# #         return "Color"
#     flag = False
#     for c in soundclr:
#         if ld(soundex(word), c)<=1:
#             flag = True
#     if flag:
#         return "Color"
# #     elif soundex(word) in soundclr:
# #         return "Color"
#     else:
#         return "Other"
                
# # check_color = F.udf(check_color, StringType())
# check_color_l=F.udf(lambda x: check_color(x, lclr, soundclr), StringType())
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_color(df, col):
# #     df = df.limit(100)
#     df = preprocess(df)
#     df = df.withColumn("check", check_color_l(F.col(col)))
#     df.select(col, "check").show(100)
#     #dummy = df.filter(df.check == 'Other')
#     #dummy.select("SCHOOL LEVEL*").show(dummy.count())
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
#'kiv2-tbus.Vehicle_Color.txt.gz'
color = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Parking_Violations_Issued_-_Fiscal_Year_2017.tsv")
# print(json_for_color(color, "Vehicle Color"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-880e0a66d032> in <module>
#       1 #'kiv2-tbus.Vehicle_Color.txt.gz'
#       2 color = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Parking_Violations_Issued_-_Fiscal_Year_2017.tsv")
# ----> 3 print(json_for_color(color, "Vehicle Color"))
#
# NameError: name 'json_for_color' is not defined

# %%
# # Code for city Validation
# citydf = spark.read.option("sep", "|").option("header", "true").csv("../Downloads/USA/us_cities_states_counties.csv")
# citydf = citydf.filter(citydf["State short"]=="NY")
# mvv = citydf.select("City").rdd.flatMap(lambda x: x).collect()
# lowermvv = [c.lower() for c in mvv]
# def check_city(word, mvv):
#     if word is None:
#         return "Other"
#     word = word.strip()
#     word = word.lower()
#     if word == "null":
#         return "Other"
#     lst = mvv
#     if word in lst:
#         return "City"        
#     else:
#         return "Other"
                
# # check_city = F.udf(check_city, StringType())
# check_city_l=F.udf(lambda x: check_city(x,lowermvv), StringType())
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_city(df, col):
#     df = preprocess(df)
#     df = df.withColumn("check", check_city_l(F.col(col)))
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
# #     temp.show()
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
# city1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Charges.tsv")
# city2 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2003_Campaign_Contributions (1).tsv")
# print(json_for_city(city1, "City"))
# print(json_for_city(city2, "City"))

# %%
# # Code for building classification
# def check_build_cls(word):
#     if '-' not in word:
#         return "other"
#     if word == "null":
#         return "other"
#     word = word.strip().split("-")[0]
#     word = word.upper()
#     lst = ["A0","A1","A2","A3","A4","A5","A6","A7","A8","A9",
#            "B1","B2","B3","B9","C0","C1","C2","C3","C4","C5","C6","C7","C8","C9","CM",
#            "D0","D1","D2","D3","D4","D5","D6","D7","D8","D9",
#            "E1","E2","E3","E4","E7","E9","F1","F2","F4","F5","F8","F9",
#            "G0","G1","G2","G3","G4","G5","G6","G7","G8","G9","GU","GW","G9",
#            "HB","HH","HR","HS","H1","H2","H3","H4","H5","H6","H7","H8","H9",
#            "I1","I2","I3","I4","I5","I6","I7","I9","J1","J2","J3","J4","J5","J6","J7","J8","J9",
#            "K1","K2","K3","K4","K5","K6","K7","K8","K9","L1","L2","L3","L8","L9",
#            "M1","M2","M3","M4","M9","N1","N2","N3","N4","N9",
#            "O1","O2","O3","O4","O5","O6","O7","O8","O9","P1","P2","P3","P4","P5","P6","P7","P8","P9"
#            ,"Q1","Q2","Q3","Q4","Q5","Q6","Q7","Q8","Q9",
#            "RA","RB","RG","RH","RK","RP","RR","RS","RT","RW","R0","R1","R2","R3","R4","R5","R6","R7","R8","R9","RR",
#            "S0","S1","S2","S3","S4","S5","S9","T1","T2","T9",
#            "U0","U1","U2","U3","U4","U5","U6","U7","U8","U9","V0","V1","V2","V3","V4","V5","V6","V7","V8","V9",
#            "W1","W2","W3","W4","W5","W6","W7","W8","W9","Y1","Y2","Y3","Y4","Y5","Y6","Y7","Y8","Y9",
#            "Z0","Z1","Z2","Z3","Z4","Z5","Z7","Z8","Z9"]
#     if word in lst:
#         return "building_classification"        
#     else:
#         return "other"
                
# check_build_cls = F.udf(check_build_cls, StringType())
    
# def preprocess(df):
#     df = df.na.fill("null")
#     return df

# def json_for_build_cls(df, col):
#     df = preprocess(df)
#     df = df.withColumn("check", check_build_cls(F.col(col)))
#     df.createOrReplaceTempView("df")
#     temp = spark.sql("select check, count(*) as ctr from df group by check")
#     ls = []
#     for row in temp.rdd.collect():
#         if row.check=="Other":
#             ls.append(("Other", row.ctr))
#         else:
#             ls.append((row.check, row.ctr))
#     return {"semantic_type":checkType(col), "count":ls}

# %%
# bd2 = pd.read_csv("../Downloads/DOF__Cooperative_Comparable_Rental_Income___Manhattan__FY_2009_2010.tsv", sep="\t")
# bd2 = bd2["MANHATTAN – COOPERATIVES COMPARABLE PROPERTIES – Building Classification"]
# schema = StructType([StructField('MANHATTAN – COOPERATIVES COMPARABLE PROPERTIES – Building Classification', StringType(), False)])
# build2 = spark.createDataFrame(bd2, schema)

# %%
# build1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/DOF__Condominium_comparable_rental_income___Brooklyn_-_FY_2010_2011.tsv")
# build2 = spark.read.option("sep", ",").option("header", "true").csv("../Downloads/csvtemp.csv")
# print(json_for_build_cls(build1, "BROOKLYN CONDOMINIUM PROPERTY Building Classification"))
# print(json_for_build_cls(build2, "MANHATTAN – COOPERATIVES COMPARABLE PROPERTIES – Building Classification"))
# build2.select("MANHATTAN – COOPERATIVES COMPARABLE PROPERTIES – Building Classification").show()

# %%
# build2.select("MANHATTAN – COOPERATIVES COMPARABLE PROPERTIES – Boro-Block-Lot").show(truncate=False)
# print(build2.count())
# build2.columns

# %%
"""
List of functions written for semantic type : 
1. check_park
2. check_agency
3. check_subject
4. check_street
5. check_address
6. check_schLvl
7. check_website
8. check_build_cls
9. check_zipcode
10. check_school_name
11. check_borough
12. check_phoneNum
13. check_color
14. check_city
15. check_latitude/longitude
16. check_biz
17. check_neigh
18. check_car_make
19. check_area_of_study
20. check_uni_name
21. check_body
22. check_loc
"""



def preprocess(df):
    df = df.na.fill("null")
    return df



# Code for location type check
def check_loc(name):
    name = name.lower()
    name = name.replace("&","")
    name = name.replace("and","")
    name = name.replace("/"," ")
    name = name.replace(".","")
    name= name.replace("-","")
    name = name.strip()
#     name = name.split(" ")
    lst = ["residence","house","bar","club","subway","diner","market","street",
           "store","hospital","grocery","bus"]
    for item in lst:
        if item in name:
            return "location_type"
    return "other"

    
check_loc = F.udf(check_loc, StringType())



# Code for vehicle body Validation
def check_body(name):
    name = name.strip()
    name = name.lower()
    name = name.replace("&","")
    name = name.replace("and","")
    name = name.replace("/"," ")
    name = name.split(" ")
    lst = ["wagon", "truck", "sedan", "bike","bus","pick","taxi",
           "van","cycle","cab","motor","door","moped","conv",
           "garbage","mixer","ambul","passenger","tank","flat","bed","wheel",
           "limo","vehicle","dump","train","delv","subn","dsd","util","refg","trlr","pkup","semi"]
    for n in name:
        for item in lst:
            if ld(n, item)<=2:
                return "vehicle_type"
    return "other"

    
check_body = F.udf(check_body, StringType())


# Code for university name Validation
def check_uni_name(name):
    name = name.strip()
    name = name.lower()
    name = name.replace(","," ")
    name = name.replace("&","")
    if name=="null":
        return "other"
    if "university" in name:
        return "college_name"
    if "college" in name and "school" not in name:
        return "college_name"
    return "other"


check_uni_name = F.udf(check_uni_name, StringType())

# Code for area of study validation
def check_area_of_study(name):
    if name=="null" or name=="-":
        return "other"
    name = name.strip()
    name = name.lower()
    name = name.replace("&","")
    name = name.replace("and","")
    name = name.replace("/"," ")
    name = name.split(" ")
    lst = ['general agriculture', 'agriculture production and management', 'agricultural economics', 'animal sciences', 'food science', 'plant science and agronomy', 'soil science', 'miscellaneous agriculture', 'forestry', 'natural resources management', 'fine arts', 'drama and theater arts', 'music', 'visual and performing arts', 'commercial art and graphic design', 'film video and photographic arts', 'studio arts', 'miscellaneous fine arts', 'environmental science', 'biology', 'biochemical sciences', 'botany', 'molecular biology', 'ecology', 'genetics', 'microbiology', 'pharmacology', 'physiology', 'zoology', 'neuroscience', 'miscellaneous biology', 'cognitive science and biopsychology', 'general business', 'accounting', 'actuarial science', 'business management and administration', 'operations logistics and e-commerce', 'business economics', 'marketing and marketing research', 'finance', 'human resources and personnel management', 'international business', 'hospitality management', 'management information systems and statistics', 'miscellaneous business & medical administration', 'communications', 'journalism', 'mass media', 'advertising and public relations', 'communication technologies', 'computer and information systems', 'computer programming and data processing', 'computer science', 'information sciences', 'computer administration management and security', 'computer networking and telecommunications', 'mathematics', 'applied mathematics', 'statistics and decision science', 'mathematics and computer science', 'general education', 'educational administration and supervision', 'school student counseling', 'elementary education', 'mathematics teacher education', 'physical and health education teaching', 'early childhood education', 'science and computer teacher education', 'secondary teacher education', 'special needs education', 'social science or history teacher education', 'teacher education: multiple levels', 'language and drama education', 'art and music education', 'miscellaneous education', 'library science', 'architecture', 'general engineering', 'aerospace engineering', 'biological engineering', 'architectural engineering', 'biomedical engineering', 'chemical engineering', 'civil engineering', 'computer engineering', 'electrical engineering', 'engineering mechanics physics and science', 'environmental engineering', 'geological and geophysical engineering', 'industrial and manufacturing engineering', 'materials engineering and materials science', 'mechanical engineering', 'metallurgical engineering', 'mining and mineral engineering', 'naval architecture and marine engineering', 'nuclear engineering', 'petroleum engineering', 'miscellaneous engineering', 'engineering technologies', 'engineering and industrial management', 'electrical engineering technology', 'industrial production technologies', 'mechanical engineering related technologies', 'miscellaneous engineering technologies', 'materials science', 'nutrition sciences', 'general medical and health services', 'communication disorders sciences and services', 'health and medical administrative services', 'medical assisting services', 'medical technologies technicians', 'health and medical preparatory programs', 'nursing', 'pharmacy pharmaceutical sciences and administration', 'treatment therapy professions', 'community and public health', 'miscellaneous health medical professions', 'area ethnic and civilization studies', 'linguistics and comparative language and literature', 'french german latin and other common foreign language studies', 'other foreign languages', 'english language and literature', 'composition and rhetoric', 'liberal arts', 'humanities', 'intercultural and international studies', 'philosophy and religious studies', 'theology and religious vocations', 'anthropology and archeology', 'art history and criticism', 'history', 'united states history', 'cosmetology services and culinary arts', 'family and consumer sciences', 'military technologies', 'physical fitness parks recreation and leisure', 'construction services', 'electrical', 'industrial arts & consumer services', 'transportation sciences and technologies', 'multi/interdisciplinary studies', 'court reporting', 'pre-law and legal studies', 'criminal justice and fire protection', 'public administration', 'public policy', 'physical sciences', 'astronomy and astrophysics', 'atmospheric sciences and meteorology', 'chemistry', 'geology and earth science', 'geosciences', 'oceanography', 'physics', 'multi-disciplinary or general science', 'nuclear', 'physical sciences', 'psychology', 'educational psychology', 'clinical psychology', 'counseling psychology', 'industrial and organizational psychology', 'social psychology', 'miscellaneous psychology', 'human services and community organization', 'social work', 'interdisciplinary social sciences', 'general social sciences', 'economics', 'criminology', 'geography', 'international relations', 'political science and government', 'sociology', 'miscellaneous social sciences']
    for nm in name:
        for item in lst:
            if nm == item:
                return "area_of_study"
    return "other"

    
check_area_of_study = F.udf(check_area_of_study, StringType())


# Code for car make validation
def check_car_make(name):
    name = name.strip()
    name = name.lower()
    name = name.replace("`","")
    name = name.replace("."," ")
    name = name.replace("0","0")
    lst = ["volvo","chrylsr","datsun","chevy","chevrolet","ford","volkswagen",
           "vw","buick","mercury","dodge","subaru","mazda","audi","honda","hyundai",
           "plymth","lincoln","toyota","renault","peugot","nissan","isuzu","cadillac",
            "yamaha", "jeep","saab","yamaha","porshe","oldsmob","pontac","ferrari","mitsubi",
            "eagle","jaguar","camaro"]
    if name=="-":
        return "other"
    for item in lst:
        if ld(name, item)<=2:
            return "car_make"
    return "other"
    
    if name == "null":
        return "other"
    for item in ls:
        if item in name:
            return "neighborhood"
    return "other"
    
check_make = F.udf(check_car_make, StringType())

# Code for neighborhood validation
def check_neighborhood(name):
    name = name.strip()
    name = name.lower()
    name = name.replace(".","")
    name = name.replace(","," ")
    name = name.split("-")[0]
    
    ls = ['albans','hollis hills', 'jamaica', 'borough park', 'laguardia airport', 
          'stapleton', 'flatiron district', 'stuyvesant town', 'clifton', 
          'westchester square', 'claremont village', 'claremont', 'central park', 
          'emerson hill', 'theater district', 'noho', 'laurelton', 
          'sunnyside', 'clinton hill', 'castle hill', 'ozone park', 
          'highbridge', 'canarsie', 'park slope', 'pelham bay park', 
          'bergen beach', 'upper east side', 'latourette park', 'soundview', 
          'governors island', 'kingsbridge', 'queens village', 'two bridges', 
          "hell's kitchen", 'bloomfield', 'briarwood', 'bay terrace, staten island', 
          'brighton beach', 'douglaston', 'tribeca', 'windsor terrace', 'bronx park', 
          'grymes hill', 'brooklyn heights', 'columbia st', 'concourse', 'ellis island', 
          'ditmars steinway', 'bedford','stuyvesant', 'kew gardens', 'east harlem', 
          'bronxdale', 'bayswater', 'bushwick', 'city island', 'huguenot', 'long island city',
          'new dorp beach', 'richmondtown', 'bellerose', 'east new york', 'maspeth',
          'country club', 'sheepshead bay', 'mariners harbor', 'arlington', 'new brighton',
          'greenwich village', 'westerleigh', 'mill basin', 'spuyten duyvil', 'van nest',
          'washington heights', 'sea gate', 'jamaica estates', 'plum beach', 'morrisania',
          'kips bay', 'tottenville', 'bay ridge', 'east morrisania', 'little neck', 'grant city', 
          'green-wood cemetery', 'west village', 'gerritsen beach', 'soho', 'alley pond park', 
          'lighthouse hill', 'oakwood', 'floral park', 'co-op city', 'cambria heights', 'chinatown', 
          'midtown', 'rockaway beach', 'breezy point', 'howard beach', 'arrochar', 'edenwald', 
          'prospect heights', 'south ozone park', 'marble hill', 'manhattan beach', 'upper west side', 
          'fort wadsworth', 'hunts point', 'roosevelt island', 'port richmond', 'morris heights', 
          'mount eden', 'jamaica bay', 'norwood', 'gramercy', 'fieldston', 'bath beach', 'rosedale', 
          'charleston', 'coney island', 'glendale', 'broad channel', 'cypress hills', 'randall manor', 
          'graniteville', 'west farms', 'civic center', 'concord', 'gowanus', 'mount hope', 'whitestone', 
          'dumbo', 'glen oaks', 'tremont', 'woodside', 'crotona park', 'richmond hill', 'rosebank', 'inwood', 
          'elmhurst', 'far rockaway', 'boerum hill', 'tompkinsville', "bull's head", 'cobble hill', 
          'concourse village', 'morris park', 'van cortlandt park', 'pleasant plains', 'neponsit', 'forest park', 
          'arverne', 'park hill', 'st. george', 'belle harbor', 'eastchester', 'prospect park', 
          'university heights', 'middle village', 'crown heights', 'sunset park', 'chelsea', 'pelham islands', 
          'todt hill', 'flatlands', 'port morris', 'springfield gardens', 'bay terrace', 
          'st. albans', 'dyker heights', 'dongan hills', 'battery park city', 'downtown brooklyn', 
          'howland hook', 'lower east side', 'rikers island', 'ridgewood', 'longwood', 'hart island',
          'pelham bay', 'wakefield', 'jackson heights', 'parkchester', 'pelham gardens', 'little italy', 
          'greenpoint', 'jamaica hills', 'fort greene', 'marine park', 'williamsburg', 'morningside heights', 
          'schuylerville', 'south brother island', 'kew gardens hills', 'midland beach',
          'shore acres', 'corona', 'south beach', 'rossville', 'hoffman island', 'john f. kennedy international airport',
          'midwood', 'east flatbush', 'flatbush', 'brownsville', 'vinegar hill', 'port ivory', 'fort hamilton', 
          'woodlawn', 'college point', 'fordham', 'great kills', 'north riverdale', 'throgs neck', 'mott haven', 
          'rockaway park', 'navy yard', 'liberty island', 'bensonhurst', 'castleton corners', 'great kills park', 
          "prince's bay", 'belmont', 'riverdale', 'willowbrook', "randall's island", 'east village', 'woodhaven', 
          'west brighton', 'chelsea, staten island', 'baychester', 'clason point', 'melrose', 'nolita', 
          'floyd bennett field', 'williamsbridge', 'cunningham park', 'gravesend', 'bayside', 'ferry point park', 
          'silver lake', 'financial district', 'forest hills', 'flushing meadows corona park', 'freshkills park', 
          'olinville', 'kensington', 'woodrow', 'arden heights', 'carroll gardens', 'fresh meadows', 'east elmhurst', 
          'hollis', 'prospect-lefferts gardens', 'south slope', 'rego park', 'unionport', 'eltingville', 'murray hill', 
          'holliswood', 'new dorp', 'new springville', 'red hook', 'allerton', 'harlem', 'flushing', 
          'north brother island', 'astoria', 'edgemere','lincoln square','clinton','manhattan','hunters point',
         'prospect lefferts gardens','Van Cortlandt Village']
    
    
    if name == "null":
        return "other"
    for item in ls:
        if item in name:
            return "neighborhood"
    return "other"
    
check_neigh = F.udf(check_neighborhood, StringType())


# Code for latitude and longitude validation
def check_latLong(number):
    def islat(num):
        if num>=-90 and num<=90:
            return True
        else:
            return False
    
    def islong(num):
        if num>=-180 and num<=180:
            return True
        else:
            return False
    
    number = number.replace('(', '')
    number = number.replace(')', '')
    lst = number.split(',')
    if len(lst)>1:
        try:
            lat = float(lst[0])
            long = float(lst[1])
            if islat(lat) or islong(long):
                return "lat_lon_cord"
            else:
                return "other"
        except:
            return "other"
    else:
        try:
            val = float(lst[0])
            if islat(val) or islong(val):
                return "lat_lon_cord"
            else:
                return "other"
        except:
            return "other"

check_lat_long = F.udf(check_latLong, StringType())


# Code for park Validataion
def check_park(word):
    word = word.strip()
    word = word.lower()
#     word = word.replace("."," ")
#     word = word.replace("-"," ")
#     word = word.replace("/"," ")
#     word = word.replace("("," ")
#     word = word.replace(")"," ")
    ls = word.split(" ")
    lst = ['parks', 'playground', 'gardens','picnic','recs','recreations','zoo', 'rink',
           'square','triangle','plgds','water','front','ferry', 'lake','field', 'center']
    for item in ls:
        for it in lst:
            if item in it:
                return "park_playground"
    return "other"
        
    
check_park = F.udf(check_park, StringType())

# Code for agency Validation
def check_agency(name):
    name = name.strip()
    name = name.lower()
    lst = ['nycem','nychh','dop','hra','doi','acs','dot','hpd','dca','dpr','ddc','tlc','dcp','dof','doris','cuny','oath','nypd',
           'lpc','dob','qpl','sca','ccrb','dfta','dycd','dcla','nypl','doitt','bic','law','dep','boe','doc','sbs','doe','dohmh',
           'dsny','bpl','dcas','dhs','311','nycha','cchr','fdny']
    if name=="null":
        return "other"
    if name in lst:
        return "city_agency"
    else:
        return "other"
    
check_agency = F.udf(check_agency, StringType())

# Code for subject Validation
def check_subject(name):
    name = name.strip()
    name = name.split(" ")
#     name = name.lower()
    ls = [n.lower() for n in name]
    lst = ['math', 'social', 'science', 'english', 'biology', 'history', 'geography', 'algebra', 'economics',
            'chemistry', 'geometry']
    if ls[0]=="null":
        return "other"
    for item in ls:
        for it in lst:
            if item in it:
                return "subject_in_school"
    return "other"
            
check_subject = F.udf(check_subject, StringType())            
            
# Code for street validation
def check_street(name):
    name = name.strip()
    name = name.split(" ")
    ls = [n.lower() for n in name]
    for item in ls:
        try:
            int(item)
            return "other"
        except:
            continue
    word = ls[-1]
    if word == "null":
        return "other"
    lst = ['boulevard', 'parkway', 'east', 'west', 'street', 'avenue', 'lane', 
           'place' , 'road', 'broadway', 'beach', 'drive', 'trail', 'circle', 'promenade','transit',
            'park', 'highway', 'expressway', 'parkway', 'overpass', 'tunnel', 'slip',
            'bridge', 'exit', 'loop', 'court', 'ramp', 'alley', 'entrance', 'heights', 'oval']
    slst = [soundex(l) for l in lst]
    if any(item in ls for item in lst):
        return "street_name"
    elif any(soundex(item) in ls for item in slst):
        return "street_name"
    else:
        return "other"
    
check_street = F.udf(check_street, StringType())

# Code for address validation
def check_address(word):
    word = word.strip()
    word = word.lower()
    word = word.replace(" ","")
    word = word.replace(",","")
    if word == "null":
        return "other"
    if re.match("\d+\w+\d*", word):
        return "address"
    return "other"
        
    
check_address = F.udf(check_address, StringType())


# Code for schoolLevel Validation
def check_schLvl(word):
    word = word.strip()
    word = word.lower()
    if word == "null":
        return "other"
    lst = ['elementary', 'middle', 'k-2', 'k-3', 'k-8', 'high school' , 'high school transfer', 'yabc']
    if word in lst:
        return "school_level"        
    else:
        return "other"
                
check_school_level = F.udf(check_schLvl, StringType())


# Code for website Validation
def check_website(word):
    if word=='null':
        return "other"
    ls = re.split('\.|\/',word)
    lst = ['gov', 'com', 'org', 'info', 'http', 'https', 'net','edu','www']
    if any(item in ls for item in lst):
        return "website"
    else:
        return "other"

check_website = F.udf(check_website, StringType())






# Code for building classification
def check_build_cls(word):
    if '-' not in word:
        return "other"
    if word == "null":
        return "other"
    word = word.strip().split("-")[0]
    word = word.upper()
    lst = ["A0","A1","A2","A3","A4","A5","A6","A7","A8","A9",
           "B1","B2","B3","B9","C0","C1","C2","C3","C4","C5","C6","C7","C8","C9","CM",
           "D0","D1","D2","D3","D4","D5","D6","D7","D8","D9",
           "E1","E2","E3","E4","E7","E9","F1","F2","F4","F5","F8","F9",
           "G0","G1","G2","G3","G4","G5","G6","G7","G8","G9","GU","GW","G9",
           "HB","HH","HR","HS","H1","H2","H3","H4","H5","H6","H7","H8","H9",
           "I1","I2","I3","I4","I5","I6","I7","I9","J1","J2","J3","J4","J5","J6","J7","J8","J9",
           "K1","K2","K3","K4","K5","K6","K7","K8","K9","L1","L2","L3","L8","L9",
           "M1","M2","M3","M4","M9","N1","N2","N3","N4","N9",
           "O1","O2","O3","O4","O5","O6","O7","O8","O9","P1","P2","P3","P4","P5","P6","P7","P8","P9"
           ,"Q1","Q2","Q3","Q4","Q5","Q6","Q7","Q8","Q9",
           "RA","RB","RG","RH","RK","RP","RR","RS","RT","RW","R0","R1","R2","R3","R4","R5","R6","R7","R8","R9","RR",
           "S0","S1","S2","S3","S4","S5","S9","T1","T2","T9",
           "U0","U1","U2","U3","U4","U5","U6","U7","U8","U9","V0","V1","V2","V3","V4","V5","V6","V7","V8","V9",
           "W1","W2","W3","W4","W5","W6","W7","W8","W9","Y1","Y2","Y3","Y4","Y5","Y6","Y7","Y8","Y9",
           "Z0","Z1","Z2","Z3","Z4","Z5","Z7","Z8","Z9"]
    if word in lst:
        return "building_classification"        
    else:
        return "other"
                
check_build_cls = F.udf(check_build_cls, StringType())


# Code for business Name validation
def check_bizName(name):
    name = name.strip()
    name = name.lower()
    name = name.replace(".","")
    ls = ["co","resto","restaurant","bistro","llc","ltd","inc","pizza","bar",
           "cafe","donuts","grill", "beer","little caesars", "pret","kitchen","hotel","tavern",
            "diner","pllc","group","solutions","pc","pe",'llp','ra']
    ls_new = ["donut","pizz","food","bar","deli","house","bbq","corp","engineer",
              'associate',"architect","consult","service","design","studio"]
    lst = name.split(" ")
    if lst[0]=="the" or lst[0]=='le' or lst[0]=='la':
        return "business_name"
    if name == "null":
        return "other"
    if re.search("\w+\s*[a][n][d]\s*\w+", name):
        return "business_name"
    elif re.search("\s[b][y]\s", name):
        return "business_name"
    elif re.search("\w'[s]", name):
        return "business_name"
    elif any(item in ls for item in lst):
        return "business_name"
    elif any("burger" in item for item in lst):
        return "business_name"
    elif any(it in item for it in ls_new for item in lst):
        return "business_name"
    else:
        return "other"
    
check_biz = F.udf(check_bizName, StringType())



# Code for zipcode validation
def check_zipCode(number):
    number = number.strip()
    if number == "null":
        return "other"
    
    zip_re = re.compile('^[0-9]{5}(?:-[0-9]{4})?$') #accepts 11209 as well as 11209-1234
    if not zip_re.match(number):
        return "other"
    
    code = number[:5]
    if int(code)<10000 or int(code)>19999:
        return "other"
    return "zipcode"    
    
check_zipCode = F.udf(check_zipCode, StringType())


def check_school_name(name):
    name = name.strip()
    name = name.replace(" ","")
    name = name.replace("/","")
    name = name.replace(".","")
    name = name.lower()
    lst = ["ps","i.s","hs","high","school","academy","ms"]
    if any(item in name for item in lst):
        return "school_name"
    else:
        return "other"
    
check_sch_name = F.udf(check_school_name, StringType())



# Code for borough checking. RUN THIS AND READ A FILE AND CALL json_for_borough(dataframe, original_col_name)
def check_borough(word):
    word = word.lower()
    if word in ["manhattan", "brooklyn", "bronx", "staten island", "queens"]:
        return "borough"
    else:
        return "other"

check_borough = F.udf(check_borough, StringType())


# Code for phone checking. RUN THIS AND READ A FILE AND CALL json_for_phone(dataframe, original_col_name)
def check_phoneNum(number):
    number = number.strip()
    number = number.replace("-","")
    number = number.replace(".","")
    if number == 'null':
        return "other"
    if len(number)!= 10:
        return "other"
    if not number.isdigit():
        return "other"
        
    return "phone_number"
        
check_phoneNum = F.udf(check_phoneNum, StringType())

# %%
import json

with open("../Downloads/nyc-neighborhoods/hoods.json") as f:
    data = json.load(f)

lst = []
for item in data["features"]:
    lst.append(item["properties"]["neighborhood"].lower())
print(set(lst))
# def plot_graph_for_json(jsonfilename):
#     with open(jsonfilename) as f:
#         data = json.load(f)
#     dtct = {}
#     for col in data["columns"]:
#         for tp in col["dataTypes"]:
#             dt = tp["type"]
#             if dt not in dtct.keys():
#                 dtct[dt] = 1
#             else:
#                 dtct[dt] += 1
#     filename = jsonfilename.split('.')[0]
#     plt.bar(range(len(dtct)), list(dtct.values()), align='center')
#     st=0
#     for x,y in dtct.items():
#         x=st
#         label = y
#         plt.annotate(label,(x,y),textcoords="offset points",xytext=(0,2),ha='center',weight='bold')
#         st+=1
#     plt.xticks(range(len(dtct)), list(dtct.keys()))
#     plt.title("Histogram for {}".format(filename), weight='bold')
#     plt.show()

# %%
with open("../Downloads/names/male.txt") as f:
    male = f.readlines()
with open("../Downloads/names/female.txt") as f:
    female = f.readlines()
male = [x.strip() for x in male]
female = [x.strip() for x in female]
content = male+female

def check_name(name, content):
    name = name.lower()
    name = name.replace("&","")
    name = name.replace("and","")
    name = name.replace("/"," ")
    name = name.replace(".","")
    name= name.replace("-","")
    name = name.strip()
    if len(name)==1:
        return "person_name"
    for nm in content:
        if soundex(name) in soundex(nm):
            return "person_name"
    return "other"
#     name = name.split(" ")
    lst = ["residence","house","bar","club","subway","diner","market","street",
           "store","hospital","grocery","bus"]
    for item in lst:
        if item in name:
            return "location_type"
    return "other"

    
check_name_l = F.udf(lambda x: check_name(x, content), StringType())

# %%
# with open("../Downloads/names/male.txt") as f:
#     male = f.readlines()
# with open("../Downloads/names/female.txt") as f:
#     female = f.readlines()
# male = [x.strip() for x in male]
# female = [x.strip() for x in female]
# content = male+female

# %%
name = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/Greenbook.tsv")
# body = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/Parking_Violations_Issued_-_Fiscal_Year_2017.tsv")
# interest.select("interest1").distinct().show(make.count(), truncate=False)
name = preprocess(name)
temp = name.withColumn("check", check_name_l(F.col('First Name')))
print(temp.filter(temp.check=="other").count())
temp.select("check",'First Name').show(truncate=False)
# temp.filter(temp.check=="other").filter(temp['Vehicle Body Type']!="null").select('Vehicle Body Type', "check").show(1000, truncate=False)
# temp.filter(temp.check=="other").select("interest1", "check").show(temp.count(), truncate=False)
# temp.filter(temp.check=="other").select("neighborhood","check").show(truncate=False)
name.columns
# Out:
# 310
# +-----------+----------+
# |check      |First Name|
# +-----------+----------+
# |person_name|Dawn      |
# |person_name|Shachi    |
# |person_name|Olga      |
# |person_name|Peter     |
# |person_name|Darrell   |
# |person_name|Johnson   |
# |person_name|Lakisha   |
# |person_name|Roman     |
# |person_name|Andrew    |
# |other      |Vacant    |
# |person_name|Anthony   |
# |person_name|Thomas    |
# |person_name|Merrick   |
# |person_name|Edward    |
# |person_name|Alicia    |
# |person_name|Michael   |
# |person_name|Linda     |
# |person_name|Veronika  |
# |person_name|Corinne   |
# |person_name|Sergio    |
# +-----------+----------+
# only showing top 20 rows
# ['Agency Name',
#  'Agency Acronym',
#  'Agency Website',
#  'First Name',
#  'Last Name',
#  'Middle Initial',
#  'Name Suffix',
#  'Office Title',
#  'Division Name',
#  'Parent Division',
#  'Grand Parent Division',
#  'Great Grand Parent Division',
#  'Address',
#  'City',
#  'State',
#  'Zip Code',
#  'Phone 1',
#  'Phone 2',
#  'Fax 1',
#  'Fax 2',
#  'Agency Primary Phone',
#  'Division Primary Phone',
#  'Section']

# %%
# Code for color Validation
lclr=['lime', 'lavender', 'clear', 'lm', 'q', 
      'violet', 'trns', 'red', 'rng', 'slvr', 
      'grn', 'copper', 'unknown', 'blck', 'aqua', 
      'trans', 'purple', 'bl', 'gry', 'yllw', 'wht', 'gld', 
      'azure', 'lvndr', 'zr', 'pq', 'tan', 'lns', 'flesh', 
      'magenta', 'yellow', 'cppr', 'orange', 'slmn', 'clr]', 
      'silver', 'opaque', 'rd', 'rust', 'tn', 'brwn', 'pink', 
      'gold', 'clr', 'flsh', 'pnk', 'llc', 'brown', 'black', 'turquoise', 
      'nknwn', 'gray', 'rst', 'color]', 'prpl', 'mgnt', 'brss', 'salmon', 
      'blue', 'green', 'trqs', 'vlt', 'lilac', 'white', 'lens', 'brass']


def check_color(word, lclr):
    word = word.strip()
    word = word.lower()
    if word == "null":
        return "other"
    if word == '-':
        return "other"
    for item in lclr:
        if ld(word, item)<=1:
            return "color"

    return "other"
                
check_color_l=F.udf(lambda x: check_color(x, lclr), StringType())




# Code for city Validation
citydf = spark.read.option("sep", "|").option("header", "true").csv("../Downloads/USA/us_cities_states_counties.csv")
citydf = citydf.filter(citydf["State short"]=="NY")
mvv = citydf.select("City").rdd.flatMap(lambda x: x).collect()
lowermvv = [c.lower() for c in mvv]
def check_city(word, mvv):
    if word is None:
        return "other"
    word = word.strip()
    word = word.lower()
    if word == "null":
        return "other"
    lst = mvv
    if word in lst:
        return "city"        
    else:
        return "other"
                
check_city_l=F.udf(lambda x: check_city(x,lowermvv), StringType())


# Code for name check
with open("../Downloads/names/male.txt") as f:
    male = f.readlines()
with open("../Downloads/names/female.txt") as f:
    female = f.readlines()
male = [x.strip() for x in male]
female = [x.strip() for x in female]
content = male+female

def check_name(name, content):
    name = name.lower()
    name = name.replace("&","")
    name = name.replace("and","")
    name = name.replace("/"," ")
    name = name.replace(".","")
    name= name.replace("-","")
    name = name.strip()
    if len(name)==1:
        return "person_name"
    for nm in content:
        if soundex(name) in soundex(nm):
            return "person_name"
    return "other"
#     name = name.split(" ")
    lst = ["residence","house","bar","club","subway","diner","market","street",
           "store","hospital","grocery","bus"]
    for item in lst:
        if item in name:
            return "location_type"
    return "other"

    
check_name_l = F.udf(lambda x: check_name(x, content), StringType())

# %%
park.select("Park/Site Name").distinct().show(agency.count(),truncate=False)
# print(agency.count())
# from functools import reduce
# def change_col(col):
#     col = col.replace(" ","_")
#     col = col.replace("/","_")
#     col = col.replace("-","_")
#     return col
# oldColumns = park.columns
# print(oldColumns)
# newColumns = [change_col(item) for item in oldColumns]
# print(newColumns)
# park = park.select(F.col(col).alias(change_col(col)) for col in df.columns)
# park = reduce(lambda data, idx: park.withColumnRenamed(oldColumns[idx], newColumns[idx]), range(len(oldColumns)), park)
# park.columns
# Out:
# +--------------------------------------------------------------------------------------+
# |Park/Site Name                                                                        |
# +--------------------------------------------------------------------------------------+
# |Mobilization for Change Community Garden                                              |
# |Juniper Valley Park                                                                   |
# |Cuyler Gore Park                                                                      |
# |Chelsea Park                                                                          |
# |Wolfe's Pond                                                                          |
# |Bronx Botanical Gardens                                                               |
# |Kaiser                                                                                |
# |J. Hood Wright                                                                        |
# |Al Oerter Rec Center                                                                  |
# |Fordham University                                                                    |
# |1 Centre Street                                                                       |
# |St. Nicholas-Olive Street Garden                                                      |
# |Culinary Kids                                                                         |
# |Family Group Garden                                                                   |
# |New Hoe Avenue Garden                                                                 |
# |JJ Byrne                                                                              |
# |Mahony Playground                                                                     |
# |Silver Lake Dog Run                                                                   |
# |Skate Park at Allerton                                                                |
# |McGorlick Park                                                                        |
# |Salt marsh                                                                            |
# |Soho Partnership                                                                      |
# |Flushing Meadows Pool                                                                 |
# |E Gun Hill Rd & Bronxwood Ave                                                         |
# |John Jay Park                                                                         |
# |Sara D. Roosevelt                                                                     |
# |Noble Playground                                                                      |
# |Highbridge                                                                            |
# |100 Centre Street                                                                     |
# |Bloomingdale Playgound                                                                |
# |Bradley Playground                                                                    |
# |Cedar Grove Beach                                                                     |
# |Fred Johnson                                                                          |
# |El Flamboyan                                                                          |
# |David Marcus Plgd                                                                     |
# |Harrison St Basketball Court                                                          |
# |Baisley Pond Park                                                                     |
# |Buzz O'Rourke Playground                                                              |
# |FAB                                                                                   |
# |St. Catherine's                                                                       |
# |Corporal Thompson Playground                                                          |
# |Joyce Kilmer                                                                          |
# |Olinville                                                                             |
# |80 Centre St                                                                          |
# |Pier 25 Mini Golf & Skate Park                                                        |
# |Pier 57                                                                               |
# |Carroll Park                                                                          |
# |Jackson Square                                                                        |
# |Rainey park                                                                           |
# |Desalvio                                                                              |
# |Vogue Community Garden                                                                |
# |Van Cortlandt Stadium                                                                 |
# |Virginia Park                                                                         |
# |Austin E                                                                              |
# |Riverdale Neighborhood House                                                          |
# |Hands  & Hearts(New Lots Urban Farm)                                                  |
# |Hudson River Park                                                                     |
# |Union Square                                                                          |
# |Cloves Lake                                                                           |
# |Bennett Park                                                                          |
# |Rec Center  54                                                                        |
# |Sorrentino                                                                            |
# |Museum of Natural History/Planitarium                                                 |
# |Fort Greene                                                                           |
# |2 Lafayette St                                                                        |
# |Phil Rizzuto Park                                                                     |
# |Rockaway Beach                                                                        |
# |Bleecker St. Playground                                                               |
# |Orchard Beach picnic areas, basketball ct, Pelham playground, Nature Center, Boathouse|
# |Morris Jumel Ecological Garden                                                        |
# |Mt. Prospect plgd                                                                     |
# |Brownsville Rec Ctr                                                                   |
# |Queens Museum                                                                         |
# |Southern Blvd & E 173 St                                                              |
# |Concrete Plant Park                                                                   |
# |Fashion BID                                                                           |
# |Parks Council Success Garden- P.S. 175 I.S. 275                                       |
# |Faber Pool                                                                            |
# |Playground for All Children                                                           |
# |150 St                                                                                |
# |B.C.C.A. Mini-Park and Garden                                                         |
# |Cunningham Ballfields                                                                 |
# |Pier 45                                                                               |
# |Arthur Ave & E 187 St                                                                 |
# |Socrates Park                                                                         |
# |Nursery                                                                               |
# |Brooklyn War Memorial                                                                 |
# |Pierrepont Park                                                                       |
# |Commodore Berry                                                                       |
# |Kelly                                                                                 |
# |Bryant Park - Bryant Park Corp.                                                       |
# |George Eagle Carr Community Garden                                                    |
# |Grover Cleveland                                                                      |
# |Prall Playground                                                                      |
# |Good Shepheard's Community Group                                                      |
# |McDonald Park                                                                         |
# |MacArthur Park                                                                        |
# |Watson & Gleason                                                                      |
# |Pier 40 Roof                                                                          |
# |Kissena Park                                                                          |
# |Bensonhurst                                                                           |
# |346 Broadway                                                                          |
# |Detective Keith Williams                                                              |
# |E Tremont Ave & University Ave                                                        |
# |Crotona Park                                                                          |
# |Colonel Young                                                                         |
# |Each One Teach One                                                                    |
# |Harlem River Ballfield                                                                |
# |LBH Rec Center                                                                        |
# |Walker Park                                                                           |
# |Hunts Point                                                                           |
# |DSNY Main Office -Worth St                                                            |
# |Rucker Park-parks                                                                     |
# |Berry Homes ballfield                                                                 |
# |John M. D'Amato Field                                                                 |
# |South Beach                                                                           |
# |227th St. Plgd                                                                        |
# |Graniteville                                                                          |
# |FAB                                                                                   |
# |Red Hook Park                                                                         |
# |UCC (United Community Centers) Youth Farm/East New York Farms                         |
# |Columbus Park - DSNY Partnership                                                      |
# |St. Vartan's                                                                          |
# |Washington Square Park                                                                |
# |Greenthumb compound                                                                   |
# |Cunningham Picnic                                                                     |
# |Steinway St                                                                           |
# |City Line Park                                                                        |
# |Whitehall Ferry Terminal                                                              |
# |Harlem RBI – Community Group                                                          |
# |Broadway & Murray St                                                                  |
# |Father Dumo Square                                                                    |
# |Clove lake garage complex                                                             |
# |Skyview Shopping Plaza                                                                |
# |Korean War Vet                                                                        |
# |French Charley Playground                                                             |
# |Muskrat Playground                                                                    |
# |Sunset Park                                                                           |
# |Shore Road Plgd                                                                       |
# |Sternberg Park                                                                        |
# |Vernon (Throop Avenue Block Assoc.)                                                   |
# |Hunt's point Riverside Park- Plgd - Parks                                             |
# |Niles Triangle                                                                        |
# |West Bronx Rec. Ctr                                                                   |
# |Underwood Playground                                                                  |
# |City Hall Park                                                                        |
# |Hamilton Fish                                                                         |
# |Thomas Payne                                                                          |
# |Battery Park City                                                                     |
# |Chelsea Rec Center                                                                    |
# |Grand Central                                                                         |
# |Starret City                                                                          |
# |111 Centre St                                                                         |
# |Inwood Dyckman fields                                                                 |
# |Abe Wolfson                                                                           |
# |Charybdis plgd                                                                        |
# |Seton Falls Park                                                                      |
# |New Vision Garden                                                                     |
# |100 Gold Street                                                                       |
# |Chelsea Waterside Park Playground                                                     |
# |St. Michaels                                                                          |
# |Marie Curie Playground                                                                |
# |Las Casitas Communitiy Garden                                                         |
# |P.O. Serrano                                                                          |
# |280 Broadway                                                                          |
# |Upon the Rock                                                                         |
# |St. Mary's                                                                            |
# |Cadman Plaza                                                                          |
# |Battery Park - DSNY Partnership                                                       |
# |Pelham Fritz                                                                          |
# |River Garden                                                                          |
# |Fort Totten                                                                           |
# |Underhill                                                                             |
# |Brower                                                                                |
# |Courtyard West                                                                        |
# |Highline Entrance+Park                                                                |
# |Washington Market Playground                                                          |
# |Isla Verde Garden                                                                     |
# |Prospect Park                                                                         |
# |McCaffry Plgd – Parks                                                                 |
# |Echo Park                                                                             |
# |Metropolitan Rec Ctr                                                                  |
# |Seward park                                                                           |
# |Bayard St & Baxter St                                                                 |
# |Gregory's Garden (P.S. 158 Memorial Garden                                            |
# |West 124th Street Community Garden                                                    |
# |Passerelle - Aquatics                                                                 |
# |Greenbelt Park                                                                        |
# |E 176 St & Marmion Ave                                                                |
# |Alley Pond Environmental                                                              |
# |Jardin de las Rosas                                                                   |
# |Little Green Garden (3) Large lower expanse                                           |
# |Captain Tilly                                                                         |
# |Tompkins Square Park                                                                  |
# |West Brighton Pool                                                                    |
# |Southwest Plgd – Parks                                                                |
# |Boerum                                                                                |
# |Southern Fields                                                                       |
# |Park Slope Playground                                                                 |
# |Foley Square - DSNY Partnership                                                       |
# |Bronx County Courthouse                                                               |
# |Pier 40 Dog Run                                                                       |
# |Bryant Hill Community Garden                                                          |
# |Park Row & Beekman Street                                                             |
# |Jacob Schiff                                                                          |
# |Pier 84 (44 St Park Building)                                                         |
# |Astoria Park                                                                          |
# |Flushing Meadows Corona Park                                                          |
# |World ice rink                                                                        |
# |Bronx Zoo                                                                             |
# |Myrtle Ave BID                                                                        |
# |Red Gate Garden                                                                       |
# |Asser Levy Rec Ctr                                                                    |
# |Crack is Wack                                                                         |
# |Hornaday Community Garden (volky Flower Garden)                                       |
# |Tony Dapolito                                                                         |
# |Dumbo Brooklyn Heights                                                                |
# |E 174 St & Manor Ave                                                                  |
# |River Park                                                                            |
# |60 Lafayette St                                                                       |
# |Warren & Greenwich                                                                    |
# |96th St Train Station (under our supervision)                                         |
# |DeMatti Playground                                                                    |
# |Asser Levy                                                                            |
# |Bellevue South                                                                        |
# |Times Square                                                                          |
# |Pleasant Village Community Garden                                                     |
# |Parks Academy                                                                         |
# |E Tremont Ave & Bruckner Blvd                                                         |
# |Queens Hall of Science                                                                |
# |Cobble hill park                                                                      |
# |Broadway & Park Place                                                                 |
# |Jacob Javits Playground                                                               |
# |100 Centre St                                                                         |
# |Centre St & Chambers St                                                               |
# |Maggie's Garden                                                                       |
# |Hansboro                                                                              |
# |Pelham Bay  Ball field, north picnic area                                             |
# |22 Reade St                                                                           |
# |Owl's Head                                                                            |
# |Squibb Park                                                                           |
# |Soundview – Parks                                                                     |
# |6BC Botanical Garden                                                                  |
# |Al Smith Rec Ctr                                                                      |
# |Allerton Ballfields                                                                   |
# |West End Avenuw                                                                       |
# |Byrne Park                                                                            |
# |Sachkera Plgd – Parks                                                                 |
# |Tribeca Partnership                                                                   |
# |Bay Ridge                                                                             |
# |Greenbelt Rec Ctr                                                                     |
# |St. James                                                                             |
# |Morningside Park                                                                      |
# |Lincoln Square                                                                        |
# |Wall Street (South/Front)                                                             |
# |Block Association #81                                                                 |
# |Elmhurst Park                                                                         |
# |West 4th St. Courts (PLGD)                                                            |
# |Bushwick Inlet Field                                                                  |
# |Greenwich & Murray                                                                    |
# |Sixth St. & Ave. B                                                                    |
# |Staten Island Ferry Terminal                                                          |
# |HUB 3rd Ave                                                                           |
# |N. 5th St. pier                                                                       |
# |Verdi Square                                                                          |
# |Queens Zoo                                                                            |
# |St. John's                                                                            |
# |William Simmons Community Garden Club                                                 |
# |Bryant Park                                                                           |
# |Imagination Playground                                                                |
# |Lyons Pool                                                                            |
# |Quarry Ballfield- Parks                                                               |
# |Rocket Park                                                                           |
# +--------------------------------------------------------------------------------------+
# only showing top 273 rows

# %%
park = preprocess(park)
# street.select("TOSTREETNAME").show()
tempst = park.withColumn("temp", check_color_l(F.col("Park/Site Name")))
# tempst.
# tempst.groupBy("temp").agg({"temp":'count'}).show()
# tempst.select("temp","Park/Site Name").show(tempst.count(), truncate=False)
tempst.filter(tempst.temp=="color").select("temp","Park/Site Name").distinct().show(tempst.count(), truncate=False)
# Out:
# +----+--------------+
# |temp|Park/Site Name|
# +----+--------------+
# +----+--------------+

# %%
# lclr=["lime", 'lavender', 'clear', 'lm', 'q', 
#       'violet', 'trns', 'red', 'rng', 'slvr', 
#       'grn', 'copper', 'unknown', 'blck', 'aqua', 
#       'trans', 'purple', 'bl', 'gry', 'yllw', 'wht', 'gld', 
#       'azure', 'lvndr', 'zr', 'pq', 'tan', 'lns', 'flesh', 
#       'magenta', 'yellow', 'cppr', 'orange', 'slmn', 'clr]', 
#       'silver', 'opaque', 'rd', 'rust', 'tn', 'brwn', 'pink', 
#       'gold', 'clr', 'flsh', 'pnk', 'llc', 'brown', 'black', 'turquoise', 
#       'nknwn', 'gray', 'rst', 'color]', 'prpl', 'mgnt', 'brss', 'salmon', 
#       'blue', 'green', 'trqs', 'vlt', 'lilac', 'white', 'lens', 'brass']


# R = Row('color')

# clr = spark.createDataFrame([R(i) for i in lclr])

# %%
"""
For each entry in the cluster2.txt file
1. Read the filename.
2. Check if the column exists.
3. Call check_1 and call the colm check_1. Find count of proper/other
4. Do the above for all the check_i.
5. Return the type that has least Other.
6. Find count of nulls where check_i is null and check_i+1 is null and so on.
"""
    
    
def find_type(df, col):
    df = preprocess(df)
    df = df.withColumn("check1", check_website(F.col(col)))
    df = df.withColumn("check2", check_borough(F.col(col)))
    df = df.withColumn("check3", check_phoneNum(F.col(col)))
    df = df.withColumn("check4", check_build_cls(F.col(col)))
    df = df.withColumn("check5", check_city_l(F.col(col)))
    df = df.withColumn("check6", check_school_level(F.col(col)))
    df = df.withColumn("check7", check_sch_name(F.col(col)))
    df = df.withColumn("check8", check_color_l(F.col(col)))
    df = df.withColumn("check9", check_address(F.col(col)))
    df = df.withColumn("check10", check_street(F.col(col)))
    df = df.withColumn("check11", check_subject(F.col(col)))
    df = df.withColumn("check12", check_agency(F.col(col)))
    df = df.withColumn("check13", check_park(F.col(col)))
    df = df.withColumn("check14", check_zipCode(F.col(col)))
    df = df.withColumn("check15", check_lat_long(F.col(col)))
    df = df.withColumn("check16", check_biz(F.col(col)))
    df = df.withColumn("check17", check_neigh(F.col(col)))
    df = df.withColumn("check18", check_make(F.col(col)))
    df = df.withColumn("check19", check_area_of_study(F.col(col)))
    df = df.withColumn("check20", check_uni_name(F.col(col)))
    df = df.withColumn("check21", check_body(F.col(col)))
    df = df.withColumn("check22", check_loc(F.col(col)))
    df = df.withColumn("check23", check_name_l(F.col(col)))
#     df.filter(df.check21!='other').select(col, "check21").show()
    countr = []
    for i in range(1,24):
        colname = "check"+str(i)
        countr.append(return_ct(df, colname))
#     print(countr)
#     sorted(countr, key=lambda x:x[0])
    countr.sort()
    print("This is counter:",countr)
    return countr[0][1][0]
    

    
    
def return_ct(df, colname):
    df.createOrReplaceTempView("df")
    query = "select "+colname+", count(*) as ctr from df group by "+colname
    temp = spark.sql(query)
#     temp.show()
    print(query)
    tm = [0,0]
    flag=True
    for row in temp.rdd.collect():
        if row[colname]=="other":
            tm[0] = row.ctr
        else:
            flag=False
            tm[1] = (row[colname], row.ctr)
    if flag:
        tm[1] = ("NOTA", 0)
    return tm

# %%
# tempdf = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2017_DOE_High_School_Directory.tsv")
# print("The predicted semantic type of website is : ",find_type(tempdf, "website"))
city1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Charges.tsv")
print("The predicted semantic type of city is : ",find_type(city1, "City"))
schLvl = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2011-2012_School_Progress_Report_-_All_Schools.tsv")
print("The predicted semantic type of school level is : ",find_type(schLvl, "SCHOOL LEVEL*"))
schname = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Application_for_State_Aid.tsv")
print("The predicted semantic type of school name is : ",find_type(schname, "SCHOOL NAME"))
address = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2018_School_Quality_Report_Results_for_PreK.tsv")
print("The predicted semantic type of address is : ",find_type(address, "Address 1"))
street = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Street_Closures_due_to_construction_activities_by_Block.tsv")
print("The predicted semantic type of street name is : ",find_type(street, "TOSTREETNAME"))
sub = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/2011-2012_CLASS_SIZE_REPORT_DISTRICT_LEVEL_DISTRIBUTION.tsv")
print("The predicted semantic typeof core subject is : ",find_type(sub, "CORE SUBJECT"))
agency = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/FY2017_MMR_Spending_and_Budget_Tables.tsv")
print("The predicted semantic type of agency is : ",find_type(agency, "Agency"))
park = spark.read.option("sep", "\t").option("header","true").csv("../Downloads/Public_Recycling_Bins.tsv")
print("The predicted semantic type of park is : ",find_type(park, "Park/Site Name"))
# color = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Parking_Violations_Issued_-_Fiscal_Year_2017.tsv")
# print("The predicted semantic typeof color is : ", find_type(color, "Vehicle Color"))
# wifi = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/NYC_Wi-Fi_Hotspot_Locations.tsv")
# print("The predicted semantic type of latitude is : ", find_type(wifi, "Location (Lat, Long)"))
# biz1 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Sidewalk_Caf__Licenses_and_Applications.tsv")
# print("The predicted semantic type of businessname is : ", find_type(biz1, "BUSINESS_NAME2"))
# biz2 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/Commercial_Bicycle_Unit_Inspections.tsv")
# print("The predicted semantic type of businessname is : ", find_type(biz2, "BusinessName"))
# biz3 = spark.read.option("sep", "\t").option("header", "true").csv("../Downloads/DOB_NOW__Build___Job_Application_Filings.tsv")
# print("The predicted semantic type of businessname is : ", find_type(biz3, "Owner's Business Name"))
# neigh = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/2019_DOE_High_School_Directory.tsv")
# print("The predicted semantic type of neighborhood is : ",find_type(neigh, "neighborhood"))
# interest = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/2018_DOE_High_School_Directory.tsv")
# print("The predicted semantic type of area of study is : ", find_type(interest, "interest1"))
# body = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/Motor_Vehicle_Collisions_-_Crashes.tsv")
# print("The predicted semantic type of vehicle body type is : ", find_type(body, "VEHICLE TYPE CODE 2"))
# loc = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/2003_Campaign_Expenditures.tsv")
# print("The predicted semantic type of lat long type is : ", find_type(loc, 'Location 1'))
# loc = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/DOHMH_New_York_City_Restaurant_Inspection_Results.tsv")
# print("The predicted semantic type of business name type is : ", find_type(loc, 'DBA'))
# loc = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/NYPD_Complaint_Data_Current__Year_To_Date_.tsv")
# print("The predicted semantic type of loc type is : ", find_type(loc, 'PREM_TYP_DESC'))
name = spark.read.option("delimiter", "\t").option("header", "true").csv("../Downloads/Greenbook.tsv")
print("The predicted semantic type of name type is : ", find_type(name, 'First Name'))
# name.columns
# Out:
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[2110, ('city', 145516)], [25400, ('person_name', 122226)], [70960, ('borough', 76666)], [98249, ('vehicle_type', 49377)], [116194, ('neighborhood', 31432)], [142415, ('street_name', 5211)], [144630, ('park_playground', 2996)], [146434, ('business_name', 1192)], [147289, ('subject_in_school', 337)], [147355, ('college_name', 271)], [147574, ('school_name', 52)], [147625, ('car_make', 1)], [147625, ('color', 1)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)], [147626, ('NOTA', 0)]]
# The predicted semantic type of city is :  city
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[0, ('school_level', 1743)], [1119, ('person_name', 624)], [1250, ('school_name', 493)], [1721, ('vehicle_type', 22)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)], [1743, ('NOTA', 0)]]
# The predicted semantic type of school level is :  school_level
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[2827, ('school_name', 9426)], [9184, ('vehicle_type', 3069)], [10527, ('person_name', 1726)], [11544, ('park_playground', 709)], [11716, ('subject_in_school', 537)], [11788, ('neighborhood', 465)], [11834, ('business_name', 419)], [12098, ('street_name', 155)], [12157, ('location_type', 96)], [12180, ('college_name', 73)], [12218, ('area_of_study', 35)], [12236, ('address', 17)], [12247, ('color', 6)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)], [12253, ('NOTA', 0)]]
# The predicted semantic type of school name is :  school_name
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[8, ('address', 1976)], [1213, ('location_type', 771)], [1642, ('street_name', 342)], [1649, ('school_name', 335)], [1801, ('vehicle_type', 183)], [1871, ('neighborhood', 113)], [1913, ('park_playground', 71)], [1928, ('business_name', 56)], [1952, ('subject_in_school', 32)], [1981, ('college_name', 3)], [1983, ('person_name', 1)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)], [1984, ('NOTA', 0)]]
# The predicted semantic type of address is :  address
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[23617, ('street_name', 45797)], [45182, ('person_name', 24232)], [47209, ('location_type', 22205)], [56886, ('address', 12528)], [57151, ('vehicle_type', 12263)], [59409, ('park_playground', 10005)], [61818, ('subject_in_school', 7596)], [66000, ('neighborhood', 3414)], [67271, ('business_name', 2143)], [68008, ('school_name', 1406)], [69278, ('college_name', 136)], [69413, ('city', 1)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)], [69414, ('NOTA', 0)]]
# The predicted semantic type of street name is :  street_name
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[1758, ('person_name', 10680)], [5403, ('subject_in_school', 7035)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)], [12438, ('NOTA', 0)]]
# The predicted semantic typeof core subject is :  person_name
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[0, ('city_agency', 273)], [74, ('person_name', 199)], [82, ('vehicle_type', 191)], [232, ('car_make', 41)], [268, ('color', 5)], [271, ('school_name', 2)], [272, ('address', 1)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)], [273, ('NOTA', 0)]]
# The predicted semantic type of agency is :  city_agency
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[235, ('park_playground', 310)], [246, ('vehicle_type', 299)], [340, ('person_name', 205)], [345, ('street_name', 200)], [431, ('neighborhood', 114)], [495, ('business_name', 50)], [503, ('subject_in_school', 42)], [519, ('location_type', 26)], [522, ('school_name', 23)], [523, ('address', 22)], [538, ('college_name', 7)], [539, ('car_make', 6)], [540, ('area_of_study', 5)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)], [545, ('NOTA', 0)]]
# The predicted semantic type of park is :  park_playground
# select check1, count(*) as ctr from df group by check1
# select check2, count(*) as ctr from df group by check2
# select check3, count(*) as ctr from df group by check3
# select check4, count(*) as ctr from df group by check4
# select check5, count(*) as ctr from df group by check5
# select check6, count(*) as ctr from df group by check6
# select check7, count(*) as ctr from df group by check7
# select check8, count(*) as ctr from df group by check8
# select check9, count(*) as ctr from df group by check9
# select check10, count(*) as ctr from df group by check10
# select check11, count(*) as ctr from df group by check11
# select check12, count(*) as ctr from df group by check12
# select check13, count(*) as ctr from df group by check13
# select check14, count(*) as ctr from df group by check14
# select check15, count(*) as ctr from df group by check15
# select check16, count(*) as ctr from df group by check16
# select check17, count(*) as ctr from df group by check17
# select check18, count(*) as ctr from df group by check18
# select check19, count(*) as ctr from df group by check19
# select check20, count(*) as ctr from df group by check20
# select check21, count(*) as ctr from df group by check21
# select check22, count(*) as ctr from df group by check22
# select check23, count(*) as ctr from df group by check23
# This is counter: [[310, ('person_name', 4541)], [4174, ('vehicle_type', 677)], [4601, ('car_make', 250)], [4745, ('city', 106)], [4772, ('business_name', 79)], [4816, ('color', 35)], [4828, ('location_type', 23)], [4839, ('park_playground', 12)], [4847, ('neighborhood', 4)], [4847, ('subject_in_school', 4)], [4849, ('city_agency', 2)], [4849, ('school_name', 2)], [4850, ('street_name', 1)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)], [4851, ('NOTA', 0)]]
# The predicted semantic type of name type is :  person_name
